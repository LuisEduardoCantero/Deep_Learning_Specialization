# %% [markdown]
# ## Resumen del notebook
#
# En este notebook se implementa una regresión logisitca para una clasficación binomial.
#
# En este notebook se pretende implementar una convolucioncmuy basica a las imagenes del set de entrenamiento y de prueba. La convolucion consiste unicamente en aplicar un filtro de bordes a las imagenes.
#
# Al final del notebook se realiza una prueba del modelo entrenado con imagenes de lentes gravitacionales reales con forma de arco para analizar el desempeño ante imagenes reales.
#
#
# **Información del data set utilizado:**
#
# No. Imagenes **sin** lentes para TRAIN: 2900
#
# No. Imagenes **con** lentes para TRAIN: 3700
#
#
# No. Imagenes **sin** lentes para TEST: 1700
#
# No. Imagenes **con** lentes para TEST: 2500
#
#
# **Principales hiperparametros de entrenamiento en este notebook:**
#
# Tamaño en pixeles de las imagenes de entrenamiento: 217x217x3
#
# Alpha (learning rate): 0.005
#
# Numero de iteraciones durante el entrenamiento: 2000
#
# **Desempeño de este modelo ante imagenes reales de lentes gravitacionales: MAL:** Realiza una mala clasificación en la mayoria de las imagenes reales. Se necesita mejorar el modelo en general y tratar de identificar por qué el rendimiento del modelo
#
# **Desempeño del modelo con diferentes valores de alpha (learning rate):**

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# **Desempeño del modelo con diferentes valores de alpha (learning rate):**

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <a name='1'></a>
# ## Cargar librerias
#
# Primero cargamos las librerias necesarias para este notebook de clasificación binaria.

# %%
import numpy as np
import copy
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
from lr_utils import load_dataset
from public_tests import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
#####
import tensorflow as tf
from astroNN.datasets import galaxy10
import sklearn
from sklearn.model_selection import train_test_split
#import scipy.ndimage
import cv2
from skimage.transform import PiecewiseAffineTransform, warp
from skimage import data
import os
import pandas as pd

# %%
def seno_imagen(image, amplitud, periodo, nombre):

    rows, cols = image.shape[0], image.shape[1]

    src_cols = np.linspace(0, cols, 20)
    src_rows = np.linspace(0, rows, 10)
    src_rows, src_cols = np.meshgrid(src_rows, src_cols)
    src = np.dstack([src_cols.flat, src_rows.flat])[0]

    # add sinusoidal oscillation to row coordinates
    #dst_rows = src[:, 1] - np.sin(np.linspace(0, periodo, src.shape[0]) +12 ) * amplitud +150
    dst_rows = src[:, 1] - 0.38*np.sin(np.linspace(0, periodo, src.shape[0])/.5 ) * amplitud - 10
    dst_cols = src[:, 0]
    #dst_rows *= 1.5
    #dst_rows -= 1.5 * 50
    dst = np.vstack([dst_cols, dst_rows]).T


    tform = PiecewiseAffineTransform()
    tform.estimate(src, dst)

    out_rows = image.shape[0] # - 1.5 * 50
    out_cols = cols
    out = warp(image, tform, output_shape=(out_rows, out_cols))

    fig, ax = plt.subplots()
    ax.imshow(out)
    #ax.plot(tform.inverse(src)[:, 0], tform.inverse(src)[:, 1], '.b')
    #ax.axis((0, out_cols, out_rows, 0))
    plt.rcParams ["figure.figsize"] = (5,5)
    
    plt.axis('off')
    plt.imshow(out)
    
    #plt.savefig(nombre, bbox_inches='tight',pad_inches = 0, dpi=56.5)

# %%
def seno_imagen1(image, amplitud, periodo, nombre):

    rows, cols = image.shape[0], image.shape[1]

    src_cols = np.linspace(0, cols, 20)
    src_rows = np.linspace(0, rows, 10)
    src_rows, src_cols = np.meshgrid(src_rows, src_cols)
    src = np.dstack([src_cols.flat, src_rows.flat])[0]

    # add sinusoidal oscillation to row coordinates
    #dst_rows = src[:, 1] - np.sin(np.linspace(0, periodo, src.shape[0]) +12 ) * amplitud +150
    dst_rows = src[:, 1] - 0.38*np.sin(np.linspace(0, periodo, src.shape[0])/.5 ) * amplitud + 40
    dst_cols = src[:, 0]
    #dst_rows *= 1.5
    #dst_rows -= 1.5 * 50
    dst = np.vstack([dst_cols, dst_rows]).T


    tform = PiecewiseAffineTransform()
    tform.estimate(src, dst)

    out_rows = image.shape[0] # - 1.5 * 50
    out_cols = cols
    out = warp(image, tform, output_shape=(out_rows, out_cols))

    fig, ax = plt.subplots()
    ax.imshow(out)
    #ax.plot(tform.inverse(src)[:, 0], tform.inverse(src)[:, 1], '.b')
    #ax.axis((0, out_cols, out_rows, 0))
    plt.rcParams ["figure.figsize"] = (5,5)
    
    plt.axis('off')
    plt.imshow(out)
    
    plt.savefig(nombre, bbox_inches='tight',pad_inches = 0, dpi=56.5)

# %%
# for i in range(250, 450):
#     ruta1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst/' + str(i) + '.png'
#     ruta2 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/1.png'
    
#     ruta3 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_lens/' + str(i) + '.png'
#     ruta4 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_lens/_' + str(i) + '.png'
    
#     image = cv2.imread(ruta1)
#     image1 =  seno_imagen1(image, 110, 4.7, ruta2)

#     image2 = cv2.imread(ruta2)
#     image1 = cv2.imread(ruta1)
    
#     dst = cv2.addWeighted(image1, 0.99, image2, 0.99, 0)
    
#     plt.imshow(dst)
#     plt.rcParams ["figure.figsize"] = (5,5)
#     plt.savefig(ruta3, bbox_inches='tight',pad_inches = 0, dpi=56.5)
#     plt.imshow(image2)
#     plt.savefig(ruta4, bbox_inches='tight',pad_inches = 0, dpi=56.5)
#     #plt.show()

# %%
images, labels = galaxy10.load_data()
# Out:
# /home/luiscantero/.astroNN/datasets/Galaxy10.h5 was found!

# %%
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2)

features = ['Disk, Face-on, No Spiral', 'Smooth, Completely round', 'Smooth, in-between round', 'Smooth, Cigar shaped', 'Disk, Edge-on, Rounded Bulge', 'Disk, Edge-on, Boxy Bulge', 
            'Disk, Edge-on, No Bulge','Disk, Face-on, Tight Spiral', 'Disk, Face-on, Medium Spiral', 'Disk, Face-on, Loose Spiral']

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((17428, 69, 69, 3), (4357, 69, 69, 3), (17428,), (4357,))

# %%
# guardar los datos de entrenamiento
# for i in range(0, 400): #len(x_train)//2):
#     plt.axis('off')
#     plt.rcParams ["figure.figsize"] = (10,10)
#     plt.imshow(x_train[i])
#     name = str(features[y_train[i]])
#     images = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies/' + str(i) + '_' + name + '.png'
#     plt.savefig(images, bbox_inches='tight',pad_inches = 0, dpi=28.3)
    
#     lentes 
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_A_' + name + '.png'
#     lente_imagen(x_train[i], 60, 8, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_B_' + name + '.png'
#     lente_imagen(x_train[i], 40, 8, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_C_' + name + '.png'
#     lente_imagen(x_train[i], 20, 8, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_D_' + name + '.png'
#     lente_imagen(x_train[i], 60, 10, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_E_' + name + '.png'
#     lente_imagen(x_train[i], 40, 10, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(i) + '_F_' + name + '.png'
#     lente_imagen(x_train[i], 20, 10, nombre1)    
    
#     plt.show()

# %%
# guardar los datos de prueba
# for i in range(0, 250): #len(x_test)//2):
#     plt.axis('off')
#     plt.imshow(x_test[i])
#     name = str(features[y_test[i]])
#     images = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies/' + str(i) + '_' + name + '.png'
#     plt.savefig(images, bbox_inches='tight',pad_inches = 0, dpi=56.4)
    
#     #lentes 
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_A_' + name + '.png'
#     lente_imagen(x_test[i], 55, 7, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_B_' + name + '.png'
#     lente_imagen(x_test[i], 35, 7, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_C_' + name + '.png'
#     lente_imagen(x_test[i], 15, 7, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_D_' + name + '.png'
#     lente_imagen(x_test[i], 55, 11, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_E_' + name + '.png'
#     lente_imagen(x_test[i], 35, 11, nombre1)
#     nombre1 = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(i) + '_F_' + name + '.png'
#     lente_imagen(x_test[i], 15, 11, nombre1)       
    
    #plt.show()

# %%
# Crear un solo arreglo de todas las imagenes dentro de las carpetas TRAIN
image1 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies/0_Smooth, in-between round.png')
image2 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies/100_Smooth, Completely round.png')

train_set_x_orig_2 = np.append(image1 , image1)
train_set_x_orig_2.shape

basepath = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies/'

i = 0
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            if(i > 1):
                name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies/' + str(entry.name)
                image1 = cv2.imread(name)
                imaget = train_set_x_orig_2
                train_set_x_orig_2 = np.append(imaget , image1)
        i = i+1
        
basepath2 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst/'
        
with os.scandir(basepath2) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)  
            
basepath3 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_2/'
        
with os.scandir(basepath3) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_2/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)              

            
basepath4 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/'
        
with os.scandir(basepath4) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)
            
basepath5 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_lens/'
        
with os.scandir(basepath5) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/train_galaxies_lsst_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)            
      

p2 = train_set_x_orig_2.shape[0]/(217*217*3) 
r2 = int(p2)
plt.imshow(train_set_x_orig_2.reshape(r2, 217, 217, 3)[0])
# Out:
# 0_Smooth, in-between round.png
# 100_Smooth, Completely round.png
# 101_Smooth, Completely round.png
# 102_Smooth, Cigar shaped.png
# 103_Smooth, Completely round.png
# 104_Disk, Face-on, Loose Spiral.png
# 105_Smooth, Completely round.png
# 106_Disk, Face-on, No Spiral.png
# 107_Smooth, Completely round.png
# 108_Smooth, in-between round.png
# 109_Smooth, in-between round.png
# 10_Disk, Face-on, No Spiral.png
# 110_Smooth, Completely round.png
# 111_Smooth, in-between round.png
# 112_Smooth, Completely round.png
# 113_Disk, Face-on, Medium Spiral.png
# 114_Smooth, Completely round.png
# 115_Disk, Face-on, No Spiral.png
# 116_Smooth, in-between round.png
# 117_Smooth, in-between round.png
# 118_Smooth, in-between round.png
# 119_Disk, Edge-on, Rounded Bulge.png
# 11_Disk, Face-on, No Spiral.png
# 120_Smooth, in-between round.png
# 121_Smooth, Completely round.png
# 122_Disk, Edge-on, No Bulge.png
# 123_Smooth, Completely round.png
# 124_Disk, Face-on, No Spiral.png
# 125_Disk, Edge-on, No Bulge.png
# 126_Disk, Face-on, Loose Spiral.png
# 127_Disk, Edge-on, Rounded Bulge.png
# 128_Smooth, Cigar shaped.png
# 129_Disk, Edge-on, Rounded Bulge.png
# 12_Smooth, in-between round.png
# 130_Disk, Face-on, No Spiral.png
# 131_Disk, Face-on, No Spiral.png
# 132_Disk, Face-on, Medium Spiral.png
# 133_Disk, Face-on, Tight Spiral.png
# 134_Smooth, in-between round.png
# 135_Smooth, Completely round.png
# 136_Smooth, in-between round.png
# 137_Smooth, in-between round.png
# 138_Disk, Face-on, Medium Spiral.png
# 139_Smooth, Completely round.png
# 13_Smooth, in-between round.png
# 140_Smooth, Completely round.png
# 141_Smooth, in-between round.png
# 142_Smooth, Completely round.png
# 143_Smooth, Cigar shaped.png
# 144_Smooth, in-between round.png
# 145_Smooth, in-between round.png
# 146_Smooth, in-between round.png
# 147_Disk, Face-on, Tight Spiral.png
# 148_Smooth, in-between round.png
# 149_Smooth, Completely round.png
# 14_Disk, Face-on, Tight Spiral.png
# 150_Disk, Edge-on, No Bulge.png
# 151_Smooth, in-between round.png
# 152_Smooth, Completely round.png
# 153_Smooth, in-between round.png
# 154_Smooth, in-between round.png
# 155_Smooth, in-between round.png
# 156_Smooth, Completely round.png
# 157_Smooth, Completely round.png
# 158_Smooth, in-between round.png
# 159_Smooth, Completely round.png
# 15_Smooth, in-between round.png
# 160_Smooth, in-between round.png
# 161_Smooth, in-between round.png
# 162_Smooth, in-between round.png
# 163_Disk, Face-on, Tight Spiral.png
# 164_Smooth, in-between round.png
# 165_Smooth, in-between round.png
# 166_Smooth, Completely round.png
# 167_Smooth, in-between round.png
# 168_Disk, Face-on, No Spiral.png
# 169_Disk, Face-on, No Spiral.png
# 16_Smooth, Completely round.png
# 170_Disk, Face-on, No Spiral.png
# 171_Smooth, in-between round.png
# 172_Disk, Edge-on, Rounded Bulge.png
# 173_Disk, Face-on, No Spiral.png
# 174_Disk, Face-on, No Spiral.png
# 175_Disk, Face-on, No Spiral.png
# 176_Smooth, Completely round.png
# 177_Smooth, in-between round.png
# 178_Smooth, Completely round.png
# 179_Disk, Face-on, No Spiral.png
# 17_Disk, Edge-on, Rounded Bulge.png
# 180_Disk, Face-on, No Spiral.png
# 181_Disk, Face-on, No Spiral.png
# 182_Disk, Face-on, No Spiral.png
# 183_Smooth, in-between round.png
# 184_Smooth, Completely round.png
# 185_Smooth, in-between round.png
# 186_Disk, Face-on, Loose Spiral.png
# 187_Smooth, Completely round.png
# 188_Smooth, Completely round.png
# 189_Smooth, in-between round.png
# 18_Disk, Face-on, No Spiral.png
# 190_Disk, Face-on, Tight Spiral.png
# 191_Smooth, Completely round.png
# 192_Smooth, Completely round.png
# 193_Smooth, in-between round.png
# 194_Smooth, Completely round.png
# 195_Disk, Face-on, No Spiral.png
# 196_Smooth, in-between round.png
# 197_Smooth, in-between round.png
# 198_Disk, Edge-on, Rounded Bulge.png
# 199_Smooth, Completely round.png
# 19_Disk, Face-on, Medium Spiral.png
# 1_Disk, Face-on, No Spiral.png
# 200_Smooth, in-between round.png
# 201_Smooth, Completely round.png
# 202_Smooth, Completely round.png
# 203_Smooth, in-between round.png
# 204_Disk, Face-on, Tight Spiral.png
# 205_Smooth, in-between round.png
# 206_Smooth, in-between round.png
# 207_Smooth, Completely round.png
# 208_Disk, Face-on, Tight Spiral.png
# 209_Disk, Face-on, Loose Spiral.png
# 20_Smooth, Completely round.png
# 210_Smooth, Completely round.png
# 211_Smooth, Completely round.png
# 212_Disk, Face-on, No Spiral.png
# 213_Smooth, in-between round.png
# 214_Smooth, in-between round.png
# 215_Smooth, Completely round.png
# 216_Smooth, Completely round.png
# 217_Disk, Edge-on, No Bulge.png
# 218_Disk, Face-on, Loose Spiral.png
# 219_Disk, Edge-on, Rounded Bulge.png
# 21_Disk, Face-on, No Spiral.png
# 220_Smooth, in-between round.png
# 221_Disk, Edge-on, No Bulge.png
# 222_Smooth, Completely round.png
# 223_Smooth, Completely round.png
# 224_Smooth, Completely round.png
# 225_Smooth, Cigar shaped.png
# 226_Smooth, in-between round.png
# 227_Smooth, Completely round.png
# 228_Smooth, in-between round.png
# 229_Smooth, Completely round.png
# 22_Smooth, Completely round.png
# 230_Disk, Edge-on, Rounded Bulge.png
# 231_Smooth, in-between round.png
# 232_Disk, Face-on, Tight Spiral.png
# 233_Disk, Face-on, Medium Spiral.png
# 234_Disk, Face-on, No Spiral.png
# 235_Disk, Face-on, No Spiral.png
# 236_Smooth, in-between round.png
# 237_Smooth, in-between round.png
# 238_Disk, Face-on, No Spiral.png
# 239_Smooth, in-between round.png
# 23_Disk, Face-on, No Spiral.png
# 240_Disk, Face-on, Tight Spiral.png
# 241_Smooth, Completely round.png
# 242_Smooth, Completely round.png
# 243_Smooth, in-between round.png
# 244_Disk, Face-on, No Spiral.png
# 245_Smooth, Completely round.png
# 246_Smooth, Cigar shaped.png
# 247_Disk, Edge-on, Rounded Bulge.png
# 248_Smooth, in-between round.png
# 249_Smooth, in-between round.png
# 24_Disk, Edge-on, No Bulge.png
# 250_Smooth, in-between round.png
# 251_Smooth, Completely round.png
# 252_Disk, Face-on, No Spiral.png
# 253_Disk, Face-on, No Spiral.png
# 254_Smooth, Completely round.png
# 255_Smooth, Completely round.png
# 256_Disk, Edge-on, Rounded Bulge.png
# 257_Smooth, in-between round.png
# 258_Smooth, Completely round.png
# 259_Disk, Face-on, Loose Spiral.png
# 25_Smooth, Completely round.png
# 260_Smooth, Completely round.png
# 261_Smooth, Completely round.png
# 262_Smooth, in-between round.png
# 263_Smooth, in-between round.png
# 264_Disk, Face-on, Medium Spiral.png
# 265_Smooth, in-between round.png
# 266_Smooth, in-between round.png
# 267_Disk, Face-on, No Spiral.png
# 268_Smooth, Cigar shaped.png
# 269_Smooth, Cigar shaped.png
# 26_Smooth, Completely round.png
# 270_Smooth, Completely round.png
# 271_Smooth, Completely round.png
# 272_Smooth, in-between round.png
# 273_Smooth, in-between round.png
# 274_Smooth, Completely round.png
# 275_Disk, Edge-on, No Bulge.png
# 276_Disk, Face-on, Loose Spiral.png
# 277_Smooth, Completely round.png
# 278_Disk, Face-on, No Spiral.png
# 279_Smooth, Completely round.png
# 27_Smooth, in-between round.png
# 280_Smooth, in-between round.png
# 281_Smooth, Completely round.png
# 282_Disk, Face-on, No Spiral.png
# 283_Disk, Face-on, Tight Spiral.png
# 284_Smooth, in-between round.png
# 285_Smooth, in-between round.png
# 286_Smooth, Completely round.png
# 287_Disk, Face-on, Loose Spiral.png
# 288_Disk, Edge-on, Rounded Bulge.png
# 289_Smooth, Completely round.png
# 28_Disk, Face-on, No Spiral.png
# 290_Smooth, Completely round.png
# 291_Smooth, in-between round.png
# 292_Disk, Edge-on, No Bulge.png
# 293_Smooth, Completely round.png
# 294_Smooth, in-between round.png
# 295_Smooth, in-between round.png
# 296_Smooth, in-between round.png
# 297_Smooth, Completely round.png
# 298_Disk, Face-on, No Spiral.png
# 299_Disk, Face-on, Medium Spiral.png
# 29_Smooth, in-between round.png
# 2_Smooth, in-between round.png
# 300_Smooth, in-between round.png
# 301_Smooth, Completely round.png
# 302_Smooth, Completely round.png
# 303_Smooth, Completely round.png
# 304_Smooth, in-between round.png
# 305_Smooth, in-between round.png
# 306_Smooth, Completely round.png
# 307_Smooth, Completely round.png
# 308_Smooth, Completely round.png
# 309_Smooth, in-between round.png
# 30_Smooth, in-between round.png
# 310_Smooth, Completely round.png
# 311_Smooth, in-between round.png
# 312_Disk, Face-on, Tight Spiral.png
# 313_Disk, Face-on, No Spiral.png
# 314_Smooth, in-between round.png
# 315_Smooth, in-between round.png
# 316_Smooth, in-between round.png
# 317_Disk, Edge-on, Rounded Bulge.png
# 318_Smooth, Completely round.png
# 319_Smooth, Completely round.png
# 31_Disk, Face-on, Tight Spiral.png
# 320_Smooth, in-between round.png
# 321_Smooth, in-between round.png
# 322_Smooth, in-between round.png
# 323_Smooth, Completely round.png
# 324_Disk, Face-on, Tight Spiral.png
# 325_Smooth, in-between round.png
# 326_Smooth, in-between round.png
# 327_Disk, Edge-on, Rounded Bulge.png
# 328_Smooth, Completely round.png
# 329_Disk, Edge-on, No Bulge.png
# 32_Disk, Edge-on, Rounded Bulge.png
# 330_Smooth, Completely round.png
# 331_Smooth, in-between round.png
# 332_Smooth, in-between round.png
# 333_Smooth, Completely round.png
# 334_Smooth, in-between round.png
# 335_Smooth, in-between round.png
# 336_Smooth, in-between round.png
# 337_Smooth, Completely round.png
# 338_Smooth, in-between round.png
# 339_Smooth, Completely round.png
# 33_Disk, Face-on, No Spiral.png
# 340_Smooth, Completely round.png
# 341_Disk, Face-on, No Spiral.png
# 342_Smooth, in-between round.png
# 343_Smooth, Completely round.png
# 344_Disk, Face-on, No Spiral.png
# 345_Disk, Edge-on, No Bulge.png
# 346_Smooth, in-between round.png
# 347_Disk, Edge-on, Rounded Bulge.png
# 348_Smooth, Completely round.png
# 349_Disk, Edge-on, Rounded Bulge.png
# 34_Smooth, in-between round.png
# 350_Disk, Edge-on, Rounded Bulge.png
# 351_Disk, Face-on, Loose Spiral.png
# 352_Smooth, Completely round.png
# 353_Smooth, Completely round.png
# 354_Smooth, in-between round.png
# 355_Disk, Face-on, Tight Spiral.png
# 356_Smooth, Completely round.png
# 357_Smooth, Completely round.png
# 358_Smooth, Completely round.png
# 359_Disk, Face-on, Medium Spiral.png
# 35_Smooth, Completely round.png
# 360_Disk, Face-on, Medium Spiral.png
# 361_Smooth, Completely round.png
# 362_Smooth, Completely round.png
# 363_Smooth, Completely round.png
# 364_Disk, Face-on, Medium Spiral.png
# 365_Smooth, Completely round.png
# 366_Smooth, in-between round.png
# 367_Smooth, in-between round.png
# 368_Smooth, in-between round.png
# 369_Disk, Edge-on, Rounded Bulge.png
# 36_Smooth, Completely round.png
# 370_Smooth, Completely round.png
# 371_Smooth, Completely round.png
# 372_Disk, Face-on, Tight Spiral.png
# 373_Disk, Edge-on, Rounded Bulge.png
# 374_Smooth, in-between round.png
# 375_Smooth, in-between round.png
# 376_Smooth, Completely round.png
# 377_Smooth, in-between round.png
# 378_Smooth, in-between round.png
# 379_Smooth, in-between round.png
# 37_Disk, Face-on, No Spiral.png
# 380_Disk, Face-on, No Spiral.png
# 381_Disk, Edge-on, No Bulge.png
# 382_Disk, Face-on, No Spiral.png
# 383_Smooth, Completely round.png
# 384_Smooth, Completely round.png
# 385_Disk, Face-on, No Spiral.png
# 386_Smooth, in-between round.png
# 387_Smooth, Completely round.png
# 388_Disk, Face-on, Tight Spiral.png
# 389_Disk, Edge-on, No Bulge.png
# 38_Smooth, in-between round.png
# 390_Smooth, in-between round.png
# 391_Disk, Face-on, No Spiral.png
# 392_Disk, Face-on, No Spiral.png
# 393_Disk, Face-on, No Spiral.png
# 394_Disk, Face-on, Loose Spiral.png
# 395_Smooth, in-between round.png
# 396_Disk, Edge-on, Rounded Bulge.png
# 397_Smooth, in-between round.png
# 398_Smooth, in-between round.png
# 399_Disk, Face-on, Tight Spiral.png
# 39_Smooth, Completely round.png
# 3_Smooth, Completely round.png
# 40_Disk, Face-on, No Spiral.png
# 41_Smooth, Cigar shaped.png
# 42_Smooth, in-between round.png
# 43_Smooth, Completely round.png
# 44_Disk, Face-on, Loose Spiral.png
# 45_Smooth, in-between round.png
# 46_Smooth, Completely round.png
# 47_Smooth, Completely round.png
# 48_Smooth, Completely round.png
# 49_Smooth, Completely round.png
# 4_Disk, Edge-on, No Bulge.png
# 50_Smooth, Completely round.png
# 51_Smooth, in-between round.png
# 52_Smooth, in-between round.png
# 53_Smooth, in-between round.png
# 54_Smooth, in-between round.png
# 55_Disk, Face-on, No Spiral.png
# 56_Smooth, in-between round.png
# 57_Smooth, Completely round.png
# 58_Disk, Edge-on, Rounded Bulge.png
# 59_Smooth, Completely round.png
# 5_Smooth, in-between round.png
# 60_Smooth, Completely round.png
# 61_Smooth, in-between round.png
# 62_Smooth, Completely round.png
# 63_Smooth, in-between round.png
# 64_Disk, Face-on, No Spiral.png
# 65_Smooth, Completely round.png
# 66_Smooth, Completely round.png
# 67_Disk, Face-on, No Spiral.png
# 68_Disk, Face-on, No Spiral.png
# 69_Smooth, Completely round.png
# 6_Disk, Face-on, Medium Spiral.png
# 70_Smooth, in-between round.png
# 71_Smooth, in-between round.png
# 72_Smooth, in-between round.png
# 73_Disk, Face-on, Tight Spiral.png
# 74_Smooth, in-between round.png
# 75_Disk, Edge-on, Rounded Bulge.png
# 76_Smooth, Completely round.png
# 77_Disk, Face-on, Loose Spiral.png
# 78_Disk, Edge-on, Rounded Bulge.png
# 79_Smooth, Completely round.png
# 7_Disk, Edge-on, No Bulge.png
# 80_Smooth, in-between round.png
# 81_Disk, Edge-on, Rounded Bulge.png
# 82_Smooth, Completely round.png
# 83_Smooth, in-between round.png
# 84_Disk, Face-on, Loose Spiral.png
# 85_Disk, Face-on, Tight Spiral.png
# 86_Smooth, Cigar shaped.png
# 87_Smooth, in-between round.png
# 88_Smooth, Completely round.png
# 89_Smooth, in-between round.png
# 8_Smooth, Completely round.png
# 90_Disk, Edge-on, No Bulge.png
# 91_Smooth, Completely round.png
# 92_Smooth, Completely round.png
# 93_Disk, Face-on, No Spiral.png
# 94_Disk, Face-on, No Spiral.png
# 95_Smooth, Completely round.png
# 96_Disk, Face-on, Medium Spiral.png
# 97_Disk, Face-on, No Spiral.png
# 98_Smooth, Completely round.png
# 99_Smooth, Completely round.png
# 9_Disk, Face-on, No Spiral.png
# 250.png
# 251.png
# 252.png
# 253.png
# 254.png
# 255.png
# 256.png
# 257.png
# 258.png
# 259.png
# 260.png
# 261.png
# 262.png
# 263.png
# 264.png
# 265.png
# 266.png
# 267.png
# 268.png
# 269.png
# 270.png
# 271.png
# 272.png
# 273.png
# 274.png
# 275.png
# 276.png
# 277.png
# 278.png
# 279.png
# 280.png
# 281.png
# 282.png
# 283.png
# 284.png
# 285.png
# 286.png
# 287.png
# 288.png
# 289.png
# 290.png
# 291.png
# 292.png
# 293.png
# 294.png
# 295.png
# 296.png
# 297.png
# 298.png
# 299.png
# 300.png
# 301.png
# 302.png
# 303.png
# 304.png
# 305.png
# 306.png
# 307.png
# 308.png
# 309.png
# 310.png
# 311.png
# 312.png
# 313.png
# 314.png
# 315.png
# 316.png
# 317.png
# 318.png
# 319.png
# 320.png
# 321.png
# 322.png
# 323.png
# 324.png
# 325.png
# 326.png
# 327.png
# 328.png
# 329.png
# 330.png
# 331.png
# 332.png
# 333.png
# 334.png
# 335.png
# 336.png
# 337.png
# 338.png
# 339.png
# 340.png
# 341.png
# 342.png
# 343.png
# 344.png
# 345.png
# 346.png
# 347.png
# 348.png
# 349.png
# 350.png
# 351.png
# 352.png
# 353.png
# 354.png
# 355.png
# 356.png
# 357.png
# 358.png
# 359.png
# 360.png
# 361.png
# 362.png
# 363.png
# 364.png
# 365.png
# 366.png
# 367.png
# 368.png
# 369.png
# 370.png
# 371.png
# 372.png
# 373.png
# 374.png
# 375.png
# 376.png
# 377.png
# 378.png
# 379.png
# 380.png
# 381.png
# 382.png
# 383.png
# 384.png
# 385.png
# 386.png
# 387.png
# 388.png
# 389.png
# 390.png
# 391.png
# 392.png
# 393.png
# 394.png
# 395.png
# 396.png
# 397.png
# 398.png
# 399.png
# 400.png
# 401.png
# 402.png
# 403.png
# 404.png
# 405.png
# 406.png
# 407.png
# 408.png
# 409.png
# 410.png
# 411.png
# 412.png
# 413.png
# 414.png
# 415.png
# 416.png
# 417.png
# 418.png
# 419.png
# 420.png
# 421.png
# 422.png
# 423.png
# 424.png
# 425.png
# 426.png
# 427.png
# 428.png
# 429.png
# 430.png
# 431.png
# 432.png
# 433.png
# 434.png
# 435.png
# 436.png
# 437.png
# 438.png
# 439.png
# 440.png
# 441.png
# 442.png
# 443.png
# 444.png
# 445.png
# 446.png
# 447.png
# 448.png
# 449.png
# 1000.png
# 1001.png
# 1002.png
# 1003.png
# 1004.png
# 1005.png
# 1006.png
# 1007.png
# 1008.png
# 1009.png
# 1010.png
# 1011.png
# 1012.png
# 1013.png
# 1014.png
# 1015.png
# 1016.png
# 1017.png
# 1018.png
# 1019.png
# 1020.png
# 1021.png
# 1022.png
# 1023.png
# 1024.png
# 1025.png
# 1026.png
# 1027.png
# 1028.png
# 1029.png
# 1030.png
# 1031.png
# 1032.png
# 1033.png
# 1034.png
# 1035.png
# 1036.png
# 1037.png
# 1038.png
# 1039.png
# 1040.png
# 1041.png
# 1042.png
# 1043.png
# 1044.png
# 1045.png
# 1046.png
# 1047.png
# 1048.png
# 1049.png
# 1050.png
# 1051.png
# 1052.png
# 1053.png
# 1054.png
# 1055.png
# 1056.png
# 1057.png
# 1058.png
# 1059.png
# 1060.png
# 1061.png
# 1062.png
# 1063.png
# 1064.png
# 1065.png
# 1066.png
# 1067.png
# 1068.png
# 1069.png
# 1070.png
# 1071.png
# 1072.png
# 1073.png
# 1074.png
# 1075.png
# 1076.png
# 1077.png
# 1078.png
# 1079.png
# 1080.png
# 1081.png
# 1082.png
# 1083.png
# 1084.png
# 1085.png
# 1086.png
# 1087.png
# 1088.png
# 1089.png
# 1090.png
# 1091.png
# 1092.png
# 1093.png
# 1094.png
# 1095.png
# 1096.png
# 1097.png
# 1098.png
# 1099.png
# 0_A_Smooth, Completely round.png
# 0_B_Smooth, Completely round.png
# 0_C_Smooth, Completely round.png
# 0_D_Smooth, Completely round.png
# 0_E_Smooth, Completely round.png
# 0_F_Smooth, Completely round.png
# 100_A_Smooth, Completely round.png
# 100_B_Smooth, Completely round.png
# 100_C_Smooth, Completely round.png
# 100_D_Smooth, Completely round.png
# 100_E_Smooth, Completely round.png
# 100_F_Smooth, Completely round.png
# 101_A_Smooth, in-between round.png
# 101_B_Smooth, in-between round.png
# 101_C_Smooth, in-between round.png
# 101_D_Smooth, in-between round.png
# 101_E_Smooth, in-between round.png
# 101_F_Smooth, in-between round.png
# 102_A_Disk, Face-on, Medium Spiral.png
# 102_B_Disk, Face-on, Medium Spiral.png
# 102_C_Disk, Face-on, Medium Spiral.png
# 102_D_Disk, Face-on, Medium Spiral.png
# 102_E_Disk, Face-on, Medium Spiral.png
# 102_F_Disk, Face-on, Medium Spiral.png
# 103_A_Disk, Face-on, No Spiral.png
# 103_B_Disk, Face-on, No Spiral.png
# 103_C_Disk, Face-on, No Spiral.png
# 103_D_Disk, Face-on, No Spiral.png
# 103_E_Disk, Face-on, No Spiral.png
# 103_F_Disk, Face-on, No Spiral.png
# 104_A_Smooth, Completely round.png
# 104_B_Smooth, Completely round.png
# 104_C_Smooth, Completely round.png
# 104_D_Smooth, Completely round.png
# 104_E_Smooth, Completely round.png
# 104_F_Smooth, Completely round.png
# 105_A_Smooth, in-between round.png
# 105_B_Smooth, in-between round.png
# 105_C_Smooth, in-between round.png
# 105_D_Smooth, in-between round.png
# 105_E_Smooth, in-between round.png
# 105_F_Smooth, in-between round.png
# 106_A_Disk, Face-on, Tight Spiral.png
# 106_B_Disk, Face-on, Tight Spiral.png
# 106_C_Disk, Face-on, Tight Spiral.png
# 106_D_Disk, Face-on, Tight Spiral.png
# 106_E_Disk, Face-on, Tight Spiral.png
# 106_F_Disk, Face-on, Tight Spiral.png
# 107_A_Smooth, Completely round.png
# 107_B_Smooth, Completely round.png
# 107_C_Smooth, Completely round.png
# 107_D_Smooth, Completely round.png
# 107_E_Smooth, Completely round.png
# 107_F_Smooth, Completely round.png
# 108_A_Disk, Face-on, No Spiral.png
# 108_B_Disk, Face-on, No Spiral.png
# 108_C_Disk, Face-on, No Spiral.png
# 108_D_Disk, Face-on, No Spiral.png
# 108_E_Disk, Face-on, No Spiral.png
# 108_F_Disk, Face-on, No Spiral.png
# 109_A_Disk, Edge-on, Rounded Bulge.png
# 109_B_Disk, Edge-on, Rounded Bulge.png
# 109_C_Disk, Edge-on, Rounded Bulge.png
# 109_D_Disk, Edge-on, Rounded Bulge.png
# 109_E_Disk, Edge-on, Rounded Bulge.png
# 109_F_Disk, Edge-on, Rounded Bulge.png
# 10_A_Disk, Edge-on, Rounded Bulge.png
# 10_B_Disk, Edge-on, Rounded Bulge.png
# 10_C_Disk, Edge-on, Rounded Bulge.png
# 10_D_Disk, Edge-on, Rounded Bulge.png
# 10_E_Disk, Edge-on, Rounded Bulge.png
# 10_F_Disk, Edge-on, Rounded Bulge.png
# 110_A_Disk, Face-on, Tight Spiral.png
# 110_B_Disk, Face-on, Tight Spiral.png
# 110_C_Disk, Face-on, Tight Spiral.png
# 110_D_Disk, Face-on, Tight Spiral.png
# 110_E_Disk, Face-on, Tight Spiral.png
# 110_F_Disk, Face-on, Tight Spiral.png
# 111_A_Disk, Face-on, No Spiral.png
# 111_B_Disk, Face-on, No Spiral.png
# 111_C_Disk, Face-on, No Spiral.png
# 111_D_Disk, Face-on, No Spiral.png
# 111_E_Disk, Face-on, No Spiral.png
# 111_F_Disk, Face-on, No Spiral.png
# 112_A_Smooth, in-between round.png
# 112_B_Smooth, in-between round.png
# 112_C_Smooth, in-between round.png
# 112_D_Smooth, in-between round.png
# 112_E_Smooth, in-between round.png
# 112_F_Smooth, in-between round.png
# 113_A_Smooth, Completely round.png
# 113_B_Smooth, Completely round.png
# 113_C_Smooth, Completely round.png
# 113_D_Smooth, Completely round.png
# 113_E_Smooth, Completely round.png
# 113_F_Smooth, Completely round.png
# 114_A_Smooth, in-between round.png
# 114_B_Smooth, in-between round.png
# 114_C_Smooth, in-between round.png
# 114_D_Smooth, in-between round.png
# 114_E_Smooth, in-between round.png
# 114_F_Smooth, in-between round.png
# 115_A_Smooth, in-between round.png
# 115_B_Smooth, in-between round.png
# 115_C_Smooth, in-between round.png
# 115_D_Smooth, in-between round.png
# 115_E_Smooth, in-between round.png
# 115_F_Smooth, in-between round.png
# 116_A_Disk, Edge-on, Rounded Bulge.png
# 116_B_Disk, Edge-on, Rounded Bulge.png
# 116_C_Disk, Edge-on, Rounded Bulge.png
# 116_D_Disk, Edge-on, Rounded Bulge.png
# 116_E_Disk, Edge-on, Rounded Bulge.png
# 116_F_Disk, Edge-on, Rounded Bulge.png
# 117_A_Disk, Face-on, Tight Spiral.png
# 117_B_Disk, Face-on, Tight Spiral.png
# 117_C_Disk, Face-on, Tight Spiral.png
# 117_D_Disk, Face-on, Tight Spiral.png
# 117_E_Disk, Face-on, Tight Spiral.png
# 117_F_Disk, Face-on, Tight Spiral.png
# 118_A_Smooth, in-between round.png
# 118_B_Smooth, in-between round.png
# 118_C_Smooth, in-between round.png
# 118_D_Smooth, in-between round.png
# 118_E_Smooth, in-between round.png
# 118_F_Smooth, in-between round.png
# 119_A_Disk, Face-on, No Spiral.png
# 119_B_Disk, Face-on, No Spiral.png
# 119_C_Disk, Face-on, No Spiral.png
# 119_D_Disk, Face-on, No Spiral.png
# 119_E_Disk, Face-on, No Spiral.png
# 119_F_Disk, Face-on, No Spiral.png
# 11_A_Smooth, Completely round.png
# 11_B_Smooth, Completely round.png
# 11_C_Smooth, Completely round.png
# 11_D_Smooth, Completely round.png
# 11_E_Smooth, Completely round.png
# 11_F_Smooth, Completely round.png
# 120_A_Smooth, Completely round.png
# 120_B_Smooth, Completely round.png
# 120_C_Smooth, Completely round.png
# 120_D_Smooth, Completely round.png
# 120_E_Smooth, Completely round.png
# 120_F_Smooth, Completely round.png
# 121_A_Smooth, in-between round.png
# 121_B_Smooth, in-between round.png
# 121_C_Smooth, in-between round.png
# 121_D_Smooth, in-between round.png
# 121_E_Smooth, in-between round.png
# 121_F_Smooth, in-between round.png
# 122_A_Smooth, Completely round.png
# 122_B_Smooth, Completely round.png
# 122_C_Smooth, Completely round.png
# 122_D_Smooth, Completely round.png
# 122_E_Smooth, Completely round.png
# 122_F_Smooth, Completely round.png
# 123_A_Disk, Face-on, No Spiral.png
# 123_B_Disk, Face-on, No Spiral.png
# 123_C_Disk, Face-on, No Spiral.png
# 123_D_Disk, Face-on, No Spiral.png
# 123_E_Disk, Face-on, No Spiral.png
# 123_F_Disk, Face-on, No Spiral.png
# 124_A_Disk, Face-on, No Spiral.png
# 124_B_Disk, Face-on, No Spiral.png
# 124_C_Disk, Face-on, No Spiral.png
# 124_D_Disk, Face-on, No Spiral.png
# 124_E_Disk, Face-on, No Spiral.png
# 124_F_Disk, Face-on, No Spiral.png
# 125_A_Disk, Face-on, No Spiral.png
# 125_B_Disk, Face-on, No Spiral.png
# 125_C_Disk, Face-on, No Spiral.png
# 125_D_Disk, Face-on, No Spiral.png
# 125_E_Disk, Face-on, No Spiral.png
# 125_F_Disk, Face-on, No Spiral.png
# 126_A_Smooth, in-between round.png
# 126_B_Smooth, in-between round.png
# 126_C_Smooth, in-between round.png
# 126_D_Smooth, in-between round.png
# 126_E_Smooth, in-between round.png
# 126_F_Smooth, in-between round.png
# 127_A_Smooth, in-between round.png
# 127_B_Smooth, in-between round.png
# 127_C_Smooth, in-between round.png
# 127_D_Smooth, in-between round.png
# 127_E_Smooth, in-between round.png
# 127_F_Smooth, in-between round.png
# 128_A_Disk, Face-on, Loose Spiral.png
# 128_B_Disk, Face-on, Loose Spiral.png
# 128_C_Disk, Face-on, Loose Spiral.png
# 128_D_Disk, Face-on, Loose Spiral.png
# 128_E_Disk, Face-on, Loose Spiral.png
# 128_F_Disk, Face-on, Loose Spiral.png
# 129_A_Smooth, in-between round.png
# 129_B_Smooth, in-between round.png
# 129_C_Smooth, in-between round.png
# 129_D_Smooth, in-between round.png
# 129_E_Smooth, in-between round.png
# 129_F_Smooth, in-between round.png
# 12_A_Smooth, in-between round.png
# 12_B_Smooth, in-between round.png
# 12_C_Smooth, in-between round.png
# 12_D_Smooth, in-between round.png
# 12_E_Smooth, in-between round.png
# 12_F_Smooth, in-between round.png
# 130_A_Disk, Face-on, No Spiral.png
# 130_B_Disk, Face-on, No Spiral.png
# 130_C_Disk, Face-on, No Spiral.png
# 130_D_Disk, Face-on, No Spiral.png
# 130_E_Disk, Face-on, No Spiral.png
# 130_F_Disk, Face-on, No Spiral.png
# 131_A_Disk, Edge-on, No Bulge.png
# 131_B_Disk, Edge-on, No Bulge.png
# 131_C_Disk, Edge-on, No Bulge.png
# 131_D_Disk, Edge-on, No Bulge.png
# 131_E_Disk, Edge-on, No Bulge.png
# 131_F_Disk, Edge-on, No Bulge.png
# 132_A_Smooth, Completely round.png
# 132_B_Smooth, Completely round.png
# 132_C_Smooth, Completely round.png
# 132_D_Smooth, Completely round.png
# 132_E_Smooth, Completely round.png
# 132_F_Smooth, Completely round.png
# 133_A_Smooth, in-between round.png
# 133_B_Smooth, in-between round.png
# 133_C_Smooth, in-between round.png
# 133_D_Smooth, in-between round.png
# 133_E_Smooth, in-between round.png
# 133_F_Smooth, in-between round.png
# 134_A_Smooth, Completely round.png
# 134_B_Smooth, Completely round.png
# 134_C_Smooth, Completely round.png
# 134_D_Smooth, Completely round.png
# 134_E_Smooth, Completely round.png
# 134_F_Smooth, Completely round.png
# 135_A_Smooth, in-between round.png
# 135_B_Smooth, in-between round.png
# 135_C_Smooth, in-between round.png
# 135_D_Smooth, in-between round.png
# 135_E_Smooth, in-between round.png
# 135_F_Smooth, in-between round.png
# 136_A_Disk, Face-on, Tight Spiral.png
# 136_B_Disk, Face-on, Tight Spiral.png
# 136_C_Disk, Face-on, Tight Spiral.png
# 136_D_Disk, Face-on, Tight Spiral.png
# 136_E_Disk, Face-on, Tight Spiral.png
# 136_F_Disk, Face-on, Tight Spiral.png
# 137_A_Disk, Face-on, No Spiral.png
# 137_B_Disk, Face-on, No Spiral.png
# 137_C_Disk, Face-on, No Spiral.png
# 137_D_Disk, Face-on, No Spiral.png
# 137_E_Disk, Face-on, No Spiral.png
# 137_F_Disk, Face-on, No Spiral.png
# 138_A_Smooth, Completely round.png
# 138_B_Smooth, Completely round.png
# 138_C_Smooth, Completely round.png
# 138_D_Smooth, Completely round.png
# 138_E_Smooth, Completely round.png
# 138_F_Smooth, Completely round.png
# 139_A_Smooth, in-between round.png
# 139_B_Smooth, in-between round.png
# 139_C_Smooth, in-between round.png
# 139_D_Smooth, in-between round.png
# 139_E_Smooth, in-between round.png
# 139_F_Smooth, in-between round.png
# 13_A_Smooth, Completely round.png
# 13_B_Smooth, Completely round.png
# 13_C_Smooth, Completely round.png
# 13_D_Smooth, Completely round.png
# 13_E_Smooth, Completely round.png
# 13_F_Smooth, Completely round.png
# 140_A_Smooth, in-between round.png
# 140_B_Smooth, in-between round.png
# 140_C_Smooth, in-between round.png
# 140_D_Smooth, in-between round.png
# 140_E_Smooth, in-between round.png
# 140_F_Smooth, in-between round.png
# 141_A_Smooth, Completely round.png
# 141_B_Smooth, Completely round.png
# 141_C_Smooth, Completely round.png
# 141_D_Smooth, Completely round.png
# 141_E_Smooth, Completely round.png
# 141_F_Smooth, Completely round.png
# 142_A_Smooth, Completely round.png
# 142_B_Smooth, Completely round.png
# 142_C_Smooth, Completely round.png
# 142_D_Smooth, Completely round.png
# 142_E_Smooth, Completely round.png
# 142_F_Smooth, Completely round.png
# 143_A_Smooth, in-between round.png
# 143_B_Smooth, in-between round.png
# 143_C_Smooth, in-between round.png
# 143_D_Smooth, in-between round.png
# 143_E_Smooth, in-between round.png
# 143_F_Smooth, in-between round.png
# 144_A_Disk, Edge-on, No Bulge.png
# 144_B_Disk, Edge-on, No Bulge.png
# 144_C_Disk, Edge-on, No Bulge.png
# 144_D_Disk, Edge-on, No Bulge.png
# 144_E_Disk, Edge-on, No Bulge.png
# 144_F_Disk, Edge-on, No Bulge.png
# 145_A_Smooth, in-between round.png
# 145_B_Smooth, in-between round.png
# 145_C_Smooth, in-between round.png
# 145_D_Smooth, in-between round.png
# 145_E_Smooth, in-between round.png
# 145_F_Smooth, in-between round.png
# 146_A_Disk, Face-on, No Spiral.png
# 146_B_Disk, Face-on, No Spiral.png
# 146_C_Disk, Face-on, No Spiral.png
# 146_D_Disk, Face-on, No Spiral.png
# 146_E_Disk, Face-on, No Spiral.png
# 146_F_Disk, Face-on, No Spiral.png
# 147_A_Smooth, in-between round.png
# 147_B_Smooth, in-between round.png
# 147_C_Smooth, in-between round.png
# 147_D_Smooth, in-between round.png
# 147_E_Smooth, in-between round.png
# 147_F_Smooth, in-between round.png
# 148_A_Disk, Edge-on, Rounded Bulge.png
# 148_B_Disk, Edge-on, Rounded Bulge.png
# 148_C_Disk, Edge-on, Rounded Bulge.png
# 148_D_Disk, Edge-on, Rounded Bulge.png
# 148_E_Disk, Edge-on, Rounded Bulge.png
# 148_F_Disk, Edge-on, Rounded Bulge.png
# 149_A_Smooth, Completely round.png
# 149_B_Smooth, Completely round.png
# 149_C_Smooth, Completely round.png
# 149_D_Smooth, Completely round.png
# 149_E_Smooth, Completely round.png
# 149_F_Smooth, Completely round.png
# 14_A_Disk, Edge-on, Rounded Bulge.png
# 14_B_Disk, Edge-on, Rounded Bulge.png
# 14_C_Disk, Edge-on, Rounded Bulge.png
# 14_D_Disk, Edge-on, Rounded Bulge.png
# 14_E_Disk, Edge-on, Rounded Bulge.png
# 14_F_Disk, Edge-on, Rounded Bulge.png
# 150_A_Smooth, in-between round.png
# 150_B_Smooth, in-between round.png
# 150_C_Smooth, in-between round.png
# 150_D_Smooth, in-between round.png
# 150_E_Smooth, in-between round.png
# 150_F_Smooth, in-between round.png
# 151_A_Disk, Edge-on, Rounded Bulge.png
# 151_B_Disk, Edge-on, Rounded Bulge.png
# 151_C_Disk, Edge-on, Rounded Bulge.png
# 151_D_Disk, Edge-on, Rounded Bulge.png
# 151_E_Disk, Edge-on, Rounded Bulge.png
# 151_F_Disk, Edge-on, Rounded Bulge.png
# 152_A_Smooth, in-between round.png
# 152_B_Smooth, in-between round.png
# 152_C_Smooth, in-between round.png
# 152_D_Smooth, in-between round.png
# 152_E_Smooth, in-between round.png
# 152_F_Smooth, in-between round.png
# 153_A_Disk, Face-on, No Spiral.png
# 153_B_Disk, Face-on, No Spiral.png
# 153_C_Disk, Face-on, No Spiral.png
# 153_D_Disk, Face-on, No Spiral.png
# 153_E_Disk, Face-on, No Spiral.png
# 153_F_Disk, Face-on, No Spiral.png
# 154_A_Disk, Face-on, No Spiral.png
# 154_B_Disk, Face-on, No Spiral.png
# 154_C_Disk, Face-on, No Spiral.png
# 154_D_Disk, Face-on, No Spiral.png
# 154_E_Disk, Face-on, No Spiral.png
# 154_F_Disk, Face-on, No Spiral.png
# 155_A_Smooth, in-between round.png
# 155_B_Smooth, in-between round.png
# 155_C_Smooth, in-between round.png
# 155_D_Smooth, in-between round.png
# 155_E_Smooth, in-between round.png
# 155_F_Smooth, in-between round.png
# 156_A_Smooth, in-between round.png
# 156_B_Smooth, in-between round.png
# 156_C_Smooth, in-between round.png
# 156_D_Smooth, in-between round.png
# 156_E_Smooth, in-between round.png
# 156_F_Smooth, in-between round.png
# 157_A_Smooth, Completely round.png
# 157_B_Smooth, Completely round.png
# 157_C_Smooth, Completely round.png
# 157_D_Smooth, Completely round.png
# 157_E_Smooth, Completely round.png
# 157_F_Smooth, Completely round.png
# 158_A_Smooth, in-between round.png
# 158_B_Smooth, in-between round.png
# 158_C_Smooth, in-between round.png
# 158_D_Smooth, in-between round.png
# 158_E_Smooth, in-between round.png
# 158_F_Smooth, in-between round.png
# 159_A_Smooth, Completely round.png
# 159_B_Smooth, Completely round.png
# 159_C_Smooth, Completely round.png
# 159_D_Smooth, Completely round.png
# 159_E_Smooth, Completely round.png
# 159_F_Smooth, Completely round.png
# 15_A_Smooth, in-between round.png
# 15_B_Smooth, in-between round.png
# 15_C_Smooth, in-between round.png
# 15_D_Smooth, in-between round.png
# 15_E_Smooth, in-between round.png
# 15_F_Smooth, in-between round.png
# 160_A_Smooth, Completely round.png
# 160_B_Smooth, Completely round.png
# 160_C_Smooth, Completely round.png
# 160_D_Smooth, Completely round.png
# 160_E_Smooth, Completely round.png
# 160_F_Smooth, Completely round.png
# 161_A_Disk, Face-on, Medium Spiral.png
# 161_B_Disk, Face-on, Medium Spiral.png
# 161_C_Disk, Face-on, Medium Spiral.png
# 161_D_Disk, Face-on, Medium Spiral.png
# 161_E_Disk, Face-on, Medium Spiral.png
# 161_F_Disk, Face-on, Medium Spiral.png
# 162_A_Smooth, in-between round.png
# 162_B_Smooth, in-between round.png
# 162_C_Smooth, in-between round.png
# 162_D_Smooth, in-between round.png
# 162_E_Smooth, in-between round.png
# 162_F_Smooth, in-between round.png
# 163_A_Smooth, in-between round.png
# 163_B_Smooth, in-between round.png
# 163_C_Smooth, in-between round.png
# 163_D_Smooth, in-between round.png
# 163_E_Smooth, in-between round.png
# 163_F_Smooth, in-between round.png
# 164_A_Smooth, Completely round.png
# 164_B_Smooth, Completely round.png
# 164_C_Smooth, Completely round.png
# 164_D_Smooth, Completely round.png
# 164_E_Smooth, Completely round.png
# 164_F_Smooth, Completely round.png
# 165_A_Smooth, Completely round.png
# 165_B_Smooth, Completely round.png
# 165_C_Smooth, Completely round.png
# 165_D_Smooth, Completely round.png
# 165_E_Smooth, Completely round.png
# 165_F_Smooth, Completely round.png
# 166_A_Smooth, Completely round.png
# 166_B_Smooth, Completely round.png
# 166_C_Smooth, Completely round.png
# 166_D_Smooth, Completely round.png
# 166_E_Smooth, Completely round.png
# 166_F_Smooth, Completely round.png
# 167_A_Smooth, Completely round.png
# 167_B_Smooth, Completely round.png
# 167_C_Smooth, Completely round.png
# 167_D_Smooth, Completely round.png
# 167_E_Smooth, Completely round.png
# 167_F_Smooth, Completely round.png
# 168_A_Disk, Face-on, No Spiral.png
# 168_B_Disk, Face-on, No Spiral.png
# 168_C_Disk, Face-on, No Spiral.png
# 168_D_Disk, Face-on, No Spiral.png
# 168_E_Disk, Face-on, No Spiral.png
# 168_F_Disk, Face-on, No Spiral.png
# 169_A_Disk, Face-on, No Spiral.png
# 169_B_Disk, Face-on, No Spiral.png
# 169_C_Disk, Face-on, No Spiral.png
# 169_D_Disk, Face-on, No Spiral.png
# 169_E_Disk, Face-on, No Spiral.png
# 169_F_Disk, Face-on, No Spiral.png
# 16_A_Smooth, in-between round.png
# 16_B_Smooth, in-between round.png
# 16_C_Smooth, in-between round.png
# 16_D_Smooth, in-between round.png
# 16_E_Smooth, in-between round.png
# 16_F_Smooth, in-between round.png
# 170_A_Disk, Edge-on, Rounded Bulge.png
# 170_B_Disk, Edge-on, Rounded Bulge.png
# 170_C_Disk, Edge-on, Rounded Bulge.png
# 170_D_Disk, Edge-on, Rounded Bulge.png
# 170_E_Disk, Edge-on, Rounded Bulge.png
# 170_F_Disk, Edge-on, Rounded Bulge.png
# 171_A_Disk, Face-on, Medium Spiral.png
# 171_B_Disk, Face-on, Medium Spiral.png
# 171_C_Disk, Face-on, Medium Spiral.png
# 171_D_Disk, Face-on, Medium Spiral.png
# 171_E_Disk, Face-on, Medium Spiral.png
# 171_F_Disk, Face-on, Medium Spiral.png
# 172_A_Smooth, Completely round.png
# 172_B_Smooth, Completely round.png
# 172_C_Smooth, Completely round.png
# 172_D_Smooth, Completely round.png
# 172_E_Smooth, Completely round.png
# 172_F_Smooth, Completely round.png
# 173_A_Smooth, in-between round.png
# 173_B_Smooth, in-between round.png
# 173_C_Smooth, in-between round.png
# 173_D_Smooth, in-between round.png
# 173_E_Smooth, in-between round.png
# 173_F_Smooth, in-between round.png
# 174_A_Disk, Face-on, Medium Spiral.png
# 174_B_Disk, Face-on, Medium Spiral.png
# 174_C_Disk, Face-on, Medium Spiral.png
# 174_D_Disk, Face-on, Medium Spiral.png
# 174_E_Disk, Face-on, Medium Spiral.png
# 174_F_Disk, Face-on, Medium Spiral.png
# 175_A_Disk, Face-on, Loose Spiral.png
# 175_B_Disk, Face-on, Loose Spiral.png
# 175_C_Disk, Face-on, Loose Spiral.png
# 175_D_Disk, Face-on, Loose Spiral.png
# 175_E_Disk, Face-on, Loose Spiral.png
# 175_F_Disk, Face-on, Loose Spiral.png
# 176_A_Disk, Face-on, No Spiral.png
# 176_B_Disk, Face-on, No Spiral.png
# 176_C_Disk, Face-on, No Spiral.png
# 176_D_Disk, Face-on, No Spiral.png
# 176_E_Disk, Face-on, No Spiral.png
# 176_F_Disk, Face-on, No Spiral.png
# 177_A_Disk, Face-on, Tight Spiral.png
# 177_B_Disk, Face-on, Tight Spiral.png
# 177_C_Disk, Face-on, Tight Spiral.png
# 177_D_Disk, Face-on, Tight Spiral.png
# 177_E_Disk, Face-on, Tight Spiral.png
# 177_F_Disk, Face-on, Tight Spiral.png
# 178_A_Disk, Face-on, Tight Spiral.png
# 178_B_Disk, Face-on, Tight Spiral.png
# 178_C_Disk, Face-on, Tight Spiral.png
# 178_D_Disk, Face-on, Tight Spiral.png
# 178_E_Disk, Face-on, Tight Spiral.png
# 178_F_Disk, Face-on, Tight Spiral.png
# 179_A_Smooth, Completely round.png
# 179_B_Smooth, Completely round.png
# 179_C_Smooth, Completely round.png
# 179_D_Smooth, Completely round.png
# 179_E_Smooth, Completely round.png
# 179_F_Smooth, Completely round.png
# 17_A_Disk, Face-on, No Spiral.png
# 17_B_Disk, Face-on, No Spiral.png
# 17_C_Disk, Face-on, No Spiral.png
# 17_D_Disk, Face-on, No Spiral.png
# 17_E_Disk, Face-on, No Spiral.png
# 17_F_Disk, Face-on, No Spiral.png
# 180_A_Disk, Face-on, Loose Spiral.png
# 180_B_Disk, Face-on, Loose Spiral.png
# 180_C_Disk, Face-on, Loose Spiral.png
# 180_D_Disk, Face-on, Loose Spiral.png
# 180_E_Disk, Face-on, Loose Spiral.png
# 180_F_Disk, Face-on, Loose Spiral.png
# 181_A_Disk, Face-on, Tight Spiral.png
# 181_B_Disk, Face-on, Tight Spiral.png
# 181_C_Disk, Face-on, Tight Spiral.png
# 181_D_Disk, Face-on, Tight Spiral.png
# 181_E_Disk, Face-on, Tight Spiral.png
# 181_F_Disk, Face-on, Tight Spiral.png
# 182_A_Smooth, Completely round.png
# 182_B_Smooth, Completely round.png
# 182_C_Smooth, Completely round.png
# 182_D_Smooth, Completely round.png
# 182_E_Smooth, Completely round.png
# 182_F_Smooth, Completely round.png
# 183_A_Disk, Edge-on, Rounded Bulge.png
# 183_B_Disk, Edge-on, Rounded Bulge.png
# 183_C_Disk, Edge-on, Rounded Bulge.png
# 183_D_Disk, Edge-on, Rounded Bulge.png
# 183_E_Disk, Edge-on, Rounded Bulge.png
# 183_F_Disk, Edge-on, Rounded Bulge.png
# 184_A_Disk, Face-on, Tight Spiral.png
# 184_B_Disk, Face-on, Tight Spiral.png
# 184_C_Disk, Face-on, Tight Spiral.png
# 184_D_Disk, Face-on, Tight Spiral.png
# 184_E_Disk, Face-on, Tight Spiral.png
# 184_F_Disk, Face-on, Tight Spiral.png
# 185_A_Smooth, Completely round.png
# 185_B_Smooth, Completely round.png
# 185_C_Smooth, Completely round.png
# 185_D_Smooth, Completely round.png
# 185_E_Smooth, Completely round.png
# 185_F_Smooth, Completely round.png
# 186_A_Smooth, Completely round.png
# 186_B_Smooth, Completely round.png
# 186_C_Smooth, Completely round.png
# 186_D_Smooth, Completely round.png
# 186_E_Smooth, Completely round.png
# 186_F_Smooth, Completely round.png
# 187_A_Smooth, in-between round.png
# 187_B_Smooth, in-between round.png
# 187_C_Smooth, in-between round.png
# 187_D_Smooth, in-between round.png
# 187_E_Smooth, in-between round.png
# 187_F_Smooth, in-between round.png
# 188_A_Disk, Edge-on, Rounded Bulge.png
# 188_B_Disk, Edge-on, Rounded Bulge.png
# 188_C_Disk, Edge-on, Rounded Bulge.png
# 188_D_Disk, Edge-on, Rounded Bulge.png
# 188_E_Disk, Edge-on, Rounded Bulge.png
# 188_F_Disk, Edge-on, Rounded Bulge.png
# 189_A_Smooth, in-between round.png
# 189_B_Smooth, in-between round.png
# 189_C_Smooth, in-between round.png
# 189_D_Smooth, in-between round.png
# 189_E_Smooth, in-between round.png
# 189_F_Smooth, in-between round.png
# 18_A_Disk, Face-on, No Spiral.png
# 18_B_Disk, Face-on, No Spiral.png
# 18_C_Disk, Face-on, No Spiral.png
# 18_D_Disk, Face-on, No Spiral.png
# 18_E_Disk, Face-on, No Spiral.png
# 18_F_Disk, Face-on, No Spiral.png
# 190_A_Disk, Face-on, No Spiral.png
# 190_B_Disk, Face-on, No Spiral.png
# 190_C_Disk, Face-on, No Spiral.png
# 190_D_Disk, Face-on, No Spiral.png
# 190_E_Disk, Face-on, No Spiral.png
# 190_F_Disk, Face-on, No Spiral.png
# 191_A_Smooth, Completely round.png
# 191_B_Smooth, Completely round.png
# 191_C_Smooth, Completely round.png
# 191_D_Smooth, Completely round.png
# 191_E_Smooth, Completely round.png
# 191_F_Smooth, Completely round.png
# 192_A_Disk, Face-on, Tight Spiral.png
# 192_B_Disk, Face-on, Tight Spiral.png
# 192_C_Disk, Face-on, Tight Spiral.png
# 192_D_Disk, Face-on, Tight Spiral.png
# 192_E_Disk, Face-on, Tight Spiral.png
# 192_F_Disk, Face-on, Tight Spiral.png
# 193_A_Disk, Face-on, Medium Spiral.png
# 193_B_Disk, Face-on, Medium Spiral.png
# 193_C_Disk, Face-on, Medium Spiral.png
# 193_D_Disk, Face-on, Medium Spiral.png
# 193_E_Disk, Face-on, Medium Spiral.png
# 193_F_Disk, Face-on, Medium Spiral.png
# 194_A_Smooth, in-between round.png
# 194_B_Smooth, in-between round.png
# 194_C_Smooth, in-between round.png
# 194_D_Smooth, in-between round.png
# 194_E_Smooth, in-between round.png
# 194_F_Smooth, in-between round.png
# 195_A_Disk, Face-on, Tight Spiral.png
# 195_B_Disk, Face-on, Tight Spiral.png
# 195_C_Disk, Face-on, Tight Spiral.png
# 195_D_Disk, Face-on, Tight Spiral.png
# 195_E_Disk, Face-on, Tight Spiral.png
# 195_F_Disk, Face-on, Tight Spiral.png
# 196_A_Smooth, Completely round.png
# 196_B_Smooth, Completely round.png
# 196_C_Smooth, Completely round.png
# 196_D_Smooth, Completely round.png
# 196_E_Smooth, Completely round.png
# 196_F_Smooth, Completely round.png
# 197_A_Smooth, Cigar shaped.png
# 197_B_Smooth, Cigar shaped.png
# 197_C_Smooth, Cigar shaped.png
# 197_D_Smooth, Cigar shaped.png
# 197_E_Smooth, Cigar shaped.png
# 197_F_Smooth, Cigar shaped.png
# 198_A_Disk, Face-on, No Spiral.png
# 198_B_Disk, Face-on, No Spiral.png
# 198_C_Disk, Face-on, No Spiral.png
# 198_D_Disk, Face-on, No Spiral.png
# 198_E_Disk, Face-on, No Spiral.png
# 198_F_Disk, Face-on, No Spiral.png
# 199_A_Smooth, Completely round.png
# 199_B_Smooth, Completely round.png
# 199_C_Smooth, Completely round.png
# 199_D_Smooth, Completely round.png
# 199_E_Smooth, Completely round.png
# 199_F_Smooth, Completely round.png
# 19_A_Disk, Face-on, No Spiral.png
# 19_B_Disk, Face-on, No Spiral.png
# 19_C_Disk, Face-on, No Spiral.png
# 19_D_Disk, Face-on, No Spiral.png
# 19_E_Disk, Face-on, No Spiral.png
# 19_F_Disk, Face-on, No Spiral.png
# 1_A_Smooth, in-between round.png
# 1_B_Smooth, in-between round.png
# 1_C_Smooth, in-between round.png
# 1_D_Smooth, in-between round.png
# 1_E_Smooth, in-between round.png
# 1_F_Smooth, in-between round.png
# 200_A_Smooth, in-between round.png
# 200_B_Smooth, in-between round.png
# 200_C_Smooth, in-between round.png
# 200_D_Smooth, in-between round.png
# 200_E_Smooth, in-between round.png
# 200_F_Smooth, in-between round.png
# 201_A_Disk, Face-on, No Spiral.png
# 201_B_Disk, Face-on, No Spiral.png
# 201_C_Disk, Face-on, No Spiral.png
# 201_D_Disk, Face-on, No Spiral.png
# 201_E_Disk, Face-on, No Spiral.png
# 201_F_Disk, Face-on, No Spiral.png
# 202_A_Smooth, Completely round.png
# 202_B_Smooth, Completely round.png
# 202_C_Smooth, Completely round.png
# 202_D_Smooth, Completely round.png
# 202_E_Smooth, Completely round.png
# 202_F_Smooth, Completely round.png
# 203_A_Smooth, in-between round.png
# 203_B_Smooth, in-between round.png
# 203_C_Smooth, in-between round.png
# 203_D_Smooth, in-between round.png
# 203_E_Smooth, in-between round.png
# 203_F_Smooth, in-between round.png
# 204_A_Smooth, Completely round.png
# 204_B_Smooth, Completely round.png
# 204_C_Smooth, Completely round.png
# 204_D_Smooth, Completely round.png
# 204_E_Smooth, Completely round.png
# 204_F_Smooth, Completely round.png
# 205_A_Disk, Face-on, No Spiral.png
# 205_B_Disk, Face-on, No Spiral.png
# 205_C_Disk, Face-on, No Spiral.png
# 205_D_Disk, Face-on, No Spiral.png
# 205_E_Disk, Face-on, No Spiral.png
# 205_F_Disk, Face-on, No Spiral.png
# 206_A_Smooth, Completely round.png
# 206_B_Smooth, Completely round.png
# 206_C_Smooth, Completely round.png
# 206_D_Smooth, Completely round.png
# 206_E_Smooth, Completely round.png
# 206_F_Smooth, Completely round.png
# 207_A_Smooth, in-between round.png
# 207_B_Smooth, in-between round.png
# 207_C_Smooth, in-between round.png
# 207_D_Smooth, in-between round.png
# 207_E_Smooth, in-between round.png
# 207_F_Smooth, in-between round.png
# 208_A_Disk, Face-on, No Spiral.png
# 208_B_Disk, Face-on, No Spiral.png
# 208_C_Disk, Face-on, No Spiral.png
# 208_D_Disk, Face-on, No Spiral.png
# 208_E_Disk, Face-on, No Spiral.png
# 208_F_Disk, Face-on, No Spiral.png
# 209_A_Smooth, in-between round.png
# 209_B_Smooth, in-between round.png
# 209_C_Smooth, in-between round.png
# 209_D_Smooth, in-between round.png
# 209_E_Smooth, in-between round.png
# 209_F_Smooth, in-between round.png
# 20_A_Smooth, Completely round.png
# 20_B_Smooth, Completely round.png
# 20_C_Smooth, Completely round.png
# 20_D_Smooth, Completely round.png
# 20_E_Smooth, Completely round.png
# 20_F_Smooth, Completely round.png
# 210_A_Smooth, in-between round.png
# 210_B_Smooth, in-between round.png
# 210_C_Smooth, in-between round.png
# 210_D_Smooth, in-between round.png
# 210_E_Smooth, in-between round.png
# 210_F_Smooth, in-between round.png
# 211_A_Smooth, Completely round.png
# 211_B_Smooth, Completely round.png
# 211_C_Smooth, Completely round.png
# 211_D_Smooth, Completely round.png
# 211_E_Smooth, Completely round.png
# 211_F_Smooth, Completely round.png
# 212_A_Disk, Face-on, Medium Spiral.png
# 212_B_Disk, Face-on, Medium Spiral.png
# 212_C_Disk, Face-on, Medium Spiral.png
# 212_D_Disk, Face-on, Medium Spiral.png
# 212_E_Disk, Face-on, Medium Spiral.png
# 212_F_Disk, Face-on, Medium Spiral.png
# 213_A_Smooth, Completely round.png
# 213_B_Smooth, Completely round.png
# 213_C_Smooth, Completely round.png
# 213_D_Smooth, Completely round.png
# 213_E_Smooth, Completely round.png
# 213_F_Smooth, Completely round.png
# 214_A_Disk, Face-on, Medium Spiral.png
# 214_B_Disk, Face-on, Medium Spiral.png
# 214_C_Disk, Face-on, Medium Spiral.png
# 214_D_Disk, Face-on, Medium Spiral.png
# 214_E_Disk, Face-on, Medium Spiral.png
# 214_F_Disk, Face-on, Medium Spiral.png
# 215_A_Smooth, in-between round.png
# 215_B_Smooth, in-between round.png
# 215_C_Smooth, in-between round.png
# 215_D_Smooth, in-between round.png
# 215_E_Smooth, in-between round.png
# 215_F_Smooth, in-between round.png
# 216_A_Disk, Face-on, Tight Spiral.png
# 216_B_Disk, Face-on, Tight Spiral.png
# 216_C_Disk, Face-on, Tight Spiral.png
# 216_D_Disk, Face-on, Tight Spiral.png
# 216_E_Disk, Face-on, Tight Spiral.png
# 216_F_Disk, Face-on, Tight Spiral.png
# 217_A_Smooth, Completely round.png
# 217_B_Smooth, Completely round.png
# 217_C_Smooth, Completely round.png
# 217_D_Smooth, Completely round.png
# 217_E_Smooth, Completely round.png
# 217_F_Smooth, Completely round.png
# 218_A_Smooth, in-between round.png
# 218_B_Smooth, in-between round.png
# 218_C_Smooth, in-between round.png
# 218_D_Smooth, in-between round.png
# 218_E_Smooth, in-between round.png
# 218_F_Smooth, in-between round.png
# 219_A_Smooth, in-between round.png
# 219_B_Smooth, in-between round.png
# 219_C_Smooth, in-between round.png
# 219_D_Smooth, in-between round.png
# 219_E_Smooth, in-between round.png
# 219_F_Smooth, in-between round.png
# 21_A_Disk, Edge-on, No Bulge.png
# 21_B_Disk, Edge-on, No Bulge.png
# 21_C_Disk, Edge-on, No Bulge.png
# 21_D_Disk, Edge-on, No Bulge.png
# 21_E_Disk, Edge-on, No Bulge.png
# 21_F_Disk, Edge-on, No Bulge.png
# 220_A_Smooth, Completely round.png
# 220_B_Smooth, Completely round.png
# 220_C_Smooth, Completely round.png
# 220_D_Smooth, Completely round.png
# 220_E_Smooth, Completely round.png
# 220_F_Smooth, Completely round.png
# 221_A_Smooth, Completely round.png
# 221_B_Smooth, Completely round.png
# 221_C_Smooth, Completely round.png
# 221_D_Smooth, Completely round.png
# 221_E_Smooth, Completely round.png
# 221_F_Smooth, Completely round.png
# 222_A_Smooth, Completely round.png
# 222_B_Smooth, Completely round.png
# 222_C_Smooth, Completely round.png
# 222_D_Smooth, Completely round.png
# 222_E_Smooth, Completely round.png
# 222_F_Smooth, Completely round.png
# 223_A_Disk, Face-on, No Spiral.png
# 223_B_Disk, Face-on, No Spiral.png
# 223_C_Disk, Face-on, No Spiral.png
# 223_D_Disk, Face-on, No Spiral.png
# 223_E_Disk, Face-on, No Spiral.png
# 223_F_Disk, Face-on, No Spiral.png
# 224_A_Disk, Edge-on, Rounded Bulge.png
# 224_B_Disk, Edge-on, Rounded Bulge.png
# 224_C_Disk, Edge-on, Rounded Bulge.png
# 224_D_Disk, Edge-on, Rounded Bulge.png
# 224_E_Disk, Edge-on, Rounded Bulge.png
# 224_F_Disk, Edge-on, Rounded Bulge.png
# 225_A_Smooth, Completely round.png
# 225_B_Smooth, Completely round.png
# 225_C_Smooth, Completely round.png
# 225_D_Smooth, Completely round.png
# 225_E_Smooth, Completely round.png
# 225_F_Smooth, Completely round.png
# 226_A_Smooth, in-between round.png
# 226_B_Smooth, in-between round.png
# 226_C_Smooth, in-between round.png
# 226_D_Smooth, in-between round.png
# 226_E_Smooth, in-between round.png
# 226_F_Smooth, in-between round.png
# 227_A_Smooth, in-between round.png
# 227_B_Smooth, in-between round.png
# 227_C_Smooth, in-between round.png
# 227_D_Smooth, in-between round.png
# 227_E_Smooth, in-between round.png
# 227_F_Smooth, in-between round.png
# 228_A_Smooth, Completely round.png
# 228_B_Smooth, Completely round.png
# 228_C_Smooth, Completely round.png
# 228_D_Smooth, Completely round.png
# 228_E_Smooth, Completely round.png
# 228_F_Smooth, Completely round.png
# 229_A_Smooth, Completely round.png
# 229_B_Smooth, Completely round.png
# 229_C_Smooth, Completely round.png
# 229_D_Smooth, Completely round.png
# 229_E_Smooth, Completely round.png
# 229_F_Smooth, Completely round.png
# 22_A_Disk, Face-on, No Spiral.png
# 22_B_Disk, Face-on, No Spiral.png
# 22_C_Disk, Face-on, No Spiral.png
# 22_D_Disk, Face-on, No Spiral.png
# 22_E_Disk, Face-on, No Spiral.png
# 22_F_Disk, Face-on, No Spiral.png
# 230_A_Smooth, in-between round.png
# 230_B_Smooth, in-between round.png
# 230_C_Smooth, in-between round.png
# 230_D_Smooth, in-between round.png
# 230_E_Smooth, in-between round.png
# 230_F_Smooth, in-between round.png
# 231_A_Disk, Edge-on, Rounded Bulge.png
# 231_B_Disk, Edge-on, Rounded Bulge.png
# 231_C_Disk, Edge-on, Rounded Bulge.png
# 231_D_Disk, Edge-on, Rounded Bulge.png
# 231_E_Disk, Edge-on, Rounded Bulge.png
# 231_F_Disk, Edge-on, Rounded Bulge.png
# 232_A_Smooth, in-between round.png
# 232_B_Smooth, in-between round.png
# 232_C_Smooth, in-between round.png
# 232_D_Smooth, in-between round.png
# 232_E_Smooth, in-between round.png
# 232_F_Smooth, in-between round.png
# 233_A_Smooth, in-between round.png
# 233_B_Smooth, in-between round.png
# 233_C_Smooth, in-between round.png
# 233_D_Smooth, in-between round.png
# 233_E_Smooth, in-between round.png
# 233_F_Smooth, in-between round.png
# 234_A_Smooth, in-between round.png
# 234_B_Smooth, in-between round.png
# 234_C_Smooth, in-between round.png
# 234_D_Smooth, in-between round.png
# 234_E_Smooth, in-between round.png
# 234_F_Smooth, in-between round.png
# 235_A_Smooth, in-between round.png
# 235_B_Smooth, in-between round.png
# 235_C_Smooth, in-between round.png
# 235_D_Smooth, in-between round.png
# 235_E_Smooth, in-between round.png
# ...
# 44_C_Disk, Face-on, Medium Spiral.png
# 44_D_Disk, Face-on, Medium Spiral.png
# 44_E_Disk, Face-on, Medium Spiral.png
# 44_F_Disk, Face-on, Medium Spiral.png
# 45_A_Smooth, Cigar shaped.png
# 45_B_Smooth, Cigar shaped.png
# 45_C_Smooth, Cigar shaped.png
# 45_D_Smooth, Cigar shaped.png
# 45_E_Smooth, Cigar shaped.png
# 45_F_Smooth, Cigar shaped.png
# 46_A_Disk, Face-on, No Spiral.png
# 46_B_Disk, Face-on, No Spiral.png
# 46_C_Disk, Face-on, No Spiral.png
# 46_D_Disk, Face-on, No Spiral.png
# 46_E_Disk, Face-on, No Spiral.png
# 46_F_Disk, Face-on, No Spiral.png
# 47_A_Smooth, Completely round.png
# 47_B_Smooth, Completely round.png
# 47_C_Smooth, Completely round.png
# 47_D_Smooth, Completely round.png
# 47_E_Smooth, Completely round.png
# 47_F_Smooth, Completely round.png
# 48_A_Smooth, in-between round.png
# 48_B_Smooth, in-between round.png
# 48_C_Smooth, in-between round.png
# 48_D_Smooth, in-between round.png
# 48_E_Smooth, in-between round.png
# 48_F_Smooth, in-between round.png
# 49_A_Smooth, Completely round.png
# 49_B_Smooth, Completely round.png
# 49_C_Smooth, Completely round.png
# 49_D_Smooth, Completely round.png
# 49_E_Smooth, Completely round.png
# 49_F_Smooth, Completely round.png
# 4_A_Smooth, in-between round.png
# 4_B_Smooth, in-between round.png
# 4_C_Smooth, in-between round.png
# 4_D_Smooth, in-between round.png
# 4_E_Smooth, in-between round.png
# 4_F_Smooth, in-between round.png
# 50_A_Smooth, in-between round.png
# 50_B_Smooth, in-between round.png
# 50_C_Smooth, in-between round.png
# 50_D_Smooth, in-between round.png
# 50_E_Smooth, in-between round.png
# 50_F_Smooth, in-between round.png
# 51_A_Smooth, Completely round.png
# 51_B_Smooth, Completely round.png
# 51_C_Smooth, Completely round.png
# 51_D_Smooth, Completely round.png
# 51_E_Smooth, Completely round.png
# 51_F_Smooth, Completely round.png
# 52_A_Smooth, Completely round.png
# 52_B_Smooth, Completely round.png
# 52_C_Smooth, Completely round.png
# 52_D_Smooth, Completely round.png
# 52_E_Smooth, Completely round.png
# 52_F_Smooth, Completely round.png
# 53_A_Disk, Face-on, Medium Spiral.png
# 53_B_Disk, Face-on, Medium Spiral.png
# 53_C_Disk, Face-on, Medium Spiral.png
# 53_D_Disk, Face-on, Medium Spiral.png
# 53_E_Disk, Face-on, Medium Spiral.png
# 53_F_Disk, Face-on, Medium Spiral.png
# 54_A_Smooth, Completely round.png
# 54_B_Smooth, Completely round.png
# 54_C_Smooth, Completely round.png
# 54_D_Smooth, Completely round.png
# 54_E_Smooth, Completely round.png
# 54_F_Smooth, Completely round.png
# 55_A_Smooth, in-between round.png
# 55_B_Smooth, in-between round.png
# 55_C_Smooth, in-between round.png
# 55_D_Smooth, in-between round.png
# 55_E_Smooth, in-between round.png
# 55_F_Smooth, in-between round.png
# 56_A_Smooth, in-between round.png
# 56_B_Smooth, in-between round.png
# 56_C_Smooth, in-between round.png
# 56_D_Smooth, in-between round.png
# 56_E_Smooth, in-between round.png
# 56_F_Smooth, in-between round.png
# 57_A_Smooth, in-between round.png
# 57_B_Smooth, in-between round.png
# 57_C_Smooth, in-between round.png
# 57_D_Smooth, in-between round.png
# 57_E_Smooth, in-between round.png
# 57_F_Smooth, in-between round.png
# 58_A_Smooth, Completely round.png
# 58_B_Smooth, Completely round.png
# 58_C_Smooth, Completely round.png
# 58_D_Smooth, Completely round.png
# 58_E_Smooth, Completely round.png
# 58_F_Smooth, Completely round.png
# 59_A_Smooth, Cigar shaped.png
# 59_B_Smooth, Cigar shaped.png
# 59_C_Smooth, Cigar shaped.png
# 59_D_Smooth, Cigar shaped.png
# 59_E_Smooth, Cigar shaped.png
# 59_F_Smooth, Cigar shaped.png
# 5_A_Disk, Edge-on, Rounded Bulge.png
# 5_B_Disk, Edge-on, Rounded Bulge.png
# 5_C_Disk, Edge-on, Rounded Bulge.png
# 5_D_Disk, Edge-on, Rounded Bulge.png
# 5_E_Disk, Edge-on, Rounded Bulge.png
# 5_F_Disk, Edge-on, Rounded Bulge.png
# 60_A_Disk, Edge-on, Rounded Bulge.png
# 60_B_Disk, Edge-on, Rounded Bulge.png
# 60_C_Disk, Edge-on, Rounded Bulge.png
# 60_D_Disk, Edge-on, Rounded Bulge.png
# 60_E_Disk, Edge-on, Rounded Bulge.png
# 60_F_Disk, Edge-on, Rounded Bulge.png
# 61_A_Smooth, in-between round.png
# 61_B_Smooth, in-between round.png
# 61_C_Smooth, in-between round.png
# 61_D_Smooth, in-between round.png
# 61_E_Smooth, in-between round.png
# 61_F_Smooth, in-between round.png
# 62_A_Smooth, Completely round.png
# 62_B_Smooth, Completely round.png
# 62_C_Smooth, Completely round.png
# 62_D_Smooth, Completely round.png
# 62_E_Smooth, Completely round.png
# 62_F_Smooth, Completely round.png
# 63_A_Smooth, in-between round.png
# 63_B_Smooth, in-between round.png
# 63_C_Smooth, in-between round.png
# 63_D_Smooth, in-between round.png
# 63_E_Smooth, in-between round.png
# 63_F_Smooth, in-between round.png
# 64_A_Disk, Face-on, Tight Spiral.png
# 64_B_Disk, Face-on, Tight Spiral.png
# 64_C_Disk, Face-on, Tight Spiral.png
# 64_D_Disk, Face-on, Tight Spiral.png
# 64_E_Disk, Face-on, Tight Spiral.png
# 64_F_Disk, Face-on, Tight Spiral.png
# 65_A_Smooth, in-between round.png
# 65_B_Smooth, in-between round.png
# 65_C_Smooth, in-between round.png
# 65_D_Smooth, in-between round.png
# 65_E_Smooth, in-between round.png
# 65_F_Smooth, in-between round.png
# 66_A_Smooth, in-between round.png
# 66_B_Smooth, in-between round.png
# 66_C_Smooth, in-between round.png
# 66_D_Smooth, in-between round.png
# 66_E_Smooth, in-between round.png
# 66_F_Smooth, in-between round.png
# 67_A_Smooth, Completely round.png
# 67_B_Smooth, Completely round.png
# 67_C_Smooth, Completely round.png
# 67_D_Smooth, Completely round.png
# 67_E_Smooth, Completely round.png
# 67_F_Smooth, Completely round.png
# 68_A_Smooth, Completely round.png
# 68_B_Smooth, Completely round.png
# 68_C_Smooth, Completely round.png
# 68_D_Smooth, Completely round.png
# 68_E_Smooth, Completely round.png
# 68_F_Smooth, Completely round.png
# 69_A_Smooth, Completely round.png
# 69_B_Smooth, Completely round.png
# 69_C_Smooth, Completely round.png
# 69_D_Smooth, Completely round.png
# 69_E_Smooth, Completely round.png
# 69_F_Smooth, Completely round.png
# 6_A_Smooth, in-between round.png
# 6_B_Smooth, in-between round.png
# 6_C_Smooth, in-between round.png
# 6_D_Smooth, in-between round.png
# 6_E_Smooth, in-between round.png
# 6_F_Smooth, in-between round.png
# 70_A_Smooth, in-between round.png
# 70_B_Smooth, in-between round.png
# 70_C_Smooth, in-between round.png
# 70_D_Smooth, in-between round.png
# 70_E_Smooth, in-between round.png
# 70_F_Smooth, in-between round.png
# 71_A_Smooth, in-between round.png
# 71_B_Smooth, in-between round.png
# 71_C_Smooth, in-between round.png
# 71_D_Smooth, in-between round.png
# 71_E_Smooth, in-between round.png
# 71_F_Smooth, in-between round.png
# 72_A_Smooth, in-between round.png
# 72_B_Smooth, in-between round.png
# 72_C_Smooth, in-between round.png
# 72_D_Smooth, in-between round.png
# 72_E_Smooth, in-between round.png
# 72_F_Smooth, in-between round.png
# 73_A_Smooth, in-between round.png
# 73_B_Smooth, in-between round.png
# 73_C_Smooth, in-between round.png
# 73_D_Smooth, in-between round.png
# 73_E_Smooth, in-between round.png
# 73_F_Smooth, in-between round.png
# 74_A_Smooth, in-between round.png
# 74_B_Smooth, in-between round.png
# 74_C_Smooth, in-between round.png
# 74_D_Smooth, in-between round.png
# 74_E_Smooth, in-between round.png
# 74_F_Smooth, in-between round.png
# 75_A_Disk, Face-on, No Spiral.png
# 75_B_Disk, Face-on, No Spiral.png
# 75_C_Disk, Face-on, No Spiral.png
# 75_D_Disk, Face-on, No Spiral.png
# 75_E_Disk, Face-on, No Spiral.png
# 75_F_Disk, Face-on, No Spiral.png
# 76_A_Disk, Face-on, No Spiral.png
# 76_B_Disk, Face-on, No Spiral.png
# 76_C_Disk, Face-on, No Spiral.png
# 76_D_Disk, Face-on, No Spiral.png
# 76_E_Disk, Face-on, No Spiral.png
# 76_F_Disk, Face-on, No Spiral.png
# 77_A_Smooth, Completely round.png
# 77_B_Smooth, Completely round.png
# 77_C_Smooth, Completely round.png
# 77_D_Smooth, Completely round.png
# 77_E_Smooth, Completely round.png
# 77_F_Smooth, Completely round.png
# 78_A_Smooth, in-between round.png
# 78_B_Smooth, in-between round.png
# 78_C_Smooth, in-between round.png
# 78_D_Smooth, in-between round.png
# 78_E_Smooth, in-between round.png
# 78_F_Smooth, in-between round.png
# 79_A_Disk, Face-on, Tight Spiral.png
# 79_B_Disk, Face-on, Tight Spiral.png
# 79_C_Disk, Face-on, Tight Spiral.png
# 79_D_Disk, Face-on, Tight Spiral.png
# 79_E_Disk, Face-on, Tight Spiral.png
# 79_F_Disk, Face-on, Tight Spiral.png
# 7_A_Disk, Face-on, No Spiral.png
# 7_B_Disk, Face-on, No Spiral.png
# 7_C_Disk, Face-on, No Spiral.png
# 7_D_Disk, Face-on, No Spiral.png
# 7_E_Disk, Face-on, No Spiral.png
# 7_F_Disk, Face-on, No Spiral.png
# 80_A_Smooth, Completely round.png
# 80_B_Smooth, Completely round.png
# 80_C_Smooth, Completely round.png
# 80_D_Smooth, Completely round.png
# 80_E_Smooth, Completely round.png
# 80_F_Smooth, Completely round.png
# 81_A_Smooth, in-between round.png
# 81_B_Smooth, in-between round.png
# 81_C_Smooth, in-between round.png
# 81_D_Smooth, in-between round.png
# 81_E_Smooth, in-between round.png
# 81_F_Smooth, in-between round.png
# 82_A_Smooth, in-between round.png
# 82_B_Smooth, in-between round.png
# 82_C_Smooth, in-between round.png
# 82_D_Smooth, in-between round.png
# 82_E_Smooth, in-between round.png
# 82_F_Smooth, in-between round.png
# 83_A_Smooth, Completely round.png
# 83_B_Smooth, Completely round.png
# 83_C_Smooth, Completely round.png
# 83_D_Smooth, Completely round.png
# 83_E_Smooth, Completely round.png
# 83_F_Smooth, Completely round.png
# 84_A_Disk, Face-on, Tight Spiral.png
# 84_B_Disk, Face-on, Tight Spiral.png
# 84_C_Disk, Face-on, Tight Spiral.png
# 84_D_Disk, Face-on, Tight Spiral.png
# 84_E_Disk, Face-on, Tight Spiral.png
# 84_F_Disk, Face-on, Tight Spiral.png
# 85_A_Smooth, Cigar shaped.png
# 85_B_Smooth, Cigar shaped.png
# 85_C_Smooth, Cigar shaped.png
# 85_D_Smooth, Cigar shaped.png
# 85_E_Smooth, Cigar shaped.png
# 85_F_Smooth, Cigar shaped.png
# 86_A_Disk, Edge-on, Rounded Bulge.png
# 86_B_Disk, Edge-on, Rounded Bulge.png
# 86_C_Disk, Edge-on, Rounded Bulge.png
# 86_D_Disk, Edge-on, Rounded Bulge.png
# 86_E_Disk, Edge-on, Rounded Bulge.png
# 86_F_Disk, Edge-on, Rounded Bulge.png
# 87_A_Smooth, Completely round.png
# 87_B_Smooth, Completely round.png
# 87_C_Smooth, Completely round.png
# 87_D_Smooth, Completely round.png
# 87_E_Smooth, Completely round.png
# 87_F_Smooth, Completely round.png
# 88_A_Smooth, Completely round.png
# 88_B_Smooth, Completely round.png
# 88_C_Smooth, Completely round.png
# 88_D_Smooth, Completely round.png
# 88_E_Smooth, Completely round.png
# 88_F_Smooth, Completely round.png
# 89_A_Smooth, Completely round.png
# 89_B_Smooth, Completely round.png
# 89_C_Smooth, Completely round.png
# 89_D_Smooth, Completely round.png
# 89_E_Smooth, Completely round.png
# 89_F_Smooth, Completely round.png
# 8_A_Disk, Face-on, No Spiral.png
# 8_B_Disk, Face-on, No Spiral.png
# 8_C_Disk, Face-on, No Spiral.png
# 8_D_Disk, Face-on, No Spiral.png
# 8_E_Disk, Face-on, No Spiral.png
# 8_F_Disk, Face-on, No Spiral.png
# 90_A_Disk, Face-on, Loose Spiral.png
# 90_B_Disk, Face-on, Loose Spiral.png
# 90_C_Disk, Face-on, Loose Spiral.png
# 90_D_Disk, Face-on, Loose Spiral.png
# 90_E_Disk, Face-on, Loose Spiral.png
# 90_F_Disk, Face-on, Loose Spiral.png
# 91_A_Smooth, Completely round.png
# 91_B_Smooth, Completely round.png
# 91_C_Smooth, Completely round.png
# 91_D_Smooth, Completely round.png
# 91_E_Smooth, Completely round.png
# 91_F_Smooth, Completely round.png
# 92_A_Smooth, in-between round.png
# 92_B_Smooth, in-between round.png
# 92_C_Smooth, in-between round.png
# 92_D_Smooth, in-between round.png
# 92_E_Smooth, in-between round.png
# 92_F_Smooth, in-between round.png
# 93_A_Smooth, Completely round.png
# 93_B_Smooth, Completely round.png
# 93_C_Smooth, Completely round.png
# 93_D_Smooth, Completely round.png
# 93_E_Smooth, Completely round.png
# 93_F_Smooth, Completely round.png
# 94_A_Disk, Face-on, No Spiral.png
# 94_B_Disk, Face-on, No Spiral.png
# 94_C_Disk, Face-on, No Spiral.png
# 94_D_Disk, Face-on, No Spiral.png
# 94_E_Disk, Face-on, No Spiral.png
# 94_F_Disk, Face-on, No Spiral.png
# 95_A_Disk, Face-on, Loose Spiral.png
# 95_B_Disk, Face-on, Loose Spiral.png
# 95_C_Disk, Face-on, Loose Spiral.png
# 95_D_Disk, Face-on, Loose Spiral.png
# 95_E_Disk, Face-on, Loose Spiral.png
# 95_F_Disk, Face-on, Loose Spiral.png
# 96_A_Smooth, in-between round.png
# 96_B_Smooth, in-between round.png
# 96_C_Smooth, in-between round.png
# 96_D_Smooth, in-between round.png
# 96_E_Smooth, in-between round.png
# 96_F_Smooth, in-between round.png
# 97_A_Disk, Face-on, Loose Spiral.png
# 97_B_Disk, Face-on, Loose Spiral.png
# 97_C_Disk, Face-on, Loose Spiral.png
# 97_D_Disk, Face-on, Loose Spiral.png
# 97_E_Disk, Face-on, Loose Spiral.png
# 97_F_Disk, Face-on, Loose Spiral.png
# 98_A_Smooth, in-between round.png
# 98_B_Smooth, in-between round.png
# 98_C_Smooth, in-between round.png
# 98_D_Smooth, in-between round.png
# 98_E_Smooth, in-between round.png
# 98_F_Smooth, in-between round.png
# 99_A_Disk, Face-on, Tight Spiral.png
# 99_B_Disk, Face-on, Tight Spiral.png
# 99_C_Disk, Face-on, Tight Spiral.png
# 99_D_Disk, Face-on, Tight Spiral.png
# 99_E_Disk, Face-on, Tight Spiral.png
# 99_F_Disk, Face-on, Tight Spiral.png
# 9_A_Disk, Face-on, No Spiral.png
# 9_B_Disk, Face-on, No Spiral.png
# 9_C_Disk, Face-on, No Spiral.png
# 9_D_Disk, Face-on, No Spiral.png
# 9_E_Disk, Face-on, No Spiral.png
# 9_F_Disk, Face-on, No Spiral.png
# 250.png
# 251.png
# 252.png
# 253.png
# 254.png
# 255.png
# 256.png
# 257.png
# 258.png
# 259.png
# 260.png
# 261.png
# 262.png
# 268.png
# 270.png
# 271.png
# 272.png
# 273.png
# 274.png
# 275.png
# 276.png
# 277.png
# 278.png
# 279.png
# 280.png
# 281.png
# 282.png
# 283.png
# 284.png
# 285.png
# 286.png
# 287.png
# 288.png
# 289.png
# 290.png
# 291.png
# 292.png
# 293.png
# 294.png
# 295.png
# 296.png
# 297.png
# 298.png
# 299.png
# 300.png
# 301.png
# 302.png
# 303.png
# 304.png
# 305.png
# 306.png
# 307.png
# 308.png
# 309.png
# 310.png
# 311.png
# 312.png
# 313.png
# 314.png
# 315.png
# 316.png
# 317.png
# 318.png
# 319.png
# 320.png
# 321.png
# 322.png
# 323.png
# 324.png
# 325.png
# 328.png
# 329.png
# 330.png
# 331.png
# 332.png
# 333.png
# 334.png
# 335.png
# 336.png
# 337.png
# 338.png
# 339.png
# 340.png
# 341.png
# 342.png
# 343.png
# 344.png
# 345.png
# 346.png
# 347.png
# 348.png
# 349.png
# 350.png
# 351.png
# 352.png
# 353.png
# 354.png
# 355.png
# 356.png
# 357.png
# 358.png
# 359.png
# 360.png
# 361.png
# 362.png
# 363.png
# 364.png
# 365.png
# 366.png
# 367.png
# 368.png
# 369.png
# 370.png
# 371.png
# 372.png
# 374.png
# 375.png
# 377.png
# 378.png
# 379.png
# 380.png
# 381.png
# 382.png
# 383.png
# 384.png
# 385.png
# 386.png
# 387.png
# 388.png
# 389.png
# 390.png
# 391.png
# 392.png
# 393.png
# 394.png
# 395.png
# 396.png
# 397.png
# 398.png
# 399.png
# 400.png
# 401.png
# 402.png
# 403.png
# 404.png
# 405.png
# 406.png
# 407.png
# 408.png
# 409.png
# 410.png
# 411.png
# 412.png
# 413.png
# 414.png
# 415.png
# 416.png
# 417.png
# 418.png
# 419.png
# 420.png
# 421.png
# 422.png
# 423.png
# 424.png
# 425.png
# 426.png
# 427.png
# 428.png
# 429.png
# 430.png
# 431.png
# 432.png
# 433.png
# 434.png
# 435.png
# 436.png
# 437.png
# 438.png
# 439.png
# 440.png
# 441.png
# 442.png
# 443.png
# 444.png
# 445.png
# 446.png
# 447.png
# 448.png
# 449.png
# _250.png
# _251.png
# _252.png
# _253.png
# _254.png
# _255.png
# _256.png
# _257.png
# _258.png
# _259.png
# _260.png
# _261.png
# _262.png
# _265.png
# _268.png
# _270.png
# _271.png
# _272.png
# _273.png
# _274.png
# _275.png
# _276.png
# _277.png
# _278.png
# _279.png
# _280.png
# _281.png
# _282.png
# _283.png
# _284.png
# _285.png
# _286.png
# _288.png
# _289.png
# _290.png
# _291.png
# _292.png
# _293.png
# _294.png
# _295.png
# _296.png
# _297.png
# _298.png
# _299.png
# _300.png
# _301.png
# _302.png
# _303.png
# _304.png
# _305.png
# _306.png
# _307.png
# _308.png
# _309.png
# _310.png
# _311.png
# _312.png
# _313.png
# _314.png
# _315.png
# _316.png
# _317.png
# _318.png
# _319.png
# _320.png
# _321.png
# _322.png
# _323.png
# _324.png
# _325.png
# _327.png
# _328.png
# _329.png
# _330.png
# _331.png
# _332.png
# _333.png
# _334.png
# _335.png
# _336.png
# _337.png
# _338.png
# _339.png
# _340.png
# _341.png
# _342.png
# _343.png
# _344.png
# _345.png
# _346.png
# _347.png
# _348.png
# _349.png
# _350.png
# _351.png
# _352.png
# _353.png
# _354.png
# _355.png
# _356.png
# _357.png
# _358.png
# _359.png
# _360.png
# _361.png
# _362.png
# _363.png
# _364.png
# _365.png
# _366.png
# _367.png
# _368.png
# _369.png
# _370.png
# _371.png
# _372.png
# _373.png
# _374.png
# _375.png
# _376.png
# _377.png
# _378.png
# _379.png
# _380.png
# _381.png
# _382.png
# _383.png
# _384.png
# _385.png
# _386.png
# _387.png
# _388.png
# _389.png
# _390.png
# _391.png
# _392.png
# _393.png
# _394.png
# _395.png
# _396.png
# _397.png
# _398.png
# _399.png
# _400.png
# _401.png
# _402.png
# _403.png
# _404.png
# _405.png
# _406.png
# _407.png
# _408.png
# _409.png
# _410.png
# _411.png
# _412.png
# _413.png
# _414.png
# _415.png
# _416.png
# _417.png
# _418.png
# _419.png
# _420.png
# _421.png
# _422.png
# _423.png
# _424.png
# _425.png
# _426.png
# _427.png
# _428.png
# _429.png
# _430.png
# _431.png
# _432.png
# _433.png
# _434.png
# _435.png
# _436.png
# _437.png
# _438.png
# _439.png
# _440.png
# _441.png
# _442.png
# _443.png
# _444.png
# _445.png
# _446.png
# _447.png
# _448.png
# _449.png

# %%
# Crear un solo arreglo de todas las imagenes dentro de las carpetas TEST
image1 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies/0_Smooth, in-between round.png')
image2 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies/100_Disk, Face-on, No Spiral.png')

test_set_x_orig_2 = np.append(image1 , image1)
test_set_x_orig_2.shape

basepath = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies/'

i = 0
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            if(i > 1):
                name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies/' + str(entry.name)
                image1 = cv2.imread(name)
                imaget = test_set_x_orig_2
                test_set_x_orig_2 = np.append(imaget , image1)
        i = i + 1   
 
basepath2 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lsst/'
        
with os.scandir(basepath2) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lsst/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = test_set_x_orig_2
            test_set_x_orig_2 = np.append(imaget , image1)

basepath3 = '/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/'
        
with os.scandir(basepath3) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/W2_A2/test_galaxies_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            imaget = test_set_x_orig_2
            test_set_x_orig_2 = np.append(imaget , image1)
        
p = test_set_x_orig_2.shape[0]/(217*217*3) 
r = int(p)
plt.imshow(test_set_x_orig_2.reshape(r, 217, 217, 3)[1])
# Out:
# 0_Smooth, in-between round.png
# 100_Disk, Face-on, No Spiral.png
# 101_Smooth, Completely round.png
# 102_Disk, Face-on, Loose Spiral.png
# 103_Smooth, in-between round.png
# 104_Disk, Face-on, Medium Spiral.png
# 105_Smooth, Completely round.png
# 106_Smooth, Completely round.png
# 107_Smooth, Completely round.png
# 108_Smooth, Completely round.png
# 109_Smooth, Completely round.png
# 10_Smooth, Completely round.png
# 110_Smooth, in-between round.png
# 111_Disk, Face-on, No Spiral.png
# 112_Disk, Edge-on, Rounded Bulge.png
# 113_Disk, Face-on, No Spiral.png
# 114_Disk, Edge-on, Rounded Bulge.png
# 115_Smooth, Completely round.png
# 116_Disk, Edge-on, Rounded Bulge.png
# 117_Disk, Edge-on, Rounded Bulge.png
# 118_Smooth, Completely round.png
# 119_Smooth, in-between round.png
# 11_Smooth, in-between round.png
# 120_Smooth, in-between round.png
# 121_Smooth, in-between round.png
# 122_Smooth, in-between round.png
# 123_Smooth, Completely round.png
# 124_Smooth, in-between round.png
# 125_Disk, Face-on, Tight Spiral.png
# 126_Smooth, Completely round.png
# 127_Disk, Face-on, No Spiral.png
# 128_Smooth, Completely round.png
# 129_Smooth, Completely round.png
# 12_Smooth, Completely round.png
# 130_Smooth, in-between round.png
# 131_Smooth, Completely round.png
# 132_Smooth, in-between round.png
# 133_Smooth, in-between round.png
# 134_Smooth, in-between round.png
# 135_Smooth, Cigar shaped.png
# 136_Smooth, in-between round.png
# 137_Smooth, in-between round.png
# 138_Smooth, in-between round.png
# 139_Disk, Edge-on, No Bulge.png
# 13_Smooth, in-between round.png
# 140_Smooth, in-between round.png
# 141_Smooth, Completely round.png
# 142_Disk, Face-on, Medium Spiral.png
# 143_Smooth, Completely round.png
# 144_Disk, Face-on, Medium Spiral.png
# 145_Smooth, in-between round.png
# 146_Smooth, Completely round.png
# 147_Smooth, in-between round.png
# 148_Smooth, in-between round.png
# 149_Disk, Face-on, Loose Spiral.png
# 14_Smooth, Completely round.png
# 150_Disk, Face-on, Medium Spiral.png
# 151_Smooth, Completely round.png
# 152_Smooth, Completely round.png
# 153_Smooth, Completely round.png
# 154_Smooth, Completely round.png
# 155_Smooth, Completely round.png
# 156_Smooth, Completely round.png
# 157_Disk, Face-on, No Spiral.png
# 158_Disk, Edge-on, Rounded Bulge.png
# 159_Smooth, Completely round.png
# 15_Disk, Face-on, No Spiral.png
# 160_Disk, Face-on, Loose Spiral.png
# 161_Smooth, Completely round.png
# 162_Smooth, Completely round.png
# 163_Smooth, in-between round.png
# 164_Smooth, Completely round.png
# 165_Disk, Face-on, No Spiral.png
# 166_Disk, Face-on, No Spiral.png
# 167_Disk, Edge-on, Rounded Bulge.png
# 168_Smooth, in-between round.png
# 169_Disk, Face-on, No Spiral.png
# 16_Disk, Face-on, No Spiral.png
# 170_Smooth, Completely round.png
# 171_Smooth, Completely round.png
# 172_Disk, Face-on, No Spiral.png
# 173_Smooth, Completely round.png
# 174_Disk, Face-on, Loose Spiral.png
# 175_Smooth, in-between round.png
# 176_Disk, Face-on, No Spiral.png
# 177_Smooth, in-between round.png
# 178_Disk, Face-on, No Spiral.png
# 179_Disk, Face-on, Tight Spiral.png
# 17_Smooth, in-between round.png
# 180_Smooth, in-between round.png
# 181_Disk, Face-on, No Spiral.png
# 182_Smooth, in-between round.png
# 183_Smooth, Completely round.png
# 184_Smooth, Completely round.png
# 185_Smooth, Completely round.png
# 186_Disk, Face-on, No Spiral.png
# 187_Smooth, in-between round.png
# 188_Smooth, in-between round.png
# 189_Disk, Face-on, Medium Spiral.png
# 18_Smooth, Completely round.png
# 190_Smooth, in-between round.png
# 191_Smooth, in-between round.png
# 192_Smooth, Completely round.png
# 193_Disk, Edge-on, No Bulge.png
# 194_Smooth, Completely round.png
# 195_Smooth, Completely round.png
# 196_Smooth, Completely round.png
# 197_Smooth, in-between round.png
# 198_Disk, Edge-on, Rounded Bulge.png
# 199_Disk, Edge-on, Rounded Bulge.png
# 19_Disk, Face-on, Medium Spiral.png
# 1_Smooth, Completely round.png
# 200_Smooth, Completely round.png
# 201_Disk, Edge-on, Rounded Bulge.png
# 202_Disk, Face-on, Tight Spiral.png
# 203_Disk, Face-on, No Spiral.png
# 204_Smooth, Completely round.png
# 205_Smooth, Completely round.png
# 206_Smooth, Completely round.png
# 207_Disk, Edge-on, Rounded Bulge.png
# 208_Smooth, Completely round.png
# 209_Smooth, in-between round.png
# 20_Disk, Face-on, No Spiral.png
# 210_Smooth, in-between round.png
# 211_Disk, Face-on, No Spiral.png
# 212_Smooth, Completely round.png
# 213_Smooth, in-between round.png
# 214_Disk, Face-on, Medium Spiral.png
# 215_Disk, Face-on, Loose Spiral.png
# 216_Smooth, Completely round.png
# 217_Smooth, Completely round.png
# 218_Smooth, in-between round.png
# 219_Disk, Face-on, No Spiral.png
# 21_Smooth, Completely round.png
# 220_Disk, Face-on, No Spiral.png
# 221_Smooth, Completely round.png
# 222_Disk, Edge-on, No Bulge.png
# 223_Smooth, in-between round.png
# 224_Disk, Face-on, No Spiral.png
# 225_Disk, Face-on, No Spiral.png
# 226_Smooth, Completely round.png
# 227_Disk, Face-on, No Spiral.png
# 228_Smooth, in-between round.png
# 229_Smooth, Completely round.png
# 22_Disk, Face-on, Medium Spiral.png
# 230_Smooth, Completely round.png
# 231_Smooth, Completely round.png
# 232_Disk, Face-on, No Spiral.png
# 233_Smooth, in-between round.png
# 234_Smooth, Completely round.png
# 235_Disk, Face-on, Tight Spiral.png
# 236_Disk, Face-on, No Spiral.png
# 237_Disk, Face-on, No Spiral.png
# 238_Disk, Face-on, Tight Spiral.png
# 239_Smooth, Completely round.png
# 23_Disk, Face-on, Medium Spiral.png
# 240_Disk, Edge-on, Rounded Bulge.png
# 241_Disk, Face-on, No Spiral.png
# 242_Smooth, Completely round.png
# 243_Disk, Face-on, No Spiral.png
# 244_Smooth, Completely round.png
# 245_Smooth, in-between round.png
# 246_Smooth, Completely round.png
# 247_Smooth, Completely round.png
# 248_Smooth, Completely round.png
# 249_Smooth, Cigar shaped.png
# 24_Disk, Face-on, No Spiral.png
# 25_Smooth, in-between round.png
# 26_Disk, Edge-on, Rounded Bulge.png
# 27_Smooth, Completely round.png
# 28_Smooth, in-between round.png
# 29_Disk, Face-on, No Spiral.png
# 2_Disk, Face-on, No Spiral.png
# 30_Smooth, in-between round.png
# 31_Smooth, Completely round.png
# 32_Smooth, Completely round.png
# 33_Smooth, Completely round.png
# 34_Smooth, in-between round.png
# 35_Smooth, Completely round.png
# 36_Smooth, in-between round.png
# 37_Smooth, Completely round.png
# 38_Smooth, in-between round.png
# 39_Smooth, in-between round.png
# 3_Smooth, in-between round.png
# 40_Smooth, Completely round.png
# 41_Smooth, in-between round.png
# 42_Disk, Face-on, No Spiral.png
# 43_Disk, Edge-on, Rounded Bulge.png
# 44_Smooth, in-between round.png
# 45_Smooth, in-between round.png
# 46_Disk, Face-on, No Spiral.png
# 47_Smooth, in-between round.png
# 48_Disk, Face-on, No Spiral.png
# 49_Disk, Edge-on, No Bulge.png
# 4_Disk, Face-on, No Spiral.png
# 50_Disk, Face-on, Medium Spiral.png
# 51_Disk, Edge-on, No Bulge.png
# 52_Disk, Edge-on, No Bulge.png
# 53_Smooth, Completely round.png
# 54_Smooth, Cigar shaped.png
# 55_Disk, Face-on, Loose Spiral.png
# 56_Disk, Face-on, Loose Spiral.png
# 57_Smooth, in-between round.png
# 58_Disk, Face-on, No Spiral.png
# 59_Smooth, in-between round.png
# 5_Smooth, Completely round.png
# 60_Disk, Edge-on, Rounded Bulge.png
# 61_Disk, Edge-on, No Bulge.png
# 62_Smooth, in-between round.png
# 63_Disk, Face-on, Medium Spiral.png
# 64_Smooth, Completely round.png
# 65_Smooth, in-between round.png
# 66_Smooth, Completely round.png
# 67_Disk, Face-on, Medium Spiral.png
# 68_Smooth, Completely round.png
# 69_Smooth, in-between round.png
# 6_Disk, Face-on, Medium Spiral.png
# 70_Disk, Face-on, Tight Spiral.png
# 71_Smooth, Completely round.png
# 72_Smooth, Completely round.png
# 73_Smooth, in-between round.png
# 74_Disk, Edge-on, No Bulge.png
# 75_Smooth, Completely round.png
# 76_Disk, Face-on, No Spiral.png
# 77_Smooth, Completely round.png
# 78_Disk, Face-on, Medium Spiral.png
# 79_Disk, Face-on, Medium Spiral.png
# 7_Smooth, Completely round.png
# 80_Smooth, Completely round.png
# 81_Smooth, in-between round.png
# 82_Disk, Face-on, No Spiral.png
# 83_Smooth, in-between round.png
# 84_Smooth, Completely round.png
# 85_Smooth, in-between round.png
# 86_Smooth, Completely round.png
# 87_Disk, Face-on, No Spiral.png
# 88_Smooth, Completely round.png
# 89_Smooth, Cigar shaped.png
# 8_Disk, Edge-on, Rounded Bulge.png
# 90_Disk, Face-on, Medium Spiral.png
# 91_Disk, Face-on, Tight Spiral.png
# 92_Smooth, in-between round.png
# 93_Smooth, in-between round.png
# 94_Smooth, Completely round.png
# 95_Smooth, in-between round.png
# 96_Disk, Face-on, Tight Spiral.png
# 97_Disk, Face-on, Tight Spiral.png
# 98_Smooth, Completely round.png
# 99_Smooth, Completely round.png
# 9_Smooth, in-between round.png
# 0.png
# 1.png
# 10.png
# 100.png
# 101.png
# 102.png
# 103.png
# 104.png
# 105.png
# 106.png
# 107.png
# 108.png
# 109.png
# 11.png
# 110.png
# 111.png
# 112.png
# 113.png
# 114.png
# 115.png
# 116.png
# 117.png
# 118.png
# 119.png
# 12.png
# 120.png
# 121.png
# 122.png
# 123.png
# 124.png
# 125.png
# 126.png
# 127.png
# 128.png
# 129.png
# 13.png
# 130.png
# 131.png
# 132.png
# 133.png
# 134.png
# 135.png
# 136.png
# 137.png
# 138.png
# 139.png
# 14.png
# 140.png
# 141.png
# 142.png
# 143.png
# 144.png
# 145.png
# 146.png
# 147.png
# 148.png
# 149.png
# 15.png
# 150.png
# 151.png
# 152.png
# 153.png
# 154.png
# 155.png
# 156.png
# 157.png
# 158.png
# 159.png
# 16.png
# 160.png
# 161.png
# 162.png
# 163.png
# 164.png
# 165.png
# 166.png
# 167.png
# 168.png
# 169.png
# 17.png
# 170.png
# 171.png
# 172.png
# 173.png
# 174.png
# 175.png
# 176.png
# 177.png
# 178.png
# 179.png
# 18.png
# 180.png
# 181.png
# 182.png
# 183.png
# 184.png
# 185.png
# 186.png
# 187.png
# 188.png
# 189.png
# 19.png
# 190.png
# 191.png
# 192.png
# 193.png
# 194.png
# 195.png
# 196.png
# 197.png
# 198.png
# 199.png
# 2.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 3.png
# 30.png
# 31.png
# 32.png
# 33.png
# 34.png
# 35.png
# 36.png
# 37.png
# 38.png
# 39.png
# 4.png
# 40.png
# 41.png
# 42.png
# 43.png
# 44.png
# 45.png
# 46.png
# 47.png
# 48.png
# 49.png
# 5.png
# 50.png
# 51.png
# 52.png
# 53.png
# 54.png
# 55.png
# 56.png
# 57.png
# 58.png
# 59.png
# 6.png
# 60.png
# 61.png
# 62.png
# 63.png
# 64.png
# 65.png
# 66.png
# 67.png
# 68.png
# 69.png
# 7.png
# 70.png
# 71.png
# 72.png
# 73.png
# 74.png
# 75.png
# 76.png
# 77.png
# 78.png
# 79.png
# 8.png
# 80.png
# 81.png
# 82.png
# 83.png
# 84.png
# 85.png
# 86.png
# 87.png
# 88.png
# 89.png
# 9.png
# 90.png
# 91.png
# 92.png
# 93.png
# 94.png
# 95.png
# 96.png
# 97.png
# 98.png
# 99.png
# 0_A_Smooth, in-between round.png
# 0_B_Smooth, in-between round.png
# 0_C_Smooth, in-between round.png
# 0_D_Smooth, in-between round.png
# 0_E_Smooth, in-between round.png
# 0_F_Smooth, in-between round.png
# 100_A_Disk, Face-on, No Spiral.png
# 100_B_Disk, Face-on, No Spiral.png
# 100_C_Disk, Face-on, No Spiral.png
# 100_D_Disk, Face-on, No Spiral.png
# 100_E_Disk, Face-on, No Spiral.png
# 100_F_Disk, Face-on, No Spiral.png
# 101_A_Smooth, Completely round.png
# 101_B_Smooth, Completely round.png
# 101_C_Smooth, Completely round.png
# 101_D_Smooth, Completely round.png
# 101_E_Smooth, Completely round.png
# 101_F_Smooth, Completely round.png
# 102_A_Disk, Face-on, Loose Spiral.png
# 102_B_Disk, Face-on, Loose Spiral.png
# 102_C_Disk, Face-on, Loose Spiral.png
# 102_D_Disk, Face-on, Loose Spiral.png
# 102_E_Disk, Face-on, Loose Spiral.png
# 102_F_Disk, Face-on, Loose Spiral.png
# 103_A_Smooth, in-between round.png
# 103_B_Smooth, in-between round.png
# 103_C_Smooth, in-between round.png
# 103_D_Smooth, in-between round.png
# 103_E_Smooth, in-between round.png
# 103_F_Smooth, in-between round.png
# 104_A_Disk, Face-on, Medium Spiral.png
# 104_B_Disk, Face-on, Medium Spiral.png
# 104_C_Disk, Face-on, Medium Spiral.png
# 104_D_Disk, Face-on, Medium Spiral.png
# 104_E_Disk, Face-on, Medium Spiral.png
# 104_F_Disk, Face-on, Medium Spiral.png
# 105_A_Smooth, Completely round.png
# 105_B_Smooth, Completely round.png
# 105_C_Smooth, Completely round.png
# 105_D_Smooth, Completely round.png
# 105_E_Smooth, Completely round.png
# 105_F_Smooth, Completely round.png
# 106_A_Smooth, Completely round.png
# 106_B_Smooth, Completely round.png
# 106_C_Smooth, Completely round.png
# 106_D_Smooth, Completely round.png
# 106_E_Smooth, Completely round.png
# 106_F_Smooth, Completely round.png
# 107_A_Smooth, Completely round.png
# 107_B_Smooth, Completely round.png
# 107_C_Smooth, Completely round.png
# 107_D_Smooth, Completely round.png
# 107_E_Smooth, Completely round.png
# 107_F_Smooth, Completely round.png
# 108_A_Smooth, Completely round.png
# 108_B_Smooth, Completely round.png
# 108_C_Smooth, Completely round.png
# 108_D_Smooth, Completely round.png
# 108_E_Smooth, Completely round.png
# 108_F_Smooth, Completely round.png
# 109_A_Smooth, Completely round.png
# 109_B_Smooth, Completely round.png
# 109_C_Smooth, Completely round.png
# 109_D_Smooth, Completely round.png
# 109_E_Smooth, Completely round.png
# 109_F_Smooth, Completely round.png
# 10_A_Smooth, Completely round.png
# 10_B_Smooth, Completely round.png
# 10_C_Smooth, Completely round.png
# 10_D_Smooth, Completely round.png
# 10_E_Smooth, Completely round.png
# 10_F_Smooth, Completely round.png
# 110_A_Smooth, in-between round.png
# 110_B_Smooth, in-between round.png
# 110_C_Smooth, in-between round.png
# 110_D_Smooth, in-between round.png
# 110_E_Smooth, in-between round.png
# 110_F_Smooth, in-between round.png
# 111_A_Disk, Face-on, No Spiral.png
# 111_B_Disk, Face-on, No Spiral.png
# 111_C_Disk, Face-on, No Spiral.png
# 111_D_Disk, Face-on, No Spiral.png
# 111_E_Disk, Face-on, No Spiral.png
# 111_F_Disk, Face-on, No Spiral.png
# 112_A_Disk, Edge-on, Rounded Bulge.png
# 112_B_Disk, Edge-on, Rounded Bulge.png
# 112_C_Disk, Edge-on, Rounded Bulge.png
# 112_D_Disk, Edge-on, Rounded Bulge.png
# 112_E_Disk, Edge-on, Rounded Bulge.png
# 112_F_Disk, Edge-on, Rounded Bulge.png
# 113_A_Disk, Face-on, No Spiral.png
# 113_B_Disk, Face-on, No Spiral.png
# 113_C_Disk, Face-on, No Spiral.png
# 113_D_Disk, Face-on, No Spiral.png
# 113_E_Disk, Face-on, No Spiral.png
# 113_F_Disk, Face-on, No Spiral.png
# 114_A_Disk, Edge-on, Rounded Bulge.png
# 114_B_Disk, Edge-on, Rounded Bulge.png
# 114_C_Disk, Edge-on, Rounded Bulge.png
# 114_D_Disk, Edge-on, Rounded Bulge.png
# 114_E_Disk, Edge-on, Rounded Bulge.png
# 114_F_Disk, Edge-on, Rounded Bulge.png
# 115_A_Smooth, Completely round.png
# 115_B_Smooth, Completely round.png
# 115_C_Smooth, Completely round.png
# 115_D_Smooth, Completely round.png
# 115_E_Smooth, Completely round.png
# 115_F_Smooth, Completely round.png
# 116_A_Disk, Edge-on, Rounded Bulge.png
# 116_B_Disk, Edge-on, Rounded Bulge.png
# 116_C_Disk, Edge-on, Rounded Bulge.png
# 116_D_Disk, Edge-on, Rounded Bulge.png
# 116_E_Disk, Edge-on, Rounded Bulge.png
# 116_F_Disk, Edge-on, Rounded Bulge.png
# 117_A_Disk, Edge-on, Rounded Bulge.png
# 117_B_Disk, Edge-on, Rounded Bulge.png
# 117_C_Disk, Edge-on, Rounded Bulge.png
# 117_D_Disk, Edge-on, Rounded Bulge.png
# 117_E_Disk, Edge-on, Rounded Bulge.png
# 117_F_Disk, Edge-on, Rounded Bulge.png
# 118_A_Smooth, Completely round.png
# 118_B_Smooth, Completely round.png
# 118_C_Smooth, Completely round.png
# 118_D_Smooth, Completely round.png
# 118_E_Smooth, Completely round.png
# 118_F_Smooth, Completely round.png
# 119_A_Smooth, in-between round.png
# 119_B_Smooth, in-between round.png
# 119_C_Smooth, in-between round.png
# 119_D_Smooth, in-between round.png
# 119_E_Smooth, in-between round.png
# 119_F_Smooth, in-between round.png
# 11_A_Smooth, in-between round.png
# 11_B_Smooth, in-between round.png
# 11_C_Smooth, in-between round.png
# 11_D_Smooth, in-between round.png
# 11_E_Smooth, in-between round.png
# 11_F_Smooth, in-between round.png
# 120_A_Smooth, in-between round.png
# 120_B_Smooth, in-between round.png
# 120_C_Smooth, in-between round.png
# 120_D_Smooth, in-between round.png
# 120_E_Smooth, in-between round.png
# 120_F_Smooth, in-between round.png
# 121_A_Smooth, in-between round.png
# 121_B_Smooth, in-between round.png
# 121_C_Smooth, in-between round.png
# 121_D_Smooth, in-between round.png
# 121_E_Smooth, in-between round.png
# 121_F_Smooth, in-between round.png
# 122_A_Smooth, in-between round.png
# 122_B_Smooth, in-between round.png
# 122_C_Smooth, in-between round.png
# 122_D_Smooth, in-between round.png
# 122_E_Smooth, in-between round.png
# 122_F_Smooth, in-between round.png
# 123_A_Smooth, Completely round.png
# 123_B_Smooth, Completely round.png
# 123_C_Smooth, Completely round.png
# 123_D_Smooth, Completely round.png
# 123_E_Smooth, Completely round.png
# 123_F_Smooth, Completely round.png
# 124_A_Smooth, in-between round.png
# 124_B_Smooth, in-between round.png
# 124_C_Smooth, in-between round.png
# 124_D_Smooth, in-between round.png
# 124_E_Smooth, in-between round.png
# 124_F_Smooth, in-between round.png
# 125_A_Disk, Face-on, Tight Spiral.png
# 125_B_Disk, Face-on, Tight Spiral.png
# 125_C_Disk, Face-on, Tight Spiral.png
# 125_D_Disk, Face-on, Tight Spiral.png
# 125_E_Disk, Face-on, Tight Spiral.png
# 125_F_Disk, Face-on, Tight Spiral.png
# 126_A_Smooth, Completely round.png
# 126_B_Smooth, Completely round.png
# 126_C_Smooth, Completely round.png
# 126_D_Smooth, Completely round.png
# 126_E_Smooth, Completely round.png
# 126_F_Smooth, Completely round.png
# 127_A_Disk, Face-on, No Spiral.png
# 127_B_Disk, Face-on, No Spiral.png
# 127_C_Disk, Face-on, No Spiral.png
# 127_D_Disk, Face-on, No Spiral.png
# 127_E_Disk, Face-on, No Spiral.png
# 127_F_Disk, Face-on, No Spiral.png
# 128_A_Smooth, Completely round.png
# 128_B_Smooth, Completely round.png
# 128_C_Smooth, Completely round.png
# 128_D_Smooth, Completely round.png
# 128_E_Smooth, Completely round.png
# 128_F_Smooth, Completely round.png
# 129_A_Smooth, Completely round.png
# 129_B_Smooth, Completely round.png
# 129_C_Smooth, Completely round.png
# 129_D_Smooth, Completely round.png
# 129_E_Smooth, Completely round.png
# 129_F_Smooth, Completely round.png
# 12_A_Smooth, Completely round.png
# 12_B_Smooth, Completely round.png
# 12_C_Smooth, Completely round.png
# 12_D_Smooth, Completely round.png
# 12_E_Smooth, Completely round.png
# 12_F_Smooth, Completely round.png
# 130_A_Smooth, in-between round.png
# 130_B_Smooth, in-between round.png
# 130_C_Smooth, in-between round.png
# 130_D_Smooth, in-between round.png
# 130_E_Smooth, in-between round.png
# 130_F_Smooth, in-between round.png
# 131_A_Smooth, Completely round.png
# 131_B_Smooth, Completely round.png
# 131_C_Smooth, Completely round.png
# 131_D_Smooth, Completely round.png
# 131_E_Smooth, Completely round.png
# 131_F_Smooth, Completely round.png
# 132_A_Smooth, in-between round.png
# 132_B_Smooth, in-between round.png
# 132_C_Smooth, in-between round.png
# 132_D_Smooth, in-between round.png
# 132_E_Smooth, in-between round.png
# 132_F_Smooth, in-between round.png
# 133_A_Smooth, in-between round.png
# 133_B_Smooth, in-between round.png
# 133_C_Smooth, in-between round.png
# 133_D_Smooth, in-between round.png
# 133_E_Smooth, in-between round.png
# 133_F_Smooth, in-between round.png
# 134_A_Smooth, in-between round.png
# 134_B_Smooth, in-between round.png
# 134_C_Smooth, in-between round.png
# 134_D_Smooth, in-between round.png
# 134_E_Smooth, in-between round.png
# 134_F_Smooth, in-between round.png
# 135_A_Smooth, Cigar shaped.png
# 135_B_Smooth, Cigar shaped.png
# 135_C_Smooth, Cigar shaped.png
# 135_D_Smooth, Cigar shaped.png
# 135_E_Smooth, Cigar shaped.png
# 135_F_Smooth, Cigar shaped.png
# 136_A_Smooth, in-between round.png
# 136_B_Smooth, in-between round.png
# 136_C_Smooth, in-between round.png
# 136_D_Smooth, in-between round.png
# 136_E_Smooth, in-between round.png
# 136_F_Smooth, in-between round.png
# 137_A_Smooth, in-between round.png
# 137_B_Smooth, in-between round.png
# 137_C_Smooth, in-between round.png
# 137_D_Smooth, in-between round.png
# 137_E_Smooth, in-between round.png
# 137_F_Smooth, in-between round.png
# 138_A_Smooth, in-between round.png
# 138_B_Smooth, in-between round.png
# 138_C_Smooth, in-between round.png
# 138_D_Smooth, in-between round.png
# 138_E_Smooth, in-between round.png
# 138_F_Smooth, in-between round.png
# 139_A_Disk, Edge-on, No Bulge.png
# 139_B_Disk, Edge-on, No Bulge.png
# 139_C_Disk, Edge-on, No Bulge.png
# 139_D_Disk, Edge-on, No Bulge.png
# 139_E_Disk, Edge-on, No Bulge.png
# 139_F_Disk, Edge-on, No Bulge.png
# 13_A_Smooth, in-between round.png
# 13_B_Smooth, in-between round.png
# 13_C_Smooth, in-between round.png
# 13_D_Smooth, in-between round.png
# 13_E_Smooth, in-between round.png
# 13_F_Smooth, in-between round.png
# 140_A_Smooth, in-between round.png
# 140_B_Smooth, in-between round.png
# 140_C_Smooth, in-between round.png
# 140_D_Smooth, in-between round.png
# 140_E_Smooth, in-between round.png
# 140_F_Smooth, in-between round.png
# 141_A_Smooth, Completely round.png
# 141_B_Smooth, Completely round.png
# 141_C_Smooth, Completely round.png
# 141_D_Smooth, Completely round.png
# 141_E_Smooth, Completely round.png
# 141_F_Smooth, Completely round.png
# 142_A_Disk, Face-on, Medium Spiral.png
# 142_B_Disk, Face-on, Medium Spiral.png
# 142_C_Disk, Face-on, Medium Spiral.png
# 142_D_Disk, Face-on, Medium Spiral.png
# 142_E_Disk, Face-on, Medium Spiral.png
# 142_F_Disk, Face-on, Medium Spiral.png
# 143_A_Smooth, Completely round.png
# 143_B_Smooth, Completely round.png
# 143_C_Smooth, Completely round.png
# 143_D_Smooth, Completely round.png
# 143_E_Smooth, Completely round.png
# 143_F_Smooth, Completely round.png
# 144_A_Disk, Face-on, Medium Spiral.png
# 144_B_Disk, Face-on, Medium Spiral.png
# 144_C_Disk, Face-on, Medium Spiral.png
# 144_D_Disk, Face-on, Medium Spiral.png
# 144_E_Disk, Face-on, Medium Spiral.png
# 144_F_Disk, Face-on, Medium Spiral.png
# 145_A_Smooth, in-between round.png
# 145_B_Smooth, in-between round.png
# 145_C_Smooth, in-between round.png
# 145_D_Smooth, in-between round.png
# 145_E_Smooth, in-between round.png
# 145_F_Smooth, in-between round.png
# 146_A_Smooth, Completely round.png
# 146_B_Smooth, Completely round.png
# 146_C_Smooth, Completely round.png
# 146_D_Smooth, Completely round.png
# 146_E_Smooth, Completely round.png
# 146_F_Smooth, Completely round.png
# 147_A_Smooth, in-between round.png
# 147_B_Smooth, in-between round.png
# 147_C_Smooth, in-between round.png
# 147_D_Smooth, in-between round.png
# 147_E_Smooth, in-between round.png
# 147_F_Smooth, in-between round.png
# 148_A_Smooth, in-between round.png
# 148_B_Smooth, in-between round.png
# 148_C_Smooth, in-between round.png
# 148_D_Smooth, in-between round.png
# 148_E_Smooth, in-between round.png
# 148_F_Smooth, in-between round.png
# 149_A_Disk, Face-on, Loose Spiral.png
# 149_B_Disk, Face-on, Loose Spiral.png
# 149_C_Disk, Face-on, Loose Spiral.png
# 149_D_Disk, Face-on, Loose Spiral.png
# 149_E_Disk, Face-on, Loose Spiral.png
# 149_F_Disk, Face-on, Loose Spiral.png
# 14_A_Smooth, Completely round.png
# 14_B_Smooth, Completely round.png
# 14_C_Smooth, Completely round.png
# 14_D_Smooth, Completely round.png
# 14_E_Smooth, Completely round.png
# 14_F_Smooth, Completely round.png
# 150_A_Disk, Face-on, Medium Spiral.png
# 150_B_Disk, Face-on, Medium Spiral.png
# 150_C_Disk, Face-on, Medium Spiral.png
# 150_D_Disk, Face-on, Medium Spiral.png
# 150_E_Disk, Face-on, Medium Spiral.png
# 150_F_Disk, Face-on, Medium Spiral.png
# 151_A_Smooth, Completely round.png
# 151_B_Smooth, Completely round.png
# 151_C_Smooth, Completely round.png
# 151_D_Smooth, Completely round.png
# 151_E_Smooth, Completely round.png
# 151_F_Smooth, Completely round.png
# 152_A_Smooth, Completely round.png
# 152_B_Smooth, Completely round.png
# 152_C_Smooth, Completely round.png
# 152_D_Smooth, Completely round.png
# 152_E_Smooth, Completely round.png
# 152_F_Smooth, Completely round.png
# 153_A_Smooth, Completely round.png
# 153_B_Smooth, Completely round.png
# 153_C_Smooth, Completely round.png
# 153_D_Smooth, Completely round.png
# 153_E_Smooth, Completely round.png
# 153_F_Smooth, Completely round.png
# 154_A_Smooth, Completely round.png
# 154_B_Smooth, Completely round.png
# 154_C_Smooth, Completely round.png
# 154_D_Smooth, Completely round.png
# 154_E_Smooth, Completely round.png
# 154_F_Smooth, Completely round.png
# 155_A_Smooth, Completely round.png
# 155_B_Smooth, Completely round.png
# 155_C_Smooth, Completely round.png
# 155_D_Smooth, Completely round.png
# 155_E_Smooth, Completely round.png
# 155_F_Smooth, Completely round.png
# 156_A_Smooth, Completely round.png
# 156_B_Smooth, Completely round.png
# 156_C_Smooth, Completely round.png
# 156_D_Smooth, Completely round.png
# 156_E_Smooth, Completely round.png
# 156_F_Smooth, Completely round.png
# 157_A_Disk, Face-on, No Spiral.png
# 157_B_Disk, Face-on, No Spiral.png
# 157_C_Disk, Face-on, No Spiral.png
# 157_D_Disk, Face-on, No Spiral.png
# 157_E_Disk, Face-on, No Spiral.png
# 157_F_Disk, Face-on, No Spiral.png
# 158_A_Disk, Edge-on, Rounded Bulge.png
# 158_B_Disk, Edge-on, Rounded Bulge.png
# 158_C_Disk, Edge-on, Rounded Bulge.png
# 158_D_Disk, Edge-on, Rounded Bulge.png
# 158_E_Disk, Edge-on, Rounded Bulge.png
# 158_F_Disk, Edge-on, Rounded Bulge.png
# 159_A_Smooth, Completely round.png
# 159_B_Smooth, Completely round.png
# 159_C_Smooth, Completely round.png
# 159_D_Smooth, Completely round.png
# 159_E_Smooth, Completely round.png
# 159_F_Smooth, Completely round.png
# 15_A_Disk, Face-on, No Spiral.png
# 15_B_Disk, Face-on, No Spiral.png
# 15_C_Disk, Face-on, No Spiral.png
# 15_D_Disk, Face-on, No Spiral.png
# 15_E_Disk, Face-on, No Spiral.png
# 15_F_Disk, Face-on, No Spiral.png
# 160_A_Disk, Face-on, Loose Spiral.png
# 160_B_Disk, Face-on, Loose Spiral.png
# 160_C_Disk, Face-on, Loose Spiral.png
# 160_D_Disk, Face-on, Loose Spiral.png
# 160_E_Disk, Face-on, Loose Spiral.png
# 160_F_Disk, Face-on, Loose Spiral.png
# 161_A_Smooth, Completely round.png
# 161_B_Smooth, Completely round.png
# 161_C_Smooth, Completely round.png
# 161_D_Smooth, Completely round.png
# 161_E_Smooth, Completely round.png
# 161_F_Smooth, Completely round.png
# 162_A_Smooth, Completely round.png
# 162_B_Smooth, Completely round.png
# 162_C_Smooth, Completely round.png
# 162_D_Smooth, Completely round.png
# 162_E_Smooth, Completely round.png
# 162_F_Smooth, Completely round.png
# 163_A_Smooth, in-between round.png
# 163_B_Smooth, in-between round.png
# 163_C_Smooth, in-between round.png
# 163_D_Smooth, in-between round.png
# 163_E_Smooth, in-between round.png
# 163_F_Smooth, in-between round.png
# 164_A_Smooth, Completely round.png
# 164_B_Smooth, Completely round.png
# 164_C_Smooth, Completely round.png
# 164_D_Smooth, Completely round.png
# 164_E_Smooth, Completely round.png
# 164_F_Smooth, Completely round.png
# 165_A_Disk, Face-on, No Spiral.png
# 165_B_Disk, Face-on, No Spiral.png
# 165_C_Disk, Face-on, No Spiral.png
# 165_D_Disk, Face-on, No Spiral.png
# 165_E_Disk, Face-on, No Spiral.png
# 165_F_Disk, Face-on, No Spiral.png
# 166_A_Disk, Face-on, No Spiral.png
# 166_B_Disk, Face-on, No Spiral.png
# 166_C_Disk, Face-on, No Spiral.png
# 166_D_Disk, Face-on, No Spiral.png
# 166_E_Disk, Face-on, No Spiral.png
# 166_F_Disk, Face-on, No Spiral.png
# 167_A_Disk, Edge-on, Rounded Bulge.png
# 167_B_Disk, Edge-on, Rounded Bulge.png
# 167_C_Disk, Edge-on, Rounded Bulge.png
# 167_D_Disk, Edge-on, Rounded Bulge.png
# 167_E_Disk, Edge-on, Rounded Bulge.png
# 167_F_Disk, Edge-on, Rounded Bulge.png
# 168_A_Smooth, in-between round.png
# 168_B_Smooth, in-between round.png
# 168_C_Smooth, in-between round.png
# 168_D_Smooth, in-between round.png
# 168_E_Smooth, in-between round.png
# 168_F_Smooth, in-between round.png
# 169_A_Disk, Face-on, No Spiral.png
# 169_B_Disk, Face-on, No Spiral.png
# 169_C_Disk, Face-on, No Spiral.png
# 169_D_Disk, Face-on, No Spiral.png
# 169_E_Disk, Face-on, No Spiral.png
# 169_F_Disk, Face-on, No Spiral.png
# 16_A_Disk, Face-on, No Spiral.png
# 16_B_Disk, Face-on, No Spiral.png
# 16_C_Disk, Face-on, No Spiral.png
# 16_D_Disk, Face-on, No Spiral.png
# 16_E_Disk, Face-on, No Spiral.png
# 16_F_Disk, Face-on, No Spiral.png
# 170_A_Smooth, Completely round.png
# 170_B_Smooth, Completely round.png
# 170_C_Smooth, Completely round.png
# 170_D_Smooth, Completely round.png
# 170_E_Smooth, Completely round.png
# 170_F_Smooth, Completely round.png
# 171_A_Smooth, Completely round.png
# 171_B_Smooth, Completely round.png
# 171_C_Smooth, Completely round.png
# 171_D_Smooth, Completely round.png
# 171_E_Smooth, Completely round.png
# 171_F_Smooth, Completely round.png
# 172_A_Disk, Face-on, No Spiral.png
# 172_B_Disk, Face-on, No Spiral.png
# 172_C_Disk, Face-on, No Spiral.png
# 172_D_Disk, Face-on, No Spiral.png
# 172_E_Disk, Face-on, No Spiral.png
# 172_F_Disk, Face-on, No Spiral.png
# 173_A_Smooth, Completely round.png
# 173_B_Smooth, Completely round.png
# 173_C_Smooth, Completely round.png
# 173_D_Smooth, Completely round.png
# 173_E_Smooth, Completely round.png
# 173_F_Smooth, Completely round.png
# 174_A_Disk, Face-on, Loose Spiral.png
# 174_B_Disk, Face-on, Loose Spiral.png
# 174_C_Disk, Face-on, Loose Spiral.png
# 174_D_Disk, Face-on, Loose Spiral.png
# 174_E_Disk, Face-on, Loose Spiral.png
# 174_F_Disk, Face-on, Loose Spiral.png
# 175_A_Smooth, in-between round.png
# 175_B_Smooth, in-between round.png
# 175_C_Smooth, in-between round.png
# 175_D_Smooth, in-between round.png
# 175_E_Smooth, in-between round.png
# 175_F_Smooth, in-between round.png
# 176_A_Disk, Face-on, No Spiral.png
# 176_B_Disk, Face-on, No Spiral.png
# 176_C_Disk, Face-on, No Spiral.png
# 176_D_Disk, Face-on, No Spiral.png
# 176_E_Disk, Face-on, No Spiral.png
# 176_F_Disk, Face-on, No Spiral.png
# 177_A_Smooth, in-between round.png
# 177_B_Smooth, in-between round.png
# 177_C_Smooth, in-between round.png
# 177_D_Smooth, in-between round.png
# 177_E_Smooth, in-between round.png
# 177_F_Smooth, in-between round.png
# 178_A_Disk, Face-on, No Spiral.png
# 178_B_Disk, Face-on, No Spiral.png
# 178_C_Disk, Face-on, No Spiral.png
# 178_D_Disk, Face-on, No Spiral.png
# 178_E_Disk, Face-on, No Spiral.png
# 178_F_Disk, Face-on, No Spiral.png
# 179_A_Disk, Face-on, Tight Spiral.png
# 179_B_Disk, Face-on, Tight Spiral.png
# 179_C_Disk, Face-on, Tight Spiral.png
# 179_D_Disk, Face-on, Tight Spiral.png
# 179_E_Disk, Face-on, Tight Spiral.png
# 179_F_Disk, Face-on, Tight Spiral.png
# 17_A_Smooth, in-between round.png
# 17_B_Smooth, in-between round.png
# 17_C_Smooth, in-between round.png
# 17_D_Smooth, in-between round.png
# 17_E_Smooth, in-between round.png
# 17_F_Smooth, in-between round.png
# 180_A_Smooth, in-between round.png
# 180_B_Smooth, in-between round.png
# 180_C_Smooth, in-between round.png
# 180_D_Smooth, in-between round.png
# 180_E_Smooth, in-between round.png
# 180_F_Smooth, in-between round.png
# 181_A_Disk, Face-on, No Spiral.png
# 181_B_Disk, Face-on, No Spiral.png
# 181_C_Disk, Face-on, No Spiral.png
# 181_D_Disk, Face-on, No Spiral.png
# 181_E_Disk, Face-on, No Spiral.png
# 181_F_Disk, Face-on, No Spiral.png
# 182_A_Smooth, in-between round.png
# 182_B_Smooth, in-between round.png
# 182_C_Smooth, in-between round.png
# 182_D_Smooth, in-between round.png
# 182_E_Smooth, in-between round.png
# 182_F_Smooth, in-between round.png
# 183_A_Smooth, Completely round.png
# 183_B_Smooth, Completely round.png
# 183_C_Smooth, Completely round.png
# 183_D_Smooth, Completely round.png
# 183_E_Smooth, Completely round.png
# 183_F_Smooth, Completely round.png
# 184_A_Smooth, Completely round.png
# 184_B_Smooth, Completely round.png
# 184_C_Smooth, Completely round.png
# 184_D_Smooth, Completely round.png
# 184_E_Smooth, Completely round.png
# 184_F_Smooth, Completely round.png
# 185_A_Smooth, Completely round.png
# 185_B_Smooth, Completely round.png
# 185_C_Smooth, Completely round.png
# 185_D_Smooth, Completely round.png
# 185_E_Smooth, Completely round.png
# 185_F_Smooth, Completely round.png
# 186_A_Disk, Face-on, No Spiral.png
# 186_B_Disk, Face-on, No Spiral.png
# 186_C_Disk, Face-on, No Spiral.png
# 186_D_Disk, Face-on, No Spiral.png
# 186_E_Disk, Face-on, No Spiral.png
# 186_F_Disk, Face-on, No Spiral.png
# 187_A_Smooth, in-between round.png
# 187_B_Smooth, in-between round.png
# 187_C_Smooth, in-between round.png
# 187_D_Smooth, in-between round.png
# 187_E_Smooth, in-between round.png
# 187_F_Smooth, in-between round.png
# 188_A_Smooth, in-between round.png
# 188_B_Smooth, in-between round.png
# 188_C_Smooth, in-between round.png
# 188_D_Smooth, in-between round.png
# 188_E_Smooth, in-between round.png
# 188_F_Smooth, in-between round.png
# 189_A_Disk, Face-on, Medium Spiral.png
# 189_B_Disk, Face-on, Medium Spiral.png
# 189_C_Disk, Face-on, Medium Spiral.png
# 189_D_Disk, Face-on, Medium Spiral.png
# 189_E_Disk, Face-on, Medium Spiral.png
# 189_F_Disk, Face-on, Medium Spiral.png
# 18_A_Smooth, Completely round.png
# 18_B_Smooth, Completely round.png
# 18_C_Smooth, Completely round.png
# 18_D_Smooth, Completely round.png
# 18_E_Smooth, Completely round.png
# 18_F_Smooth, Completely round.png
# 190_A_Smooth, in-between round.png
# 190_B_Smooth, in-between round.png
# 190_C_Smooth, in-between round.png
# 190_D_Smooth, in-between round.png
# 190_E_Smooth, in-between round.png
# 190_F_Smooth, in-between round.png
# 191_A_Smooth, in-between round.png
# 191_B_Smooth, in-between round.png
# 191_C_Smooth, in-between round.png
# 191_D_Smooth, in-between round.png
# 191_E_Smooth, in-between round.png
# 191_F_Smooth, in-between round.png
# 192_A_Smooth, Completely round.png
# 192_B_Smooth, Completely round.png
# 192_C_Smooth, Completely round.png
# 192_D_Smooth, Completely round.png
# 192_E_Smooth, Completely round.png
# 192_F_Smooth, Completely round.png
# 193_A_Disk, Edge-on, No Bulge.png
# 193_B_Disk, Edge-on, No Bulge.png
# 193_C_Disk, Edge-on, No Bulge.png
# 193_D_Disk, Edge-on, No Bulge.png
# 193_E_Disk, Edge-on, No Bulge.png
# 193_F_Disk, Edge-on, No Bulge.png
# 194_A_Smooth, Completely round.png
# 194_B_Smooth, Completely round.png
# 194_C_Smooth, Completely round.png
# 194_D_Smooth, Completely round.png
# 194_E_Smooth, Completely round.png
# 194_F_Smooth, Completely round.png
# 195_A_Smooth, Completely round.png
# 195_B_Smooth, Completely round.png
# 195_C_Smooth, Completely round.png
# 195_D_Smooth, Completely round.png
# 195_E_Smooth, Completely round.png
# 195_F_Smooth, Completely round.png
# 196_A_Smooth, Completely round.png
# 196_B_Smooth, Completely round.png
# 196_C_Smooth, Completely round.png
# 196_D_Smooth, Completely round.png
# 196_E_Smooth, Completely round.png
# 196_F_Smooth, Completely round.png
# 197_A_Smooth, in-between round.png
# 197_B_Smooth, in-between round.png
# 197_C_Smooth, in-between round.png
# 197_D_Smooth, in-between round.png
# 197_E_Smooth, in-between round.png
# 197_F_Smooth, in-between round.png
# 198_A_Disk, Edge-on, Rounded Bulge.png
# 198_B_Disk, Edge-on, Rounded Bulge.png
# 198_C_Disk, Edge-on, Rounded Bulge.png
# 198_D_Disk, Edge-on, Rounded Bulge.png
# 198_E_Disk, Edge-on, Rounded Bulge.png
# 198_F_Disk, Edge-on, Rounded Bulge.png
# 199_A_Disk, Edge-on, Rounded Bulge.png
# 199_B_Disk, Edge-on, Rounded Bulge.png
# 199_C_Disk, Edge-on, Rounded Bulge.png
# 199_D_Disk, Edge-on, Rounded Bulge.png
# 199_E_Disk, Edge-on, Rounded Bulge.png
# 199_F_Disk, Edge-on, Rounded Bulge.png
# 19_A_Disk, Face-on, Medium Spiral.png
# 19_B_Disk, Face-on, Medium Spiral.png
# 19_C_Disk, Face-on, Medium Spiral.png
# 19_D_Disk, Face-on, Medium Spiral.png
# 19_E_Disk, Face-on, Medium Spiral.png
# 19_F_Disk, Face-on, Medium Spiral.png
# 1_A_Smooth, Completely round.png
# 1_B_Smooth, Completely round.png
# 1_C_Smooth, Completely round.png
# 1_D_Smooth, Completely round.png
# 1_E_Smooth, Completely round.png
# 1_F_Smooth, Completely round.png
# 200_A_Smooth, Completely round.png
# 200_B_Smooth, Completely round.png
# 200_C_Smooth, Completely round.png
# 200_D_Smooth, Completely round.png
# 200_E_Smooth, Completely round.png
# 200_F_Smooth, Completely round.png
# 201_A_Disk, Edge-on, Rounded Bulge.png
# 201_B_Disk, Edge-on, Rounded Bulge.png
# 201_C_Disk, Edge-on, Rounded Bulge.png
# 201_D_Disk, Edge-on, Rounded Bulge.png
# 201_E_Disk, Edge-on, Rounded Bulge.png
# 201_F_Disk, Edge-on, Rounded Bulge.png
# 202_A_Disk, Face-on, Tight Spiral.png
# 202_B_Disk, Face-on, Tight Spiral.png
# 202_C_Disk, Face-on, Tight Spiral.png
# 202_D_Disk, Face-on, Tight Spiral.png
# 202_E_Disk, Face-on, Tight Spiral.png
# 202_F_Disk, Face-on, Tight Spiral.png
# 203_A_Disk, Face-on, No Spiral.png
# 203_B_Disk, Face-on, No Spiral.png
# 203_C_Disk, Face-on, No Spiral.png
# 203_D_Disk, Face-on, No Spiral.png
# 203_E_Disk, Face-on, No Spiral.png
# 203_F_Disk, Face-on, No Spiral.png
# 204_A_Smooth, Completely round.png
# 204_B_Smooth, Completely round.png
# 204_C_Smooth, Completely round.png
# 204_D_Smooth, Completely round.png
# 204_E_Smooth, Completely round.png
# 204_F_Smooth, Completely round.png
# 205_A_Smooth, Completely round.png
# 205_B_Smooth, Completely round.png
# 205_C_Smooth, Completely round.png
# 205_D_Smooth, Completely round.png
# 205_E_Smooth, Completely round.png
# 205_F_Smooth, Completely round.png
# 206_A_Smooth, Completely round.png
# 206_B_Smooth, Completely round.png
# 206_C_Smooth, Completely round.png
# 206_D_Smooth, Completely round.png
# 206_E_Smooth, Completely round.png
# 206_F_Smooth, Completely round.png
# 207_A_Disk, Edge-on, Rounded Bulge.png
# 207_B_Disk, Edge-on, Rounded Bulge.png
# 207_C_Disk, Edge-on, Rounded Bulge.png
# 207_D_Disk, Edge-on, Rounded Bulge.png
# 207_E_Disk, Edge-on, Rounded Bulge.png
# 207_F_Disk, Edge-on, Rounded Bulge.png
# 208_A_Smooth, Completely round.png
# 208_B_Smooth, Completely round.png
# 208_C_Smooth, Completely round.png
# 208_D_Smooth, Completely round.png
# 208_E_Smooth, Completely round.png
# 208_F_Smooth, Completely round.png
# 209_A_Smooth, in-between round.png
# 209_B_Smooth, in-between round.png
# 209_C_Smooth, in-between round.png
# 209_D_Smooth, in-between round.png
# 209_E_Smooth, in-between round.png
# 209_F_Smooth, in-between round.png
# 20_A_Disk, Face-on, No Spiral.png
# 20_B_Disk, Face-on, No Spiral.png
# 20_C_Disk, Face-on, No Spiral.png
# 20_D_Disk, Face-on, No Spiral.png
# 20_E_Disk, Face-on, No Spiral.png
# 20_F_Disk, Face-on, No Spiral.png
# 210_A_Smooth, in-between round.png
# 210_B_Smooth, in-between round.png
# 210_C_Smooth, in-between round.png
# 210_D_Smooth, in-between round.png
# 210_E_Smooth, in-between round.png
# 210_F_Smooth, in-between round.png
# 211_A_Disk, Face-on, No Spiral.png
# 211_B_Disk, Face-on, No Spiral.png
# 211_C_Disk, Face-on, No Spiral.png
# 211_D_Disk, Face-on, No Spiral.png
# 211_E_Disk, Face-on, No Spiral.png
# 211_F_Disk, Face-on, No Spiral.png
# 212_A_Smooth, Completely round.png
# 212_B_Smooth, Completely round.png
# 212_C_Smooth, Completely round.png
# 212_D_Smooth, Completely round.png
# 212_E_Smooth, Completely round.png
# 212_F_Smooth, Completely round.png
# 213_A_Smooth, in-between round.png
# 213_B_Smooth, in-between round.png
# 213_C_Smooth, in-between round.png
# 213_D_Smooth, in-between round.png
# 213_E_Smooth, in-between round.png
# 213_F_Smooth, in-between round.png
# 214_A_Disk, Face-on, Medium Spiral.png
# 214_B_Disk, Face-on, Medium Spiral.png
# 214_C_Disk, Face-on, Medium Spiral.png
# 214_D_Disk, Face-on, Medium Spiral.png
# 214_E_Disk, Face-on, Medium Spiral.png
# 214_F_Disk, Face-on, Medium Spiral.png
# 215_A_Disk, Face-on, Loose Spiral.png
# 215_B_Disk, Face-on, Loose Spiral.png
# 215_C_Disk, Face-on, Loose Spiral.png
# 215_D_Disk, Face-on, Loose Spiral.png
# 215_E_Disk, Face-on, Loose Spiral.png
# 215_F_Disk, Face-on, Loose Spiral.png
# 216_A_Smooth, Completely round.png
# 216_B_Smooth, Completely round.png
# 216_C_Smooth, Completely round.png
# 216_D_Smooth, Completely round.png
# 216_E_Smooth, Completely round.png
# 216_F_Smooth, Completely round.png
# 217_A_Smooth, Completely round.png
# 217_B_Smooth, Completely round.png
# 217_C_Smooth, Completely round.png
# 217_D_Smooth, Completely round.png
# 217_E_Smooth, Completely round.png
# 217_F_Smooth, Completely round.png
# 218_A_Smooth, in-between round.png
# 218_B_Smooth, in-between round.png
# 218_C_Smooth, in-between round.png
# 218_D_Smooth, in-between round.png
# 218_E_Smooth, in-between round.png
# 218_F_Smooth, in-between round.png
# 219_A_Disk, Face-on, No Spiral.png
# 219_B_Disk, Face-on, No Spiral.png
# 219_C_Disk, Face-on, No Spiral.png
# 219_D_Disk, Face-on, No Spiral.png
# 219_E_Disk, Face-on, No Spiral.png
# 219_F_Disk, Face-on, No Spiral.png
# 21_A_Smooth, Completely round.png
# 21_B_Smooth, Completely round.png
# 21_C_Smooth, Completely round.png
# 21_D_Smooth, Completely round.png
# 21_E_Smooth, Completely round.png
# 21_F_Smooth, Completely round.png
# 220_A_Disk, Face-on, No Spiral.png
# 220_B_Disk, Face-on, No Spiral.png
# 220_C_Disk, Face-on, No Spiral.png
# 220_D_Disk, Face-on, No Spiral.png
# 220_E_Disk, Face-on, No Spiral.png
# 220_F_Disk, Face-on, No Spiral.png
# 221_A_Smooth, Completely round.png
# 221_B_Smooth, Completely round.png
# 221_C_Smooth, Completely round.png
# 221_D_Smooth, Completely round.png
# 221_E_Smooth, Completely round.png
# 221_F_Smooth, Completely round.png
# 222_A_Disk, Edge-on, No Bulge.png
# 222_B_Disk, Edge-on, No Bulge.png
# 222_C_Disk, Edge-on, No Bulge.png
# 222_D_Disk, Edge-on, No Bulge.png
# 222_E_Disk, Edge-on, No Bulge.png
# 222_F_Disk, Edge-on, No Bulge.png
# 223_A_Smooth, in-between round.png
# 223_B_Smooth, in-between round.png
# 223_C_Smooth, in-between round.png
# 223_D_Smooth, in-between round.png
# 223_E_Smooth, in-between round.png
# 223_F_Smooth, in-between round.png
# 224_A_Disk, Face-on, No Spiral.png
# 224_B_Disk, Face-on, No Spiral.png
# 224_C_Disk, Face-on, No Spiral.png
# 224_D_Disk, Face-on, No Spiral.png
# 224_E_Disk, Face-on, No Spiral.png
# 224_F_Disk, Face-on, No Spiral.png
# 225_A_Disk, Face-on, No Spiral.png
# 225_B_Disk, Face-on, No Spiral.png
# 225_C_Disk, Face-on, No Spiral.png
# 225_D_Disk, Face-on, No Spiral.png
# 225_E_Disk, Face-on, No Spiral.png
# 225_F_Disk, Face-on, No Spiral.png
# 226_A_Smooth, Completely round.png
# 226_B_Smooth, Completely round.png
# 226_C_Smooth, Completely round.png
# 226_D_Smooth, Completely round.png
# 226_E_Smooth, Completely round.png
# 226_F_Smooth, Completely round.png
# 227_A_Disk, Face-on, No Spiral.png
# 227_B_Disk, Face-on, No Spiral.png
# 227_C_Disk, Face-on, No Spiral.png
# 227_D_Disk, Face-on, No Spiral.png
# 227_E_Disk, Face-on, No Spiral.png
# 227_F_Disk, Face-on, No Spiral.png
# 228_A_Smooth, in-between round.png
# 228_B_Smooth, in-between round.png
# 228_C_Smooth, in-between round.png
# 228_D_Smooth, in-between round.png
# 228_E_Smooth, in-between round.png
# 228_F_Smooth, in-between round.png
# 229_A_Smooth, Completely round.png
# 229_B_Smooth, Completely round.png
# 229_C_Smooth, Completely round.png
# 229_D_Smooth, Completely round.png
# 229_E_Smooth, Completely round.png
# 229_F_Smooth, Completely round.png
# 22_A_Disk, Face-on, Medium Spiral.png
# 22_B_Disk, Face-on, Medium Spiral.png
# 22_C_Disk, Face-on, Medium Spiral.png
# 22_D_Disk, Face-on, Medium Spiral.png
# 22_E_Disk, Face-on, Medium Spiral.png
# 22_F_Disk, Face-on, Medium Spiral.png
# 230_A_Smooth, Completely round.png
# 230_B_Smooth, Completely round.png
# 230_C_Smooth, Completely round.png
# 230_D_Smooth, Completely round.png
# 230_E_Smooth, Completely round.png
# 230_F_Smooth, Completely round.png
# 231_A_Smooth, Completely round.png
# 231_B_Smooth, Completely round.png
# 231_C_Smooth, Completely round.png
# 231_D_Smooth, Completely round.png
# 231_E_Smooth, Completely round.png
# 231_F_Smooth, Completely round.png
# 232_A_Disk, Face-on, No Spiral.png
# 232_B_Disk, Face-on, No Spiral.png
# 232_C_Disk, Face-on, No Spiral.png
# 232_D_Disk, Face-on, No Spiral.png
# 232_E_Disk, Face-on, No Spiral.png
# 232_F_Disk, Face-on, No Spiral.png
# 233_A_Smooth, in-between round.png
# 233_B_Smooth, in-between round.png
# 233_C_Smooth, in-between round.png
# 233_D_Smooth, in-between round.png
# 233_E_Smooth, in-between round.png
# 233_F_Smooth, in-between round.png
# 234_A_Smooth, Completely round.png
# 234_B_Smooth, Completely round.png
# 234_C_Smooth, Completely round.png
# 234_D_Smooth, Completely round.png
# 234_E_Smooth, Completely round.png
# 234_F_Smooth, Completely round.png
# 235_A_Disk, Face-on, Tight Spiral.png
# 235_B_Disk, Face-on, Tight Spiral.png
# 235_C_Disk, Face-on, Tight Spiral.png
# 235_D_Disk, Face-on, Tight Spiral.png
# 235_E_Disk, Face-on, Tight Spiral.png
# 235_F_Disk, Face-on, Tight Spiral.png
# 236_A_Disk, Face-on, No Spiral.png
# 236_B_Disk, Face-on, No Spiral.png
# 236_C_Disk, Face-on, No Spiral.png
# 236_D_Disk, Face-on, No Spiral.png
# 236_E_Disk, Face-on, No Spiral.png
# 236_F_Disk, Face-on, No Spiral.png
# 237_A_Disk, Face-on, No Spiral.png
# 237_B_Disk, Face-on, No Spiral.png
# 237_C_Disk, Face-on, No Spiral.png
# 237_D_Disk, Face-on, No Spiral.png
# 237_E_Disk, Face-on, No Spiral.png
# 237_F_Disk, Face-on, No Spiral.png
# 238_A_Disk, Face-on, Tight Spiral.png
# 238_B_Disk, Face-on, Tight Spiral.png
# 238_C_Disk, Face-on, Tight Spiral.png
# 238_D_Disk, Face-on, Tight Spiral.png
# 238_E_Disk, Face-on, Tight Spiral.png
# 238_F_Disk, Face-on, Tight Spiral.png
# 239_A_Smooth, Completely round.png
# 239_B_Smooth, Completely round.png
# 239_C_Smooth, Completely round.png
# 239_D_Smooth, Completely round.png
# 239_E_Smooth, Completely round.png
# 239_F_Smooth, Completely round.png
# 23_A_Disk, Face-on, Medium Spiral.png
# 23_B_Disk, Face-on, Medium Spiral.png
# 23_C_Disk, Face-on, Medium Spiral.png
# 23_D_Disk, Face-on, Medium Spiral.png
# 23_E_Disk, Face-on, Medium Spiral.png
# 23_F_Disk, Face-on, Medium Spiral.png
# 240_A_Disk, Edge-on, Rounded Bulge.png
# 240_B_Disk, Edge-on, Rounded Bulge.png
# 240_C_Disk, Edge-on, Rounded Bulge.png
# 240_D_Disk, Edge-on, Rounded Bulge.png
# 240_E_Disk, Edge-on, Rounded Bulge.png
# 240_F_Disk, Edge-on, Rounded Bulge.png
# 241_A_Disk, Face-on, No Spiral.png
# 241_B_Disk, Face-on, No Spiral.png
# 241_C_Disk, Face-on, No Spiral.png
# 241_D_Disk, Face-on, No Spiral.png
# 241_E_Disk, Face-on, No Spiral.png
# 241_F_Disk, Face-on, No Spiral.png
# 242_A_Smooth, Completely round.png
# 242_B_Smooth, Completely round.png
# 242_C_Smooth, Completely round.png
# 242_D_Smooth, Completely round.png
# 242_E_Smooth, Completely round.png
# 242_F_Smooth, Completely round.png
# 243_A_Disk, Face-on, No Spiral.png
# 243_B_Disk, Face-on, No Spiral.png
# 243_C_Disk, Face-on, No Spiral.png
# 243_D_Disk, Face-on, No Spiral.png
# 243_E_Disk, Face-on, No Spiral.png
# 243_F_Disk, Face-on, No Spiral.png
# 244_A_Smooth, Completely round.png
# 244_B_Smooth, Completely round.png
# 244_C_Smooth, Completely round.png
# 244_D_Smooth, Completely round.png
# 244_E_Smooth, Completely round.png
# 244_F_Smooth, Completely round.png
# 245_A_Smooth, in-between round.png
# 245_B_Smooth, in-between round.png
# 245_C_Smooth, in-between round.png
# 245_D_Smooth, in-between round.png
# 245_E_Smooth, in-between round.png
# 245_F_Smooth, in-between round.png
# 246_A_Smooth, Completely round.png
# 246_B_Smooth, Completely round.png
# 246_C_Smooth, Completely round.png
# 246_D_Smooth, Completely round.png
# 246_E_Smooth, Completely round.png
# 246_F_Smooth, Completely round.png
# 247_A_Smooth, Completely round.png
# 247_B_Smooth, Completely round.png
# 247_C_Smooth, Completely round.png
# 247_D_Smooth, Completely round.png
# 247_E_Smooth, Completely round.png
# 247_F_Smooth, Completely round.png
# 248_A_Smooth, Completely round.png
# 248_B_Smooth, Completely round.png
# 248_C_Smooth, Completely round.png
# 248_D_Smooth, Completely round.png
# 248_E_Smooth, Completely round.png
# 248_F_Smooth, Completely round.png
# 249_A_Smooth, Cigar shaped.png
# 249_B_Smooth, Cigar shaped.png
# 249_C_Smooth, Cigar shaped.png
# 249_D_Smooth, Cigar shaped.png
# 249_E_Smooth, Cigar shaped.png
# 249_F_Smooth, Cigar shaped.png
# 24_A_Disk, Face-on, No Spiral.png
# 24_B_Disk, Face-on, No Spiral.png
# 24_C_Disk, Face-on, No Spiral.png
# 24_D_Disk, Face-on, No Spiral.png
# 24_E_Disk, Face-on, No Spiral.png
# 24_F_Disk, Face-on, No Spiral.png
# 25_A_Smooth, in-between round.png
# 25_B_Smooth, in-between round.png
# 25_C_Smooth, in-between round.png
# 25_D_Smooth, in-between round.png
# 25_E_Smooth, in-between round.png
# 25_F_Smooth, in-between round.png
# 26_A_Disk, Edge-on, Rounded Bulge.png
# 26_B_Disk, Edge-on, Rounded Bulge.png
# 26_C_Disk, Edge-on, Rounded Bulge.png
# 26_D_Disk, Edge-on, Rounded Bulge.png
# 26_E_Disk, Edge-on, Rounded Bulge.png
# 26_F_Disk, Edge-on, Rounded Bulge.png
# 27_A_Smooth, Completely round.png
# 27_B_Smooth, Completely round.png
# 27_C_Smooth, Completely round.png
# 27_D_Smooth, Completely round.png
# 27_E_Smooth, Completely round.png
# 27_F_Smooth, Completely round.png
# 28_A_Smooth, in-between round.png
# 28_B_Smooth, in-between round.png
# 28_C_Smooth, in-between round.png
# 28_D_Smooth, in-between round.png
# 28_E_Smooth, in-between round.png
# 28_F_Smooth, in-between round.png
# 29_A_Disk, Face-on, No Spiral.png
# 29_B_Disk, Face-on, No Spiral.png
# 29_C_Disk, Face-on, No Spiral.png
# 29_D_Disk, Face-on, No Spiral.png
# 29_E_Disk, Face-on, No Spiral.png
# 29_F_Disk, Face-on, No Spiral.png
# 2_A_Disk, Face-on, No Spiral.png
# 2_B_Disk, Face-on, No Spiral.png
# 2_C_Disk, Face-on, No Spiral.png
# 2_D_Disk, Face-on, No Spiral.png
# 2_E_Disk, Face-on, No Spiral.png
# 2_F_Disk, Face-on, No Spiral.png
# 30_A_Smooth, in-between round.png
# 30_B_Smooth, in-between round.png
# 30_C_Smooth, in-between round.png
# 30_D_Smooth, in-between round.png
# 30_E_Smooth, in-between round.png
# 30_F_Smooth, in-between round.png
# 31_A_Smooth, Completely round.png
# 31_B_Smooth, Completely round.png
# 31_C_Smooth, Completely round.png
# 31_D_Smooth, Completely round.png
# 31_E_Smooth, Completely round.png
# 31_F_Smooth, Completely round.png
# 32_A_Smooth, Completely round.png
# 32_B_Smooth, Completely round.png
# 32_C_Smooth, Completely round.png
# 32_D_Smooth, Completely round.png
# 32_E_Smooth, Completely round.png
# 32_F_Smooth, Completely round.png
# 33_A_Smooth, Completely round.png
# 33_B_Smooth, Completely round.png
# 33_C_Smooth, Completely round.png
# 33_D_Smooth, Completely round.png
# 33_E_Smooth, Completely round.png
# 33_F_Smooth, Completely round.png
# 34_A_Smooth, in-between round.png
# 34_B_Smooth, in-between round.png
# 34_C_Smooth, in-between round.png
# 34_D_Smooth, in-between round.png
# 34_E_Smooth, in-between round.png
# 34_F_Smooth, in-between round.png
# 35_A_Smooth, Completely round.png
# 35_B_Smooth, Completely round.png
# 35_C_Smooth, Completely round.png
# 35_D_Smooth, Completely round.png
# 35_E_Smooth, Completely round.png
# 35_F_Smooth, Completely round.png
# 36_A_Smooth, in-between round.png
# 36_B_Smooth, in-between round.png
# 36_C_Smooth, in-between round.png
# 36_D_Smooth, in-between round.png
# 36_E_Smooth, in-between round.png
# 36_F_Smooth, in-between round.png
# 37_A_Smooth, Completely round.png
# 37_B_Smooth, Completely round.png
# 37_C_Smooth, Completely round.png
# 37_D_Smooth, Completely round.png
# 37_E_Smooth, Completely round.png
# 37_F_Smooth, Completely round.png
# 38_A_Smooth, in-between round.png
# 38_B_Smooth, in-between round.png
# 38_C_Smooth, in-between round.png
# 38_D_Smooth, in-between round.png
# 38_E_Smooth, in-between round.png
# 38_F_Smooth, in-between round.png
# 39_A_Smooth, in-between round.png
# 39_B_Smooth, in-between round.png
# 39_C_Smooth, in-between round.png
# 39_D_Smooth, in-between round.png
# 39_E_Smooth, in-between round.png
# 39_F_Smooth, in-between round.png
# 3_A_Smooth, in-between round.png
# 3_B_Smooth, in-between round.png
# 3_C_Smooth, in-between round.png
# 3_D_Smooth, in-between round.png
# 3_E_Smooth, in-between round.png
# 3_F_Smooth, in-between round.png
# 40_A_Smooth, Completely round.png
# 40_B_Smooth, Completely round.png
# 40_C_Smooth, Completely round.png
# 40_D_Smooth, Completely round.png
# 40_E_Smooth, Completely round.png
# 40_F_Smooth, Completely round.png
# 41_A_Smooth, in-between round.png
# 41_B_Smooth, in-between round.png
# 41_C_Smooth, in-between round.png
# 41_D_Smooth, in-between round.png
# 41_E_Smooth, in-between round.png
# 41_F_Smooth, in-between round.png
# 42_A_Disk, Face-on, No Spiral.png
# 42_B_Disk, Face-on, No Spiral.png
# 42_C_Disk, Face-on, No Spiral.png
# 42_D_Disk, Face-on, No Spiral.png
# 42_E_Disk, Face-on, No Spiral.png
# 42_F_Disk, Face-on, No Spiral.png
# 43_A_Disk, Edge-on, Rounded Bulge.png
# 43_B_Disk, Edge-on, Rounded Bulge.png
# 43_C_Disk, Edge-on, Rounded Bulge.png
# 43_D_Disk, Edge-on, Rounded Bulge.png
# 43_E_Disk, Edge-on, Rounded Bulge.png
# 43_F_Disk, Edge-on, Rounded Bulge.png
# 44_A_Smooth, in-between round.png
# 44_B_Smooth, in-between round.png
# 44_C_Smooth, in-between round.png
# 44_D_Smooth, in-between round.png
# 44_E_Smooth, in-between round.png
# 44_F_Smooth, in-between round.png
# 45_A_Smooth, in-between round.png
# 45_B_Smooth, in-between round.png
# 45_C_Smooth, in-between round.png
# 45_D_Smooth, in-between round.png
# 45_E_Smooth, in-between round.png
# 45_F_Smooth, in-between round.png
# 46_A_Disk, Face-on, No Spiral.png
# 46_B_Disk, Face-on, No Spiral.png
# 46_C_Disk, Face-on, No Spiral.png
# 46_D_Disk, Face-on, No Spiral.png
# 46_E_Disk, Face-on, No Spiral.png
# 46_F_Disk, Face-on, No Spiral.png
# 47_A_Smooth, in-between round.png
# 47_B_Smooth, in-between round.png
# 47_C_Smooth, in-between round.png
# 47_D_Smooth, in-between round.png
# 47_E_Smooth, in-between round.png
# 47_F_Smooth, in-between round.png
# 48_A_Disk, Face-on, No Spiral.png
# 48_B_Disk, Face-on, No Spiral.png
# 48_C_Disk, Face-on, No Spiral.png
# 48_D_Disk, Face-on, No Spiral.png
# 48_E_Disk, Face-on, No Spiral.png
# 48_F_Disk, Face-on, No Spiral.png
# 49_A_Disk, Edge-on, No Bulge.png
# 49_B_Disk, Edge-on, No Bulge.png
# 49_C_Disk, Edge-on, No Bulge.png
# 49_D_Disk, Edge-on, No Bulge.png
# 49_E_Disk, Edge-on, No Bulge.png
# 49_F_Disk, Edge-on, No Bulge.png
# 4_A_Disk, Face-on, No Spiral.png
# 4_B_Disk, Face-on, No Spiral.png
# 4_C_Disk, Face-on, No Spiral.png
# 4_D_Disk, Face-on, No Spiral.png
# 4_E_Disk, Face-on, No Spiral.png
# 4_F_Disk, Face-on, No Spiral.png
# 50_A_Disk, Face-on, Medium Spiral.png
# 50_B_Disk, Face-on, Medium Spiral.png
# 50_C_Disk, Face-on, Medium Spiral.png
# 50_D_Disk, Face-on, Medium Spiral.png
# 50_E_Disk, Face-on, Medium Spiral.png
# 50_F_Disk, Face-on, Medium Spiral.png
# 51_A_Disk, Edge-on, No Bulge.png
# 51_B_Disk, Edge-on, No Bulge.png
# 51_C_Disk, Edge-on, No Bulge.png
# 51_D_Disk, Edge-on, No Bulge.png
# 51_E_Disk, Edge-on, No Bulge.png
# 51_F_Disk, Edge-on, No Bulge.png
# 52_A_Disk, Edge-on, No Bulge.png
# 52_B_Disk, Edge-on, No Bulge.png
# 52_C_Disk, Edge-on, No Bulge.png
# 52_D_Disk, Edge-on, No Bulge.png
# 52_E_Disk, Edge-on, No Bulge.png
# 52_F_Disk, Edge-on, No Bulge.png
# 53_A_Smooth, Completely round.png
# 53_B_Smooth, Completely round.png
# 53_C_Smooth, Completely round.png
# 53_D_Smooth, Completely round.png
# 53_E_Smooth, Completely round.png
# 53_F_Smooth, Completely round.png
# 54_A_Smooth, Cigar shaped.png
# 54_B_Smooth, Cigar shaped.png
# 54_C_Smooth, Cigar shaped.png
# 54_D_Smooth, Cigar shaped.png
# 54_E_Smooth, Cigar shaped.png
# 54_F_Smooth, Cigar shaped.png
# 55_A_Disk, Face-on, Loose Spiral.png
# 55_B_Disk, Face-on, Loose Spiral.png
# 55_C_Disk, Face-on, Loose Spiral.png
# 55_D_Disk, Face-on, Loose Spiral.png
# 55_E_Disk, Face-on, Loose Spiral.png
# 55_F_Disk, Face-on, Loose Spiral.png
# 56_A_Disk, Face-on, Loose Spiral.png
# 56_B_Disk, Face-on, Loose Spiral.png
# 56_C_Disk, Face-on, Loose Spiral.png
# 56_D_Disk, Face-on, Loose Spiral.png
# 56_E_Disk, Face-on, Loose Spiral.png
# 56_F_Disk, Face-on, Loose Spiral.png
# 57_A_Smooth, in-between round.png
# 57_B_Smooth, in-between round.png
# 57_C_Smooth, in-between round.png
# 57_D_Smooth, in-between round.png
# 57_E_Smooth, in-between round.png
# 57_F_Smooth, in-between round.png
# 58_A_Disk, Face-on, No Spiral.png
# 58_B_Disk, Face-on, No Spiral.png
# 58_C_Disk, Face-on, No Spiral.png
# 58_D_Disk, Face-on, No Spiral.png
# 58_E_Disk, Face-on, No Spiral.png
# 58_F_Disk, Face-on, No Spiral.png
# 59_A_Smooth, in-between round.png
# 59_B_Smooth, in-between round.png
# 59_C_Smooth, in-between round.png
# 59_D_Smooth, in-between round.png
# 59_E_Smooth, in-between round.png
# 59_F_Smooth, in-between round.png
# 5_A_Smooth, Completely round.png
# 5_B_Smooth, Completely round.png
# 5_C_Smooth, Completely round.png
# 5_D_Smooth, Completely round.png
# 5_E_Smooth, Completely round.png
# 5_F_Smooth, Completely round.png
# 60_A_Disk, Edge-on, Rounded Bulge.png
# 60_B_Disk, Edge-on, Rounded Bulge.png
# 60_C_Disk, Edge-on, Rounded Bulge.png
# 60_D_Disk, Edge-on, Rounded Bulge.png
# 60_E_Disk, Edge-on, Rounded Bulge.png
# 60_F_Disk, Edge-on, Rounded Bulge.png
# 61_A_Disk, Edge-on, No Bulge.png
# 61_B_Disk, Edge-on, No Bulge.png
# 61_C_Disk, Edge-on, No Bulge.png
# 61_D_Disk, Edge-on, No Bulge.png
# 61_E_Disk, Edge-on, No Bulge.png
# 61_F_Disk, Edge-on, No Bulge.png
# 62_A_Smooth, in-between round.png
# 62_B_Smooth, in-between round.png
# 62_C_Smooth, in-between round.png
# 62_D_Smooth, in-between round.png
# 62_E_Smooth, in-between round.png
# 62_F_Smooth, in-between round.png
# 63_A_Disk, Face-on, Medium Spiral.png
# 63_B_Disk, Face-on, Medium Spiral.png
# 63_C_Disk, Face-on, Medium Spiral.png
# 63_D_Disk, Face-on, Medium Spiral.png
# 63_E_Disk, Face-on, Medium Spiral.png
# 63_F_Disk, Face-on, Medium Spiral.png
# 64_A_Smooth, Completely round.png
# 64_B_Smooth, Completely round.png
# 64_C_Smooth, Completely round.png
# 64_D_Smooth, Completely round.png
# 64_E_Smooth, Completely round.png
# 64_F_Smooth, Completely round.png
# 65_A_Smooth, in-between round.png
# 65_B_Smooth, in-between round.png
# 65_C_Smooth, in-between round.png
# 65_D_Smooth, in-between round.png
# 65_E_Smooth, in-between round.png
# 65_F_Smooth, in-between round.png
# 66_A_Smooth, Completely round.png
# 66_B_Smooth, Completely round.png
# 66_C_Smooth, Completely round.png
# 66_D_Smooth, Completely round.png
# 66_E_Smooth, Completely round.png
# 66_F_Smooth, Completely round.png
# 67_A_Disk, Face-on, Medium Spiral.png
# 67_B_Disk, Face-on, Medium Spiral.png
# 67_C_Disk, Face-on, Medium Spiral.png
# 67_D_Disk, Face-on, Medium Spiral.png
# 67_E_Disk, Face-on, Medium Spiral.png
# 67_F_Disk, Face-on, Medium Spiral.png
# 68_A_Smooth, Completely round.png
# 68_B_Smooth, Completely round.png
# 68_C_Smooth, Completely round.png
# 68_D_Smooth, Completely round.png
# 68_E_Smooth, Completely round.png
# 68_F_Smooth, Completely round.png
# 69_A_Smooth, in-between round.png
# 69_B_Smooth, in-between round.png
# 69_C_Smooth, in-between round.png
# 69_D_Smooth, in-between round.png
# 69_E_Smooth, in-between round.png
# 69_F_Smooth, in-between round.png
# 6_A_Disk, Face-on, Medium Spiral.png
# 6_B_Disk, Face-on, Medium Spiral.png
# 6_C_Disk, Face-on, Medium Spiral.png
# 6_D_Disk, Face-on, Medium Spiral.png
# 6_E_Disk, Face-on, Medium Spiral.png
# 6_F_Disk, Face-on, Medium Spiral.png
# 70_A_Disk, Face-on, Tight Spiral.png
# 70_B_Disk, Face-on, Tight Spiral.png
# 70_C_Disk, Face-on, Tight Spiral.png
# 70_D_Disk, Face-on, Tight Spiral.png
# 70_E_Disk, Face-on, Tight Spiral.png
# 70_F_Disk, Face-on, Tight Spiral.png
# 71_A_Smooth, Completely round.png
# 71_B_Smooth, Completely round.png
# 71_C_Smooth, Completely round.png
# 71_D_Smooth, Completely round.png
# 71_E_Smooth, Completely round.png
# 71_F_Smooth, Completely round.png
# 72_A_Smooth, Completely round.png
# 72_B_Smooth, Completely round.png
# 72_C_Smooth, Completely round.png
# 72_D_Smooth, Completely round.png
# 72_E_Smooth, Completely round.png
# 72_F_Smooth, Completely round.png
# 73_A_Smooth, in-between round.png
# 73_B_Smooth, in-between round.png
# 73_C_Smooth, in-between round.png
# 73_D_Smooth, in-between round.png
# 73_E_Smooth, in-between round.png
# 73_F_Smooth, in-between round.png
# 74_A_Disk, Edge-on, No Bulge.png
# 74_B_Disk, Edge-on, No Bulge.png
# 74_C_Disk, Edge-on, No Bulge.png
# 74_D_Disk, Edge-on, No Bulge.png
# 74_E_Disk, Edge-on, No Bulge.png
# 74_F_Disk, Edge-on, No Bulge.png
# 75_A_Smooth, Completely round.png
# 75_B_Smooth, Completely round.png
# 75_C_Smooth, Completely round.png
# 75_D_Smooth, Completely round.png
# 75_E_Smooth, Completely round.png
# 75_F_Smooth, Completely round.png
# 76_A_Disk, Face-on, No Spiral.png
# 76_B_Disk, Face-on, No Spiral.png
# 76_C_Disk, Face-on, No Spiral.png
# 76_D_Disk, Face-on, No Spiral.png
# 76_E_Disk, Face-on, No Spiral.png
# 76_F_Disk, Face-on, No Spiral.png
# 77_A_Smooth, Completely round.png
# 77_B_Smooth, Completely round.png
# 77_C_Smooth, Completely round.png
# 77_D_Smooth, Completely round.png
# 77_E_Smooth, Completely round.png
# 77_F_Smooth, Completely round.png
# 78_A_Disk, Face-on, Medium Spiral.png
# 78_B_Disk, Face-on, Medium Spiral.png
# 78_C_Disk, Face-on, Medium Spiral.png
# 78_D_Disk, Face-on, Medium Spiral.png
# 78_E_Disk, Face-on, Medium Spiral.png
# 78_F_Disk, Face-on, Medium Spiral.png
# 79_A_Disk, Face-on, Medium Spiral.png
# 79_B_Disk, Face-on, Medium Spiral.png
# 79_C_Disk, Face-on, Medium Spiral.png
# 79_D_Disk, Face-on, Medium Spiral.png
# 79_E_Disk, Face-on, Medium Spiral.png
# 79_F_Disk, Face-on, Medium Spiral.png
# 7_A_Smooth, Completely round.png
# 7_B_Smooth, Completely round.png
# 7_C_Smooth, Completely round.png
# 7_D_Smooth, Completely round.png
# 7_E_Smooth, Completely round.png
# 7_F_Smooth, Completely round.png
# 80_A_Smooth, Completely round.png
# 80_B_Smooth, Completely round.png
# 80_C_Smooth, Completely round.png
# 80_D_Smooth, Completely round.png
# 80_E_Smooth, Completely round.png
# 80_F_Smooth, Completely round.png
# 81_A_Smooth, in-between round.png
# 81_B_Smooth, in-between round.png
# 81_C_Smooth, in-between round.png
# 81_D_Smooth, in-between round.png
# 81_E_Smooth, in-between round.png
# 81_F_Smooth, in-between round.png
# 82_A_Disk, Face-on, No Spiral.png
# 82_B_Disk, Face-on, No Spiral.png
# 82_C_Disk, Face-on, No Spiral.png
# 82_D_Disk, Face-on, No Spiral.png
# 82_E_Disk, Face-on, No Spiral.png
# 82_F_Disk, Face-on, No Spiral.png
# 83_A_Smooth, in-between round.png
# 83_B_Smooth, in-between round.png
# 83_C_Smooth, in-between round.png
# 83_D_Smooth, in-between round.png
# 83_E_Smooth, in-between round.png
# 83_F_Smooth, in-between round.png
# 84_A_Smooth, Completely round.png
# 84_B_Smooth, Completely round.png
# 84_C_Smooth, Completely round.png
# 84_D_Smooth, Completely round.png
# 84_E_Smooth, Completely round.png
# 84_F_Smooth, Completely round.png
# 85_A_Smooth, in-between round.png
# 85_B_Smooth, in-between round.png
# 85_C_Smooth, in-between round.png
# 85_D_Smooth, in-between round.png
# 85_E_Smooth, in-between round.png
# 85_F_Smooth, in-between round.png
# 86_A_Smooth, Completely round.png
# 86_B_Smooth, Completely round.png
# 86_C_Smooth, Completely round.png
# 86_D_Smooth, Completely round.png
# 86_E_Smooth, Completely round.png
# 86_F_Smooth, Completely round.png
# 87_A_Disk, Face-on, No Spiral.png
# 87_B_Disk, Face-on, No Spiral.png
# 87_C_Disk, Face-on, No Spiral.png
# 87_D_Disk, Face-on, No Spiral.png
# 87_E_Disk, Face-on, No Spiral.png
# 87_F_Disk, Face-on, No Spiral.png
# 88_A_Smooth, Completely round.png
# 88_B_Smooth, Completely round.png
# 88_C_Smooth, Completely round.png
# 88_D_Smooth, Completely round.png
# 88_E_Smooth, Completely round.png
# 88_F_Smooth, Completely round.png
# 89_A_Smooth, Cigar shaped.png
# 89_B_Smooth, Cigar shaped.png
# 89_C_Smooth, Cigar shaped.png
# 89_D_Smooth, Cigar shaped.png
# 89_E_Smooth, Cigar shaped.png
# 89_F_Smooth, Cigar shaped.png
# 8_A_Disk, Edge-on, Rounded Bulge.png
# 8_B_Disk, Edge-on, Rounded Bulge.png
# 8_C_Disk, Edge-on, Rounded Bulge.png
# 8_D_Disk, Edge-on, Rounded Bulge.png
# 8_E_Disk, Edge-on, Rounded Bulge.png
# 8_F_Disk, Edge-on, Rounded Bulge.png
# 90_A_Disk, Face-on, Medium Spiral.png
# 90_B_Disk, Face-on, Medium Spiral.png
# 90_C_Disk, Face-on, Medium Spiral.png
# 90_D_Disk, Face-on, Medium Spiral.png
# 90_E_Disk, Face-on, Medium Spiral.png
# 90_F_Disk, Face-on, Medium Spiral.png
# 91_A_Disk, Face-on, Tight Spiral.png
# 91_B_Disk, Face-on, Tight Spiral.png
# 91_C_Disk, Face-on, Tight Spiral.png
# 91_D_Disk, Face-on, Tight Spiral.png
# 91_E_Disk, Face-on, Tight Spiral.png
# 91_F_Disk, Face-on, Tight Spiral.png
# 92_A_Smooth, in-between round.png
# 92_B_Smooth, in-between round.png
# 92_C_Smooth, in-between round.png
# 92_D_Smooth, in-between round.png
# 92_E_Smooth, in-between round.png
# 92_F_Smooth, in-between round.png
# 93_A_Smooth, in-between round.png
# 93_B_Smooth, in-between round.png
# 93_C_Smooth, in-between round.png
# 93_D_Smooth, in-between round.png
# 93_E_Smooth, in-between round.png
# 93_F_Smooth, in-between round.png
# 94_A_Smooth, Completely round.png
# 94_B_Smooth, Completely round.png
# 94_C_Smooth, Completely round.png
# 94_D_Smooth, Completely round.png
# 94_E_Smooth, Completely round.png
# 94_F_Smooth, Completely round.png
# 95_A_Smooth, in-between round.png
# 95_B_Smooth, in-between round.png
# 95_C_Smooth, in-between round.png
# 95_D_Smooth, in-between round.png
# 95_E_Smooth, in-between round.png
# 95_F_Smooth, in-between round.png
# 96_A_Disk, Face-on, Tight Spiral.png
# 96_B_Disk, Face-on, Tight Spiral.png
# 96_C_Disk, Face-on, Tight Spiral.png
# 96_D_Disk, Face-on, Tight Spiral.png
# 96_E_Disk, Face-on, Tight Spiral.png
# 96_F_Disk, Face-on, Tight Spiral.png
# 97_A_Disk, Face-on, Tight Spiral.png
# 97_B_Disk, Face-on, Tight Spiral.png
# 97_C_Disk, Face-on, Tight Spiral.png
# 97_D_Disk, Face-on, Tight Spiral.png
# 97_E_Disk, Face-on, Tight Spiral.png
# 97_F_Disk, Face-on, Tight Spiral.png
# 98_A_Smooth, Completely round.png
# 98_B_Smooth, Completely round.png
# 98_C_Smooth, Completely round.png
# 98_D_Smooth, Completely round.png
# 98_E_Smooth, Completely round.png
# 98_F_Smooth, Completely round.png
# 99_A_Smooth, Completely round.png
# 99_B_Smooth, Completely round.png
# 99_C_Smooth, Completely round.png
# 99_D_Smooth, Completely round.png
# 99_E_Smooth, Completely round.png
# 99_F_Smooth, Completely round.png
# 9_A_Smooth, in-between round.png
# 9_B_Smooth, in-between round.png
# 9_C_Smooth, in-between round.png
# 9_D_Smooth, in-between round.png
# 9_E_Smooth, in-between round.png
# 9_F_Smooth, in-between round.png

# %%
plt.imshow(train_set_x_orig_2.reshape(r2, 217, 217, 3)[10])

# %%
plt.imshow(test_set_x_orig_2.reshape(r, 217, 217, 3)[10])

# %%
train = train_set_x_orig_2.reshape(r2, 217, 217, 3)
train.shape
# Out:
# (3484, 217, 217, 3)

# %%
d1=400 + 200 + 100
d2=2400 + 383

hola = np.zeros((1, d1 + 1)) 
bye = np.zeros((1, d2)) + 1
c = np.append(hola, bye)
c_train = c.reshape(1, d1+d2 +1)
c_train.shape
# Out:
# (1, 3484)

# %%
test = test_set_x_orig_2.reshape(r, 217, 217, 3)
test.shape
# Out:
# (1950, 217, 217, 3)

# %%
d1=250+200
d2=1500

hola = np.zeros((1, d1))
bye = np.zeros((1, d2)) + 1
c = np.append(hola, bye)
c_test = c.reshape(1, d1+d2)
c_test.shape
# Out:
# (1, 1950)

# %% [markdown]
# <a name='2'></a>
# ## 2 - Overview of the Problem set ##
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labeled as cat (y=1) or non-cat (y=0)
#     - a test set of m_test images labeled as cat or non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB). Thus, each image is square (height = num_px) and (width = num_px).
#
# You will build a simple image-recognition algorithm that can correctly classify pictures as cat or non-cat.
#
# Let's get more familiar with the dataset. Load the data by running the following code.

# %%
# Loading the data (cat/non-cat)
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()

# %%
classes
# Out:
# array([b'non-cat', b'cat'], dtype='|S7')

# %%
# Loading the data "LENS / NO_LENS"
classes2 = classes
classes2[0] = b'NO_LENS'
classes2[1] = b'LENS'


train_set_x_orig = train
train_set_y = c_train
test_set_x_orig = test
test_set_y = c_test
classes = classes2

# %%
classes
# Out:
# array([b'NO_LENS', b'LENS'], dtype='|S7')

# %%
classes[np.squeeze(train_set_y[:, 0].astype(int))].decode("utf-8")
# Out:
# 'NO_LENS'

# %% [markdown]
# We added "_orig" at the end of image datasets (train and test) because we are going to preprocess them. After preprocessing, we will end up with train_set_x and test_set_x (the labels train_set_y and test_set_y don't need any preprocessing).
#
# Each line of your train_set_x_orig and test_set_x_orig is an array representing an image. You can visualize an example by running the following code. Feel free also to change the `index` value and re-run to see other images.

# %%
# Example of a picture from TRAIN SET
index = 25
plt.imshow(train_set_x_orig[index])
print ("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index].astype(int))].decode("utf-8") +  "' picture.")
# Out:
# y = [0.], it's a 'NO_LENS' picture.

# %%
# Example of a picture from TEST SET
index = 5
plt.imshow(test_set_x_orig[index])
print ("y = " + str(test_set_y[:, index]) + ", it's a '" + classes[np.squeeze(test_set_y[:, index].astype(int))].decode("utf-8") +  "' picture.")
# Out:
# y = [0.], it's a 'NO_LENS' picture.

# %% [markdown]
# Many software bugs in deep learning come from having matrix/vector dimensions that don't fit. If you can keep your matrix/vector dimensions straight you will go a long way toward eliminating many bugs.
#
# <a name='ex-1'></a>
# ### Exercise 1
# Find the values for:
#     - m_train (number of training examples)
#     - m_test (number of test examples)
#     - num_px (= height = width of a training image)
# Remember that `train_set_x_orig` is a numpy-array of shape (m_train, num_px, num_px, 3). For instance, you can access `m_train` by writing `train_set_x_orig.shape[0]`.

# %%
#(≈ 3 lines of code)
# m_train = 
# m_test = 
# num_px = 
# YOUR CODE STARTS HERE
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = len(train_set_x_orig[0])
# YOUR CODE ENDS HERE

print ("Number of training examples: m_train = " + str(m_train))
print ("Number of testing examples: m_test = " + str(m_test))
print ("Height/Width of each image: num_px = " + str(num_px))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_set_x shape: " + str(train_set_x_orig.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x shape: " + str(test_set_x_orig.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# Number of training examples: m_train = 3484
# Number of testing examples: m_test = 1950
# Height/Width of each image: num_px = 217
# Each image is of size: (217, 217, 3)
# train_set_x shape: (3484, 217, 217, 3)
# train_set_y shape: (1, 3484)
# test_set_x shape: (1950, 217, 217, 3)
# test_set_y shape: (1, 1950)

# %% [markdown]
# **Expected Output for m_train, m_test and num_px**:
# <table style="width:15%">
#   <tr>
#     <td> m_train </td>
#     <td> 209 </td>
#   </tr>
#
#   <tr>
#     <td>m_test</td>
#     <td> 50 </td>
#   </tr>
#
#   <tr>
#     <td>num_px</td>
#     <td> 64 </td>
#   </tr>
#
# </table>

# %% [markdown]
# For convenience, you should now reshape images of shape (num_px, num_px, 3) in a numpy-array of shape (num_px $*$ num_px $*$ 3, 1). After this, our training (and test) dataset is a numpy-array where each column represents a flattened image. There should be m_train (respectively m_test) columns.
#
# <a name='ex-2'></a>
# ### Exercise 2
# Reshape the training and test data sets so that images of size (num_px, num_px, 3) are flattened into single vectors of shape (num\_px $*$ num\_px $*$ 3, 1).
#
# A trick when you want to flatten a matrix X of shape (a,b,c,d) to a matrix X_flatten of shape (b$*$c$*$d, a) is to use:
# ```python
# X_flatten = X.reshape(X.shape[0], -1).T      # X.T is the transpose of X
# ```

# %%
# Reshape the training and test examples
#(≈ 2 lines of code)
# train_set_x_flatten = ...
# test_set_x_flatten = ...
# YOUR CODE STARTS HERE
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0], -1).T
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0], -1).T
# YOUR CODE ENDS HERE

# Check that the first 10 pixels of the second image are in the correct place
#assert np.alltrue(train_set_x_flatten[0:10, 1] == [196, 192, 190, 193, 186, 182, 188, 179, 174, 213]), "Wrong solution. Use (X.shape[0], -1).T."
#assert np.alltrue(test_set_x_flatten[0:10, 1] == [115, 110, 111, 137, 129, 129, 155, 146, 145, 159]), "Wrong solution. Use (X.shape[0], -1).T."

print ("train_set_x_flatten shape: " + str(train_set_x_flatten.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x_flatten shape: " + str(test_set_x_flatten.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# train_set_x_flatten shape: (141267, 3484)
# train_set_y shape: (1, 3484)
# test_set_x_flatten shape: (141267, 1950)
# test_set_y shape: (1, 1950)

# %% [markdown]
# **Expected Output**:
#
# <table style="width:35%">
#   <tr>
#     <td>train_set_x_flatten shape</td>
#     <td> (12288, 209)</td>
#   </tr>
#   <tr>
#     <td>train_set_y shape</td>
#     <td>(1, 209)</td>
#   </tr>
#   <tr>
#     <td>test_set_x_flatten shape</td>
#     <td>(12288, 50)</td>
#   </tr>
#   <tr>
#     <td>test_set_y shape</td>
#     <td>(1, 50)</td>
#   </tr>
# </table>

# %% [markdown]
# To represent color images, the red, green and blue channels (RGB) must be specified for each pixel, and so the pixel value is actually a vector of three numbers ranging from 0 to 255.
#
# One common preprocessing step in machine learning is to center and standardize your dataset, meaning that you substract the mean of the whole numpy array from each example, and then divide each example by the standard deviation of the whole numpy array. But for picture datasets, it is simpler and more convenient and works almost as well to just divide every row of the dataset by 255 (the maximum value of a pixel channel).
#
# <!-- During the training of your model, you're going to multiply weights and add biases to some initial inputs in order to observe neuron activations. Then you backpropogate with the gradients to train the model. But, it is extremely important for each feature to have a similar range such that our gradients don't explode. You will see that more in detail later in the lectures. !-->
#
# Let's standardize our dataset.

# %%
train_set_x = train_set_x_flatten / 255.
test_set_x = test_set_x_flatten / 255.

# %% [markdown]
# <a name='4'></a>
# ## 4 - Building the parts of our algorithm ##
#
# The main steps for building a Neural Network are:
# 1. Define the model structure (such as number of input features)
# 2. Initialize the model's parameters
# 3. Loop:
#     - Calculate current loss (forward propagation)
#     - Calculate current gradient (backward propagation)
#     - Update parameters (gradient descent)
#
# You often build 1-3 separately and integrate them into one function we call `model()`.
#
# <a name='4-1'></a>
# ### 4.1 - Helper functions
#
# <a name='ex-3'></a>
# ### Exercise 3 - sigmoid
# Using your code from "Python Basics", implement `sigmoid()`. As you've seen in the figure above, you need to compute $sigmoid(z) = \frac{1}{1 + e^{-z}}$ for $z = w^T x + b$ to make predictions. Use np.exp().

# %% [markdown]
# <font color='blue'>
#
#
# **What you need to remember:**
#
# Common steps for pre-processing a new dataset are:
# - Figure out the dimensions and shapes of the problem (m_train, m_test, num_px, ...)
# - Reshape the datasets such that each example is now a vector of size (num_px \* num_px \* 3, 1)
# - "Standardize" the data

# %% [markdown]
# <a name='3'></a>
# ## 3 - General Architecture of the learning algorithm ##
#
# It's time to design a simple algorithm to distinguish cat images from non-cat images.
#
# You will build a Logistic Regression, using a Neural Network mindset. The following Figure explains why **Logistic Regression is actually a very simple Neural Network!**
#
# <img src="images/LogReg_kiank.png" style="width:650px;height:400px;">
#
# **Mathematical expression of the algorithm**:
#
# For one example $x^{(i)}$:
# $$z^{(i)} = w^T x^{(i)} + b \tag{1}$$
# $$\hat{y}^{(i)} = a^{(i)} = sigmoid(z^{(i)})\tag{2}$$
# $$ \mathcal{L}(a^{(i)}, y^{(i)}) =  - y^{(i)}  \log(a^{(i)}) - (1-y^{(i)} )  \log(1-a^{(i)})\tag{3}$$
#
# The cost is then computed by summing over all training examples:
# $$ J = \frac{1}{m} \sum_{i=1}^m \mathcal{L}(a^{(i)}, y^{(i)})\tag{6}$$
#
# **Key steps**:
# In this exercise, you will carry out the following steps:
#     - Initialize the parameters of the model
#     - Learn the parameters for the model by minimizing the cost
#     - Use the learned parameters to make predictions (on the test set)
#     - Analyse the results and conclude

# %%
# GRADED FUNCTION: sigmoid

def sigmoid(z):
    """
    Compute the sigmoid of z

    Arguments:
    z -- A scalar or numpy array of any size.

    Return:
    s -- sigmoid(z)
    """

    #(≈ 1 line of code)
    # s = ...
    # YOUR CODE STARTS HERE
    s = 1 / (1+np.exp(-z))
    # YOUR CODE ENDS HERE
    
    return s

# %%
print ("sigmoid([0, 2]) = " + str(sigmoid(np.array([0,2]))))

sigmoid_test(sigmoid)
# Out:
# sigmoid([0, 2]) = [0.5        0.88079708]
# All tests passed!

# %%
x = np.array([0.5, 0, 2.0])
output = sigmoid(x)
print(output)
# Out:
# [0.62245933 0.5        0.88079708]

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Initializing parameters
#
# <a name='ex-4'></a>
# ### Exercise 4 - initialize_with_zeros
# Implement parameter initialization in the cell below. You have to initialize w as a vector of zeros. If you don't know what numpy function to use, look up np.zeros() in the Numpy library's documentation.

# %%
# GRADED FUNCTION: initialize_with_zeros

def initialize_with_zeros(dim):
    """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.
    
    Argument:
    dim -- size of the w vector we want (or number of parameters in this case)
    
    Returns:
    w -- initialized vector of shape (dim, 1)
    b -- initialized scalar (corresponds to the bias) of type float
    """
    
    # (≈ 2 lines of code)
    # w = ...
    # b = ...
    # YOUR CODE STARTS HERE
    w = np.zeros([dim, 1])
    b = 0.0
    # YOUR CODE ENDS HERE

    return w, b

# %%
dim = 2
w, b = initialize_with_zeros(dim)

assert type(b) == float
print ("w = " + str(w))
print ("b = " + str(b))

initialize_with_zeros_test_1(initialize_with_zeros)
initialize_with_zeros_test_2(initialize_with_zeros)
# Out:
# w = [[0.]
#  [0.]]
# b = 0.0
# First test passed!
# Second test passed!

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Forward and Backward propagation
#
# Now that your parameters are initialized, you can do the "forward" and "backward" propagation steps for learning the parameters.
#
# <a name='ex-5'></a>
# ### Exercise 5 - propagate
# Implement a function `propagate()` that computes the cost function and its gradient.
#
# **Hints**:
#
# Forward Propagation:
# - You get X
# - You compute $A = \sigma(w^T X + b) = (a^{(1)}, a^{(2)}, ..., a^{(m-1)}, a^{(m)})$
# - You calculate the cost function: $J = -\frac{1}{m}\sum_{i=1}^{m}(y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)}))$
#
# Here are the two formulas you will be using:
#
# $$ \frac{\partial J}{\partial w} = \frac{1}{m}X(A-Y)^T\tag{7}$$
# $$ \frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^m (a^{(i)}-y^{(i)})\tag{8}$$

# %%
# GRADED FUNCTION: propagate

def propagate(w, b, X, Y):
    """
    Implement the cost function and its gradient for the propagation explained above

    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat) of size (1, number of examples)

    Return:
    cost -- negative log-likelihood cost for logistic regression
    dw -- gradient of the loss with respect to w, thus same shape as w
    db -- gradient of the loss with respect to b, thus same shape as b
    
    Tips:
    - Write your code step by step for the propagation. np.log(), np.dot()
    """
    
    m = X.shape[1]
    
    # FORWARD PROPAGATION (FROM X TO COST)
    #(≈ 2 lines of code)
    # compute activation
    # A = ...
    # compute cost by using np.dot to perform multiplication. 
    # And don't use loops for the sum.
    # cost = ...                                
    # YOUR CODE STARTS HERE
    A = sigmoid( np.dot(w.T, X) + b)
    cost = -1/m * np.sum(Y * np.log(A) + (1 - Y) * np.log(1 - A))
    # YOUR CODE ENDS HERE

    # BACKWARD PROPAGATION (TO FIND GRAD)
    #(≈ 2 lines of code)
    # dw = ...
    # db = ...
    # YOUR CODE STARTS HERE
    dw = 1/m * np.dot(X, (A - Y).T)
    db = 1/m * np.sum(A - Y)
    # YOUR CODE ENDS HERE
    cost = np.squeeze(np.array(cost))

    
    grads = {"dw": dw,
             "db": db}
    return grads, cost

# %%
w =  np.array([[1.], [2]])
b = 1.5
X = np.array([[1., -2., -1.], [3., 0.5, -3.2]])
Y = np.array([[1, 1, 0]])
grads, cost = propagate(w, b, X, Y)

assert type(grads["dw"]) == np.ndarray
assert grads["dw"].shape == (2, 1)
assert type(grads["db"]) == np.float64


print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
print ("cost = " + str(cost))

propagate_test(propagate)
# Out:
# dw = [[ 0.25071532]
#  [-0.06604096]]
# db = -0.1250040450043965
# cost = 0.15900537707692405
# All tests passed!

# %% [markdown]
# **Expected output**
#
# ```
# dw = [[ 0.25071532]
#  [-0.06604096]]
# db = -0.1250040450043965
# cost = 0.15900537707692405
# ```

# %% [markdown]
# <a name='4-4'></a>
# ### 4.4 - Optimization
# - You have initialized your parameters.
# - You are also able to compute a cost function and its gradient.
# - Now, you want to update the parameters using gradient descent.
#
# <a name='ex-6'></a>
# ### Exercise 6 - optimize
# Write down the optimization function. The goal is to learn $w$ and $b$ by minimizing the cost function $J$. For a parameter $\theta$, the update rule is $ \theta = \theta - \alpha \text{ } d\theta$, where $\alpha$ is the learning rate.

# %%
# GRADED FUNCTION: optimize

def optimize(w, b, X, Y, num_iterations=100, learning_rate=0.009, print_cost=False):
    """
    This function optimizes w and b by running a gradient descent algorithm
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat), of shape (1, number of examples)
    num_iterations -- number of iterations of the optimization loop
    learning_rate -- learning rate of the gradient descent update rule
    print_cost -- True to print the loss every 100 steps
    
    Returns:
    params -- dictionary containing the weights w and bias b
    grads -- dictionary containing the gradients of the weights and bias with respect to the cost function
    costs -- list of all the costs computed during the optimization, this will be used to plot the learning curve.
    
    Tips:
    You basically need to write down two steps and iterate through them:
        1) Calculate the cost and the gradient for the current parameters. Use propagate().
        2) Update the parameters using gradient descent rule for w and b.
    """
    
    w = copy.deepcopy(w)
    b = copy.deepcopy(b)
    
    costs = []
    
    for i in range(num_iterations):
        # (≈ 1 lines of code)
        # Cost and gradient calculation 
        # grads, cost = ...
        # YOUR CODE STARTS HERE
        grads, cost = propagate(w, b, X, Y)
        # YOUR CODE ENDS HERE
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # update rule (≈ 2 lines of code)
        # w = ...
        # b = ...
        # YOUR CODE STARTS HERE
        w = w - learning_rate * dw
        b = b - learning_rate * db
        # YOUR CODE ENDS HERE
        
        # Record the costs
        if i % 100 == 0:
            costs.append(cost)
        
            # Print the cost every 100 training iterations
            if print_cost:
                print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs

# %%
params, grads, costs = optimize(w, b, X, Y, num_iterations=100, learning_rate=0.009, print_cost=False)

print ("w = " + str(params["w"]))
print ("b = " + str(params["b"]))
print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
print("Costs = " + str(costs))

optimize_test(optimize)
# Out:
# w = [[0.80956046]
#  [2.0508202 ]]
# b = 1.5948713189708588
# dw = [[ 0.17860505]
#  [-0.04840656]]
# db = -0.08888460336847771
# Costs = [array(0.15900538)]
# All tests passed!

# %% [markdown]
# <a name='ex-7'></a>
# ### Exercise 7 - predict
# The previous function will output the learned w and b. We are able to use w and b to predict the labels for a dataset X. Implement the `predict()` function. There are two steps to computing predictions:
#
# 1. Calculate $\hat{Y} = A = \sigma(w^T X + b)$
#
# 2. Convert the entries of a into 0 (if activation <= 0.5) or 1 (if activation > 0.5), stores the predictions in a vector `Y_prediction`. If you wish, you can use an `if`/`else` statement in a `for` loop (though there is also a way to vectorize this).

# %%
# GRADED FUNCTION: predict

def predict(w, b, X):
    '''
    Predict whether the label is 0 or 1 using learned logistic regression parameters (w, b)
    
    Arguments:
    w -- weights, a numpy array of size (num_px * num_px * 3, 1)
    b -- bias, a scalar
    X -- data of size (num_px * num_px * 3, number of examples)
    
    Returns:
    Y_prediction -- a numpy array (vector) containing all predictions (0/1) for the examples in X
    '''
    
    m = X.shape[1]
    Y_prediction = np.zeros((1, m))
    w = w.reshape(X.shape[0], 1)
    
    # Compute vector "A" predicting the probabilities of a cat being present in the picture
    #(≈ 1 line of code)
    # A = ...
    # YOUR CODE STARTS HERE
    A = sigmoid( np.dot(w.T, X) + b)
    # YOUR CODE ENDS HERE
    
    for i in range(A.shape[1]):
        
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        #(≈ 4 lines of code)
        # if A[0, i] > ____ :
        #     Y_prediction[0,i] = 
        # else:
        #     Y_prediction[0,i] = 
        # YOUR CODE STARTS HERE
        if A[0,i]>0.5:
            Y_prediction[0,i] = 1
        else:
            Y_prediction[0,i] = 0
        # YOUR CODE ENDS HERE
    
    return Y_prediction

# %%
w = np.array([[0.1124579], [0.23106775]])
b = -0.3
X = np.array([[1., -1.1, -3.2],[1.2, 2., 0.1]])
print ("predictions = " + str(predict(w, b, X)))

predict_test(predict)
# Out:
# predictions = [[1. 1. 0.]]
# All tests passed!

# %% [markdown]
# <font color='blue'>
#
# **What to remember:**
#
# You've implemented several functions that:
# - Initialize (w,b)
# - Optimize the loss iteratively to learn parameters (w,b):
#     - Computing the cost and its gradient
#     - Updating the parameters using gradient descent
# - Use the learned (w,b) to predict the labels for a given set of examples

# %% [markdown]
# <a name='5'></a>
# ## 5 - Merge all functions into a model ##
#
# You will now see how the overall model is structured by putting together all the building blocks (functions implemented in the previous parts) together, in the right order.
#
# <a name='ex-8'></a>
# ### Exercise 8 - model
# Implement the model function. Use the following notation:
#     - Y_prediction_test for your predictions on the test set
#     - Y_prediction_train for your predictions on the train set
#     - parameters, grads, costs for the outputs of optimize()

# %%
# GRADED FUNCTION: model

def model(X_train, Y_train, X_test, Y_test, num_iterations=2000, learning_rate=0.005, print_cost=True):
    """
    Builds the logistic regression model by calling the function you've implemented previously
    
    Arguments:
    X_train -- training set represented by a numpy array of shape (num_px * num_px * 3, m_train)
    Y_train -- training labels represented by a numpy array (vector) of shape (1, m_train)
    X_test -- test set represented by a numpy array of shape (num_px * num_px * 3, m_test)
    Y_test -- test labels represented by a numpy array (vector) of shape (1, m_test)
    num_iterations -- hyperparameter representing the number of iterations to optimize the parameters
    learning_rate -- hyperparameter representing the learning rate used in the update rule of optimize()
    print_cost -- Set to True to print the cost every 100 iterations
    
    Returns:
    d -- dictionary containing information about the model.
    """
    # (≈ 1 line of code)   
    # initialize parameters with zeros 
    # w, b = ...
    
    #(≈ 1 line of code)
    # Gradient descent 
    # params, grads, costs = ...
    
    # Retrieve parameters w and b from dictionary "params"
    # w = ...
    # b = ...
    
    # Predict test/train set examples (≈ 2 lines of code)
    # Y_prediction_test = ...
    # Y_prediction_train = ...
    
    # YOUR CODE STARTS HERE
    w, b = initialize_with_zeros(X_train.shape[0])
    params, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    w = params["w"]
    b = params["b"]
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)
    # YOUR CODE ENDS HERE

    # Print train/test Errors
    if print_cost:
        print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
        print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    
    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

# %%
from public_tests import *

model_test(model)
# Out:
# Cost after iteration 0: 0.693147
# train accuracy: 85.71428571428572 %
# test accuracy: 66.66666666666667 %
# All tests passed!

# %% [markdown]
# If you pass all the tests, run the following cell to train your model.

# %%
logistic_regression_model = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations=2000, learning_rate=0.005, print_cost=True)
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.039637
# Cost after iteration 200: 0.026934
# Cost after iteration 300: 0.021348
# Cost after iteration 400: 0.018009
# Cost after iteration 500: 0.015725
# Cost after iteration 600: 0.014039
# Cost after iteration 700: 0.012732
# Cost after iteration 800: 0.011681
# Cost after iteration 900: 0.010815
# Cost after iteration 1000: 0.010086
# Cost after iteration 1100: 0.009462
# Cost after iteration 1200: 0.008921
# Cost after iteration 1300: 0.008447
# Cost after iteration 1400: 0.008026
# Cost after iteration 1500: 0.007651
# Cost after iteration 1600: 0.007313
# Cost after iteration 1700: 0.007006
# Cost after iteration 1800: 0.006727
# Cost after iteration 1900: 0.006471
# train accuracy: 99.97129735935707 %
# test accuracy: 87.84615384615384 %

# %% [markdown]
# **Comment**: Training accuracy is close to 100%. This is a good sanity check: your model is working and has high enough capacity to fit the training data. Test accuracy is 70%. It is actually not bad for this simple model, given the small dataset we used and that logistic regression is a linear classifier. But no worries, you'll build an even better classifier next week!
#
# Also, you see that the model is clearly overfitting the training data. Later in this specialization you will learn how to reduce overfitting, for example by using regularization. Using the code below (and changing the `index` variable) you can look at predictions on pictures of the test set.

# %%
# Example of a picture that was wrongly classified.
index = 1
plt.imshow(test_set_x[:, index].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[0,index]) + ", you predicted that it is a \"" + classes[int(logistic_regression_model['Y_prediction_test'][0,index])].decode("utf-8") +  "\" picture.")
# Out:
# y = 0.0, you predicted that it is a "NO_LENS" picture.

# %% [markdown]
# Let's also plot the cost function and the gradients.

# %%
# Plot learning curve (with costs)
costs = np.squeeze(logistic_regression_model['costs'])
plt.plot(costs)
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title("Learning rate =" + str(logistic_regression_model["learning_rate"]))
plt.show()

# %% [markdown]
# **Interpretation**:
# You can see the cost decreasing. It shows that the parameters are being learned. However, you see that you could train the model even more on the training set. Try to increase the number of iterations in the cell above and rerun the cells. You might see that the training set accuracy goes up, but the test set accuracy goes down. This is called overfitting.

# %% [markdown]
# <a name='6'></a>
# ## 6 - Further analysis (optional/ungraded exercise) ##
#
# Congratulations on building your first image classification model. Let's analyze it further, and examine possible choices for the learning rate $\alpha$.

# %% [markdown]
# #### Choice of learning rate ####
#
# **Reminder**:
# In order for Gradient Descent to work you must choose the learning rate wisely. The learning rate $\alpha$  determines how rapidly we update the parameters. If the learning rate is too large we may "overshoot" the optimal value. Similarly, if it is too small we will need too many iterations to converge to the best values. That's why it is crucial to use a well-tuned learning rate.
#
# Let's compare the learning curve of our model with several choices of learning rates. Run the cell below. This should take about 1 minute. Feel free also to try different values than the three we have initialized the `learning_rates` variable to contain, and see what happens.

# %%
learning_rates = [0.01, 0.001, 0.0001]
models = {}

for lr in learning_rates:
    print ("Training a model with learning rate: " + str(lr))
    models[str(lr)] = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations=1500, learning_rate=lr, print_cost=True)
    print ('\n' + "-------------------------------------------------------" + '\n')

for lr in learning_rates:
    plt.plot(np.squeeze(models[str(lr)]["costs"]), label=str(models[str(lr)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations (hundreds)')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# Training a model with learning rate: 0.01
#
# -------------------------------------------------------
#
# Training a model with learning rate: 0.001
#
# -------------------------------------------------------
#
# Training a model with learning rate: 0.0001
#
# -------------------------------------------------------

# %% [markdown]
# **Interpretation**:
# - Different learning rates give different costs and thus different predictions results.
# - If the learning rate is too large (0.01), the cost may oscillate up and down. It may even diverge (though in this example, using 0.01 still eventually ends up at a good value for the cost).
# - A lower cost doesn't mean a better model. You have to check if there is possibly overfitting. It happens when the training accuracy is a lot higher than the test accuracy.
# - In deep learning, we usually recommend that you:
#     - Choose the learning rate that better minimizes the cost function.
#     - If your model overfits, use other techniques to reduce overfitting. (We'll talk about this in later videos.)

# %% [markdown]
# <a name='7'></a>
# ## 7 - Test with your own image (optional/ungraded exercise) ##
#
# Congratulations on finishing this assignment. You can use your own image and see the output of your model. To do that:
#     1. Click on "File" in the upper bar of this notebook, then click "Open" to go on your Coursera Hub.
#     2. Add your image to this Jupyter Notebook's directory, in the "images" folder
#     3. Change your image's name in the following code
#     4. Run the code and check if the algorithm is right (1 = cat, 0 = non-cat)!

# %%
# saving here W and b...

logistic_regression_model["w"]
# Out:
# array([[ 0.00043066],
#        [ 0.00041287],
#        [-0.00012732],
#        ...,
#        [-0.00036337],
#        [-0.00067307],
#        [-0.00165172]])

# %%
logistic_regression_model["w"].shape
# Out:
# (141267, 1)

# %%
logistic_regression_model["w"].tofile('pesos_w.csv', sep = ',')

# %%
logistic_regression_model["b"]
# Out:
# -0.016752920110698646

# %%
logistic_regression_model["b"].tofile('pesos_b.csv', sep = ',')

# %%
# We preprocess the image to fit your algorithm.
def predecir(my_image): 
    fname = "images/" + my_image
    image = np.array(Image.open(fname).resize((num_px, num_px)))
    plt.rcParams ["figure.figsize"] = (5,5)
    plt.imshow(image)
    image = image / 255.
    image = image.reshape((1, num_px * num_px * 3)).T
    my_predicted_image = predict(logistic_regression_model["w"], logistic_regression_model["b"], image)
    print("y = " + str(np.squeeze(my_predicted_image)) + ", your algorithm predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")

# %%
# change this to the name of your image file
my_image = "gato_no_1.jpg"   
predecir(my_image)
# Out:
# y = 1.0, your algorithm predicts a "LENS" picture.

# %%
image = cv2.imread('images/smacs.jpeg')
plt.imshow(image)
plt.rcParams ["figure.figsize"] = (15,15)
plt.show()

# %%
my_image = "smacs0723.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_no_1.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_no_2.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_no_3.jpg"   
predecir(my_image)
# Out:
# y = 1.0, your algorithm predicts a "LENS" picture.

# %%
my_image = "lente_no_4.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_no_5.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_sino_1.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_sino_2.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_sino_3.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_si_1.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_si_2.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_si_3.jpg"   
predecir(my_image)
# Out:
# y = 1.0, your algorithm predicts a "LENS" picture.

# %%
my_image = "lente_si_4.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %%
my_image = "lente_si_5.jpg"   
predecir(my_image)
# Out:
# y = 1.0, your algorithm predicts a "LENS" picture.

# %%
my_image = "lente_si_6.jpg"   
predecir(my_image)
# Out:
# y = 0.0, your algorithm predicts a "NO_LENS" picture.

# %% [markdown]
# <font color='blue'>
#
# **What to remember from this assignment:**
# 1. Preprocessing the dataset is important.
# 2. You implemented each function separately: initialize(), propagate(), optimize(). Then you built a model().
# 3. Tuning the learning rate (which is an example of a "hyperparameter") can make a big difference to the algorithm. You will see more examples of this later in this course!

# %% [markdown]
# Finally, if you'd like, we invite you to try different things on this Notebook. Make sure you submit before trying anything. Once you submit, things you can play with include:
#     - Play with the learning rate and the number of iterations
#     - Try different initialization methods and compare the results
#     - Test other preprocessings (center the data, or divide each row by its standard deviation)

# %% [markdown]
# Bibliography:
# - http://www.wildml.com/2015/09/implementing-a-neural-network-from-scratch/
# - https://stats.stackexchange.com/questions/211436/why-do-we-normalize-images-by-subtracting-the-datasets-image-mean-and-not-the-c
