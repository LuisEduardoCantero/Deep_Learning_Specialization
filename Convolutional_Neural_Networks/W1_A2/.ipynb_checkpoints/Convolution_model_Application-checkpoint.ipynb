# %% [markdown]
# # Convolutional Neural Networks: Application
#
# Welcome to Course 4's second assignment! In this notebook, you will:
#
# - Create a mood classifer using the TF Keras Sequential API
# - Build a ConvNet to identify sign language digits using the TF Keras Functional API
#
# **After this assignment you will be able to:**
#
# - Build and train a ConvNet in TensorFlow for a __binary__ classification problem
# - Build and train a ConvNet in TensorFlow for a __multiclass__ classification problem
# - Explain different use cases for the Sequential and Functional APIs
#
# To complete this assignment, you should already be familiar with TensorFlow. If you are not, please refer back to the **TensorFlow Tutorial** of the third week of Course 2 ("**Improving deep neural networks**").
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/convolutional-neural-networks/supplement/DS4yP/h-ow-to-refresh-your-workspace).

# %% [markdown]
# ## Table of Contents
#
# - [1 - Packages](#1)
#     - [1.1 - Load the Data and Split the Data into Train/Test Sets](#1-1)
# - [2 - Layers in TF Keras](#2)
# - [3 - The Sequential API](#3)
#     - [3.1 - Create the Sequential Model](#3-1)
#         - [Exercise 1 - happyModel](#ex-1)
#     - [3.2 - Train and Evaluate the Model](#3-2)
# - [4 - The Functional API](#4)
#     - [4.1 - Load the SIGNS Dataset](#4-1)
#     - [4.2 - Split the Data into Train/Test Sets](#4-2)
#     - [4.3 - Forward Propagation](#4-3)
#         - [Exercise 2 - convolutional_model](#ex-2)
#     - [4.4 - Train the Model](#4-4)
# - [5 - History Object](#5)
# - [6 - Bibliography](#6)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# As usual, begin by loading in the packages.

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)
# Out:
# 2022-12-05 23:50:12.988923: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 23:50:12.988999: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import tensorflow as tf
from astroNN.datasets import galaxy10
import sklearn
from sklearn.model_selection import train_test_split
#import scipy.ndimage
import cv2
from skimage.transform import PiecewiseAffineTransform, warp
from skimage import data
import os
import pandas as pd
import imutils
# Out:
# WARNING! APOGEE environment variable SDSS_LOCAL_SAS_MIRROR not set
# WARNING! Gaia environment variable GAIA_TOOLS_DATA not set

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Load the Data and Split the Data into Train/Test Sets
#
# You'll be using the Happy House dataset for this part of the assignment, which contains images of peoples' faces. Your task will be to build a ConvNet that determines whether the people in the images are smiling or not -- because they only get to enter the house if they're smiling!

# %%
n_pixeles=64
dimens = (n_pixeles, n_pixeles)

# %%
# Crear un solo arreglo de todas las imagenes dentro de las carpetas TRAIN
image1 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies/0_Smooth, in-between round.png')
image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
image2 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies/1000_Disk, Face-on, No Spiral.png')
image2 = cv2.resize(image2, dimens, interpolation = cv2.INTER_AREA)

train_set_x_orig_2 = np.append(image1 , image1)
train_set_x_orig_2.shape

basepath = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies/'
print(basepath)

i = 0
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            #print(str(entry.name))
            if(i > 1):
                name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies/' + str(entry.name)
                image1 = cv2.imread(name)
                image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
                imaget = train_set_x_orig_2
                train_set_x_orig_2 = np.append(imaget , image1)
        i = i+1
        
basepath2 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst/'
print(basepath2)

with os.scandir(basepath2) as entries:
    for entry in entries:
        if entry.is_file():
            #print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)  
            
basepath3 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_2/'
print(basepath3) 
    
with os.scandir(basepath3) as entries:
    for entry in entries:
        if entry.is_file():
            #print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_2/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)              

            
basepath4 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lens/'
print(basepath4) 

with os.scandir(basepath4) as entries:
    for entry in entries:
        if entry.is_file():
            #print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)
            
basepath5 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_lens/'
print(basepath5)

with os.scandir(basepath5) as entries:
    for entry in entries:
        if entry.is_file():
            #print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = train_set_x_orig_2
            train_set_x_orig_2 = np.append(imaget , image1)            
      

p2 = train_set_x_orig_2.shape[0]/(n_pixeles*n_pixeles*3) 
r2 = int(p2)
plt.imshow(train_set_x_orig_2.reshape(r2, n_pixeles, n_pixeles, 3)[0])
# Out:
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies/
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst/
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_2/
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lens/
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/train_galaxies_lsst_lens/

# %%
# Crear un solo arreglo de todas las imagenes dentro de las carpetas TEST
image1 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies/0_Smooth, in-between round.png')
image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
image2 = cv2.imread('/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies/1000_Disk, Edge-on, Rounded Bulge.png')
image2 = cv2.resize(image2, dimens, interpolation = cv2.INTER_AREA)

test_set_x_orig_2 = np.append(image1 , image1)
test_set_x_orig_2.shape

basepath = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies/'
print(basepath)
i = 0
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            if(i > 1):
                name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies/' + str(entry.name)
                image1 = cv2.imread(name)
                image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
                imaget = test_set_x_orig_2
                test_set_x_orig_2 = np.append(imaget , image1)
        i = i + 1   

basepath2 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies_lsst/'
print(basepath2)        
with os.scandir(basepath2) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies_lsst/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = test_set_x_orig_2
            test_set_x_orig_2 = np.append(imaget , image1)

basepath3 = '/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies_lens/'
print(basepath3)       
with os.scandir(basepath3) as entries:
    for entry in entries:
        if entry.is_file():
            print(str(entry.name))
            name = f'/home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies_lens/' + str(entry.name)
            image1 = cv2.imread(name)
            image1 = cv2.resize(image1, dimens, interpolation = cv2.INTER_AREA)
            imaget = test_set_x_orig_2
            test_set_x_orig_2 = np.append(imaget , image1)
        
p = test_set_x_orig_2.shape[0]/(n_pixeles*n_pixeles*3) 
r = int(p)
plt.imshow(test_set_x_orig_2.reshape(r, n_pixeles, n_pixeles, 3)[1])
# Out:
# /home/luiscantero/Hola/Python/deep_learning/Neural_Networks_and_Deep_Learning/W2_A2/test_galaxies/
# 0_Smooth, in-between round.png
# 1000_Disk, Edge-on, Rounded Bulge.png
# 1001_Disk, Face-on, No Spiral.png
# 1002_Smooth, in-between round.png
# 1003_Smooth, Completely round.png
# 1004_Smooth, Completely round.png
# 1005_Smooth, in-between round.png
# 1006_Smooth, Completely round.png
# 1007_Smooth, Completely round.png
# 1008_Smooth, Completely round.png
# 1009_Smooth, Completely round.png
# 100_Disk, Face-on, No Spiral.png
# 1010_Disk, Edge-on, Rounded Bulge.png
# 1011_Disk, Face-on, No Spiral.png
# 1012_Smooth, Completely round.png
# 1013_Smooth, in-between round.png
# 1014_Smooth, Completely round.png
# 1015_Disk, Face-on, No Spiral.png
# 1016_Smooth, in-between round.png
# 1017_Disk, Face-on, No Spiral.png
# 1018_Disk, Face-on, Loose Spiral.png
# 1019_Disk, Edge-on, Rounded Bulge.png
# 101_Smooth, Completely round.png
# 1020_Smooth, in-between round.png
# 1021_Disk, Face-on, Medium Spiral.png
# 1022_Smooth, Cigar shaped.png
# 1023_Smooth, in-between round.png
# 1024_Smooth, Completely round.png
# 1025_Disk, Edge-on, Rounded Bulge.png
# 1026_Disk, Face-on, Medium Spiral.png
# 1027_Disk, Face-on, Tight Spiral.png
# 1028_Disk, Face-on, No Spiral.png
# 1029_Smooth, Completely round.png
# 102_Disk, Face-on, Loose Spiral.png
# 1030_Disk, Edge-on, Rounded Bulge.png
# 1031_Disk, Face-on, Tight Spiral.png
# 1032_Disk, Face-on, No Spiral.png
# 1033_Disk, Face-on, No Spiral.png
# 1034_Smooth, Completely round.png
# 1035_Disk, Edge-on, Rounded Bulge.png
# 1036_Smooth, in-between round.png
# 1037_Smooth, Completely round.png
# 1038_Disk, Face-on, Loose Spiral.png
# 1039_Smooth, Completely round.png
# 103_Smooth, in-between round.png
# 1040_Smooth, Completely round.png
# 1041_Smooth, in-between round.png
# 1042_Smooth, Completely round.png
# 1043_Smooth, Completely round.png
# 1044_Disk, Edge-on, Rounded Bulge.png
# 1045_Smooth, in-between round.png
# 1046_Disk, Face-on, Medium Spiral.png
# 1047_Smooth, Completely round.png
# 1048_Smooth, Completely round.png
# 1049_Disk, Face-on, Medium Spiral.png
# 104_Disk, Face-on, Medium Spiral.png
# 1050_Smooth, in-between round.png
# 1051_Smooth, in-between round.png
# 1052_Disk, Edge-on, Rounded Bulge.png
# 1053_Smooth, in-between round.png
# 1054_Smooth, in-between round.png
# 1055_Smooth, in-between round.png
# 1056_Smooth, Completely round.png
# 1057_Disk, Face-on, Tight Spiral.png
# 1058_Disk, Edge-on, Rounded Bulge.png
# 1059_Disk, Face-on, No Spiral.png
# 105_Smooth, Completely round.png
# 1060_Smooth, in-between round.png
# 1061_Smooth, Completely round.png
# 1062_Disk, Face-on, Medium Spiral.png
# 1063_Disk, Face-on, Loose Spiral.png
# 1064_Smooth, Completely round.png
# 1065_Disk, Edge-on, Rounded Bulge.png
# 1066_Disk, Face-on, No Spiral.png
# 1067_Smooth, Completely round.png
# 1068_Smooth, Completely round.png
# 1069_Smooth, in-between round.png
# 106_Smooth, Completely round.png
# 1070_Disk, Face-on, Medium Spiral.png
# 1071_Disk, Edge-on, No Bulge.png
# 1072_Disk, Face-on, No Spiral.png
# 1073_Smooth, Completely round.png
# 1074_Disk, Face-on, Loose Spiral.png
# 1075_Smooth, in-between round.png
# 1076_Smooth, in-between round.png
# 1077_Disk, Face-on, Medium Spiral.png
# 1078_Smooth, Completely round.png
# 1079_Disk, Edge-on, Rounded Bulge.png
# 107_Smooth, Completely round.png
# 1080_Smooth, in-between round.png
# 1081_Smooth, Completely round.png
# 1082_Disk, Edge-on, Rounded Bulge.png
# 1083_Smooth, Cigar shaped.png
# 1084_Smooth, Completely round.png
# 1085_Disk, Edge-on, No Bulge.png
# 1086_Smooth, in-between round.png
# 1087_Disk, Edge-on, Rounded Bulge.png
# 1088_Smooth, Completely round.png
# 1089_Smooth, in-between round.png
# 108_Smooth, Completely round.png
# 1090_Smooth, Completely round.png
# 1091_Smooth, Completely round.png
# 1092_Smooth, Completely round.png
# 1093_Smooth, Completely round.png
# 1094_Smooth, in-between round.png
# 1095_Disk, Edge-on, Rounded Bulge.png
# 1096_Smooth, in-between round.png
# 1097_Smooth, Completely round.png
# 1098_Disk, Face-on, Loose Spiral.png
# 1099_Smooth, Completely round.png
# 109_Smooth, Completely round.png
# 10_Smooth, Completely round.png
# 1100_Smooth, Completely round.png
# 1101_Disk, Face-on, No Spiral.png
# 1102_Smooth, in-between round.png
# 1103_Smooth, Completely round.png
# 1104_Disk, Face-on, No Spiral.png
# 1105_Disk, Face-on, No Spiral.png
# 1106_Disk, Edge-on, Rounded Bulge.png
# 1107_Disk, Face-on, Tight Spiral.png
# 1108_Smooth, in-between round.png
# 1109_Disk, Face-on, No Spiral.png
# 110_Smooth, in-between round.png
# 1110_Smooth, Completely round.png
# 1111_Disk, Face-on, No Spiral.png
# 1112_Disk, Face-on, Tight Spiral.png
# 1113_Disk, Face-on, No Spiral.png
# 1114_Disk, Face-on, No Spiral.png
# 1115_Smooth, in-between round.png
# 1116_Smooth, Completely round.png
# 1117_Disk, Face-on, No Spiral.png
# 1118_Smooth, in-between round.png
# 1119_Smooth, Completely round.png
# 111_Disk, Face-on, No Spiral.png
# 1120_Smooth, Completely round.png
# 1121_Disk, Face-on, Tight Spiral.png
# 1122_Smooth, in-between round.png
# 1123_Disk, Face-on, Medium Spiral.png
# 1124_Disk, Edge-on, Rounded Bulge.png
# 1125_Smooth, Completely round.png
# 1126_Smooth, in-between round.png
# 1127_Disk, Face-on, No Spiral.png
# 1128_Disk, Face-on, Loose Spiral.png
# 1129_Smooth, Completely round.png
# 112_Disk, Edge-on, Rounded Bulge.png
# 1130_Smooth, Completely round.png
# 1131_Smooth, Completely round.png
# 1132_Disk, Face-on, No Spiral.png
# 1133_Smooth, Completely round.png
# 1134_Smooth, Completely round.png
# 1135_Smooth, in-between round.png
# 1136_Smooth, in-between round.png
# 1137_Disk, Face-on, No Spiral.png
# 1138_Smooth, Completely round.png
# 1139_Smooth, Completely round.png
# 113_Disk, Face-on, No Spiral.png
# 1140_Smooth, in-between round.png
# 1141_Disk, Face-on, No Spiral.png
# 1142_Smooth, in-between round.png
# 1143_Disk, Face-on, No Spiral.png
# 1144_Disk, Face-on, No Spiral.png
# 1145_Disk, Face-on, No Spiral.png
# 1146_Smooth, in-between round.png
# 1147_Smooth, Completely round.png
# 1148_Smooth, in-between round.png
# 1149_Smooth, in-between round.png
# 114_Disk, Edge-on, Rounded Bulge.png
# 1150_Smooth, in-between round.png
# 1151_Disk, Edge-on, Rounded Bulge.png
# 1152_Disk, Face-on, No Spiral.png
# 1153_Smooth, Cigar shaped.png
# 1154_Smooth, in-between round.png
# 1155_Smooth, in-between round.png
# 1156_Disk, Face-on, No Spiral.png
# 1157_Smooth, Completely round.png
# 1158_Disk, Face-on, No Spiral.png
# 1159_Smooth, Completely round.png
# 115_Smooth, Completely round.png
# 1160_Disk, Face-on, Tight Spiral.png
# 1161_Disk, Face-on, Tight Spiral.png
# 1162_Smooth, Completely round.png
# 1163_Smooth, in-between round.png
# 1164_Disk, Edge-on, Rounded Bulge.png
# 1165_Smooth, Completely round.png
# 1166_Disk, Face-on, No Spiral.png
# 1167_Smooth, Completely round.png
# 1168_Disk, Edge-on, No Bulge.png
# 1169_Disk, Face-on, No Spiral.png
# 116_Disk, Edge-on, Rounded Bulge.png
# 1170_Smooth, Completely round.png
# 1171_Smooth, Completely round.png
# 1172_Disk, Face-on, No Spiral.png
# 1173_Smooth, Completely round.png
# 1174_Disk, Face-on, No Spiral.png
# 1175_Smooth, Completely round.png
# 1176_Smooth, in-between round.png
# 1177_Disk, Edge-on, No Bulge.png
# 1178_Disk, Face-on, No Spiral.png
# 1179_Disk, Edge-on, Rounded Bulge.png
# 117_Disk, Edge-on, Rounded Bulge.png
# 1180_Disk, Face-on, No Spiral.png
# 1181_Smooth, in-between round.png
# 1182_Smooth, in-between round.png
# 1183_Smooth, in-between round.png
# 1184_Smooth, Completely round.png
# 1185_Disk, Edge-on, Rounded Bulge.png
# 1186_Smooth, Cigar shaped.png
# 1187_Smooth, in-between round.png
# 1188_Smooth, Completely round.png
# 1189_Smooth, Completely round.png
# 118_Smooth, Completely round.png
# 1190_Smooth, Completely round.png
# 1191_Disk, Face-on, No Spiral.png
# 1192_Smooth, in-between round.png
# 1193_Smooth, Completely round.png
# 1194_Smooth, Completely round.png
# 1195_Disk, Face-on, No Spiral.png
# 1196_Smooth, in-between round.png
# 1197_Smooth, Completely round.png
# 1198_Smooth, in-between round.png
# 1199_Smooth, in-between round.png
# 119_Smooth, in-between round.png
# 11_Smooth, in-between round.png
# 1200_Smooth, in-between round.png
# 1201_Smooth, in-between round.png
# 1202_Disk, Face-on, Medium Spiral.png
# 1203_Smooth, in-between round.png
# 1204_Smooth, Cigar shaped.png
# 1205_Smooth, Completely round.png
# 1206_Smooth, Completely round.png
# 1207_Disk, Face-on, No Spiral.png
# 1208_Disk, Face-on, Loose Spiral.png
# 1209_Smooth, in-between round.png
# 120_Smooth, in-between round.png
# 1210_Smooth, Completely round.png
# 1211_Smooth, Completely round.png
# 1212_Smooth, Completely round.png
# 1213_Smooth, Cigar shaped.png
# 1214_Disk, Face-on, Medium Spiral.png
# 1215_Smooth, in-between round.png
# 1216_Disk, Face-on, Tight Spiral.png
# 1217_Disk, Face-on, Medium Spiral.png
# 1218_Disk, Face-on, No Spiral.png
# 1219_Smooth, Completely round.png
# 121_Smooth, in-between round.png
# 1220_Disk, Edge-on, Rounded Bulge.png
# 1221_Smooth, in-between round.png
# 1222_Disk, Face-on, Tight Spiral.png
# 1223_Disk, Edge-on, Rounded Bulge.png
# 1224_Smooth, in-between round.png
# 1225_Smooth, Completely round.png
# 1226_Smooth, in-between round.png
# 1227_Disk, Face-on, No Spiral.png
# 1228_Smooth, Completely round.png
# 1229_Smooth, Completely round.png
# 122_Smooth, in-between round.png
# 1230_Disk, Edge-on, Rounded Bulge.png
# 1231_Smooth, Completely round.png
# 1232_Disk, Face-on, No Spiral.png
# 1233_Smooth, Completely round.png
# 1234_Disk, Edge-on, Rounded Bulge.png
# 1235_Disk, Face-on, No Spiral.png
# 1236_Smooth, in-between round.png
# 1237_Smooth, Completely round.png
# 1238_Disk, Edge-on, Rounded Bulge.png
# 1239_Smooth, Completely round.png
# 123_Smooth, Completely round.png
# 1240_Disk, Edge-on, Rounded Bulge.png
# 1241_Smooth, in-between round.png
# 1242_Smooth, Completely round.png
# 1243_Smooth, Cigar shaped.png
# 1244_Disk, Face-on, No Spiral.png
# 1245_Disk, Face-on, No Spiral.png
# 1246_Smooth, Completely round.png
# 1247_Smooth, in-between round.png
# 1248_Smooth, in-between round.png
# 1249_Smooth, Completely round.png
# 124_Smooth, in-between round.png
# 1250_Smooth, in-between round.png
# 1251_Disk, Face-on, No Spiral.png
# 1252_Smooth, in-between round.png
# 1253_Disk, Edge-on, No Bulge.png
# 1254_Disk, Face-on, Medium Spiral.png
# 1255_Disk, Face-on, Tight Spiral.png
# 1256_Disk, Face-on, No Spiral.png
# 1257_Smooth, in-between round.png
# 1258_Smooth, Completely round.png
# 1259_Smooth, in-between round.png
# 125_Disk, Face-on, Tight Spiral.png
# 1260_Smooth, Completely round.png
# 1261_Disk, Face-on, No Spiral.png
# 1262_Smooth, Completely round.png
# 1263_Smooth, Completely round.png
# 1264_Smooth, Completely round.png
# 1265_Disk, Face-on, No Spiral.png
# 1266_Smooth, Cigar shaped.png
# 1267_Disk, Face-on, No Spiral.png
# 1268_Smooth, in-between round.png
# 1269_Smooth, in-between round.png
# 126_Smooth, Completely round.png
# 1270_Smooth, Cigar shaped.png
# 1271_Disk, Face-on, Tight Spiral.png
# 1272_Disk, Face-on, Tight Spiral.png
# 1273_Disk, Face-on, No Spiral.png
# 1274_Smooth, Completely round.png
# 1275_Disk, Face-on, Tight Spiral.png
# 1276_Smooth, Completely round.png
# 1277_Smooth, in-between round.png
# 1278_Smooth, Completely round.png
# 1279_Disk, Edge-on, Rounded Bulge.png
# 127_Disk, Face-on, No Spiral.png
# 1280_Disk, Face-on, No Spiral.png
# 1281_Smooth, Completely round.png
# 1282_Disk, Face-on, Tight Spiral.png
# 1283_Disk, Face-on, No Spiral.png
# 1284_Smooth, Completely round.png
# 1285_Smooth, in-between round.png
# 1286_Smooth, Cigar shaped.png
# 1287_Smooth, Completely round.png
# 1288_Smooth, Completely round.png
# 1289_Smooth, in-between round.png
# 128_Smooth, Completely round.png
# 1290_Disk, Face-on, No Spiral.png
# 1291_Smooth, in-between round.png
# 1292_Smooth, Completely round.png
# 1293_Disk, Face-on, Loose Spiral.png
# 1294_Smooth, Completely round.png
# 1295_Smooth, Completely round.png
# 1296_Disk, Face-on, No Spiral.png
# 1297_Disk, Face-on, Loose Spiral.png
# 1298_Smooth, in-between round.png
# 1299_Disk, Face-on, No Spiral.png
# 129_Smooth, Completely round.png
# 12_Smooth, Completely round.png
# 1300_Disk, Face-on, No Spiral.png
# 1301_Disk, Face-on, No Spiral.png
# 1302_Disk, Face-on, Loose Spiral.png
# 1303_Disk, Face-on, Tight Spiral.png
# 1304_Disk, Face-on, Medium Spiral.png
# 1305_Smooth, Completely round.png
# 1306_Smooth, Completely round.png
# 1307_Smooth, in-between round.png
# 1308_Smooth, Completely round.png
# 1309_Disk, Face-on, Tight Spiral.png
# 130_Smooth, in-between round.png
# 1310_Disk, Face-on, No Spiral.png
# 1311_Smooth, in-between round.png
# 1312_Smooth, Completely round.png
# 1313_Smooth, Cigar shaped.png
# 1314_Smooth, Completely round.png
# 1315_Smooth, Completely round.png
# 1316_Disk, Edge-on, Rounded Bulge.png
# 1317_Smooth, in-between round.png
# 1318_Disk, Face-on, No Spiral.png
# 1319_Smooth, in-between round.png
# 131_Smooth, Completely round.png
# 1320_Smooth, in-between round.png
# 1321_Smooth, Completely round.png
# 1322_Smooth, Completely round.png
# 1323_Disk, Face-on, No Spiral.png
# 1324_Disk, Face-on, No Spiral.png
# 1325_Smooth, Completely round.png
# 1326_Smooth, in-between round.png
# 1327_Smooth, Completely round.png
# 1328_Smooth, Completely round.png
# 1329_Disk, Edge-on, Rounded Bulge.png
# 132_Smooth, in-between round.png
# 1330_Disk, Edge-on, Rounded Bulge.png
# 1331_Smooth, Completely round.png
# 1332_Smooth, Completely round.png
# 1333_Smooth, Completely round.png
# 1334_Smooth, Completely round.png
# 1335_Smooth, Completely round.png
# 1336_Smooth, Completely round.png
# 1337_Smooth, in-between round.png
# 1338_Smooth, in-between round.png
# 1339_Disk, Face-on, Tight Spiral.png
# 133_Smooth, in-between round.png
# 1340_Smooth, in-between round.png
# 1341_Smooth, Completely round.png
# 1342_Disk, Edge-on, Rounded Bulge.png
# 1343_Smooth, in-between round.png
# 1344_Smooth, Completely round.png
# 1345_Smooth, in-between round.png
# 1346_Smooth, Completely round.png
# 1347_Disk, Face-on, No Spiral.png
# 1348_Disk, Face-on, No Spiral.png
# 1349_Disk, Face-on, No Spiral.png
# 134_Smooth, in-between round.png
# 1350_Disk, Face-on, Loose Spiral.png
# 1351_Smooth, Completely round.png
# 1352_Disk, Face-on, No Spiral.png
# 1353_Disk, Face-on, Tight Spiral.png
# 1354_Disk, Edge-on, Rounded Bulge.png
# 1355_Smooth, Completely round.png
# 1356_Smooth, Completely round.png
# 1357_Disk, Face-on, Tight Spiral.png
# 1358_Smooth, Completely round.png
# 1359_Disk, Edge-on, Rounded Bulge.png
# 135_Smooth, Cigar shaped.png
# 1360_Disk, Edge-on, No Bulge.png
# 1361_Disk, Face-on, Medium Spiral.png
# 1362_Disk, Edge-on, Rounded Bulge.png
# 1363_Smooth, Completely round.png
# 1364_Disk, Face-on, Tight Spiral.png
# 1365_Smooth, Cigar shaped.png
# 1366_Disk, Face-on, Loose Spiral.png
# 1367_Smooth, in-between round.png
# 1368_Smooth, in-between round.png
# 1369_Smooth, Completely round.png
# 136_Smooth, in-between round.png
# 1370_Smooth, Completely round.png
# 1371_Disk, Edge-on, Rounded Bulge.png
# 1372_Smooth, in-between round.png
# 1373_Smooth, in-between round.png
# 1374_Smooth, Completely round.png
# 1375_Smooth, in-between round.png
# 1376_Smooth, Completely round.png
# 1377_Smooth, in-between round.png
# 1378_Disk, Face-on, Medium Spiral.png
# 1379_Disk, Face-on, No Spiral.png
# 137_Smooth, in-between round.png
# 1380_Smooth, Completely round.png
# 1381_Disk, Face-on, No Spiral.png
# 1382_Disk, Face-on, No Spiral.png
# 1383_Smooth, Completely round.png
# 1384_Smooth, in-between round.png
# 1385_Disk, Face-on, Medium Spiral.png
# 1386_Smooth, in-between round.png
# 1387_Smooth, Completely round.png
# 1388_Smooth, Completely round.png
# 1389_Disk, Face-on, Loose Spiral.png
# 138_Smooth, in-between round.png
# 1390_Disk, Edge-on, Rounded Bulge.png
# 1391_Smooth, in-between round.png
# 1392_Smooth, in-between round.png
# 1393_Smooth, Completely round.png
# 1394_Smooth, Completely round.png
# 1395_Smooth, Completely round.png
# 1396_Smooth, Completely round.png
# 1397_Smooth, in-between round.png
# 1398_Disk, Face-on, No Spiral.png
# 1399_Smooth, Completely round.png
# 139_Disk, Edge-on, No Bulge.png
# 13_Smooth, in-between round.png
# 1400_Smooth, Completely round.png
# 1401_Smooth, Completely round.png
# 1402_Smooth, Completely round.png
# 1403_Disk, Face-on, No Spiral.png
# 1404_Smooth, Completely round.png
# 1405_Smooth, in-between round.png
# 1406_Disk, Face-on, No Spiral.png
# 1407_Smooth, in-between round.png
# 1408_Smooth, in-between round.png
# 1409_Disk, Face-on, No Spiral.png
# 140_Smooth, in-between round.png
# 1410_Smooth, in-between round.png
# 1411_Smooth, Completely round.png
# 1412_Disk, Face-on, Loose Spiral.png
# 1413_Smooth, in-between round.png
# 1414_Smooth, in-between round.png
# 1415_Smooth, in-between round.png
# 1416_Smooth, in-between round.png
# 1417_Smooth, Completely round.png
# 1418_Disk, Edge-on, No Bulge.png
# 1419_Disk, Face-on, No Spiral.png
# 141_Smooth, Completely round.png
# 1420_Smooth, Cigar shaped.png
# 1421_Disk, Face-on, No Spiral.png
# 1422_Smooth, Completely round.png
# 1423_Smooth, Completely round.png
# 1424_Smooth, Completely round.png
# 1425_Disk, Face-on, Tight Spiral.png
# 1426_Disk, Face-on, Tight Spiral.png
# 1427_Smooth, in-between round.png
# 1428_Smooth, Completely round.png
# 1429_Disk, Face-on, Loose Spiral.png
# 142_Disk, Face-on, Medium Spiral.png
# 1430_Disk, Face-on, No Spiral.png
# 1431_Disk, Edge-on, Boxy Bulge.png
# 1432_Smooth, Completely round.png
# 1433_Smooth, Completely round.png
# 1434_Disk, Edge-on, Rounded Bulge.png
# 1435_Disk, Edge-on, Rounded Bulge.png
# 1436_Disk, Face-on, No Spiral.png
# 1437_Smooth, in-between round.png
# 1438_Disk, Face-on, Loose Spiral.png
# 1439_Smooth, Completely round.png
# 143_Smooth, Completely round.png
# 1440_Disk, Edge-on, Rounded Bulge.png
# 1441_Smooth, in-between round.png
# 1442_Disk, Edge-on, No Bulge.png
# 1443_Disk, Face-on, Loose Spiral.png
# 1444_Disk, Edge-on, Rounded Bulge.png
# 1445_Smooth, Completely round.png
# 1446_Smooth, in-between round.png
# 1447_Smooth, Completely round.png
# 1448_Disk, Face-on, Medium Spiral.png
# 1449_Disk, Face-on, No Spiral.png
# 144_Disk, Face-on, Medium Spiral.png
# 1450_Disk, Edge-on, Rounded Bulge.png
# 1451_Disk, Face-on, Loose Spiral.png
# 1452_Disk, Face-on, No Spiral.png
# 1453_Smooth, in-between round.png
# 1454_Disk, Face-on, No Spiral.png
# 1455_Smooth, in-between round.png
# 1456_Disk, Face-on, No Spiral.png
# 1457_Disk, Face-on, Tight Spiral.png
# 1458_Disk, Face-on, No Spiral.png
# 1459_Smooth, in-between round.png
# 145_Smooth, in-between round.png
# 1460_Disk, Face-on, Tight Spiral.png
# 1461_Smooth, Completely round.png
# 1462_Smooth, in-between round.png
# 1463_Smooth, Completely round.png
# 1464_Disk, Face-on, No Spiral.png
# 1465_Smooth, in-between round.png
# 1466_Smooth, in-between round.png
# 1467_Smooth, in-between round.png
# 1468_Smooth, in-between round.png
# 1469_Disk, Face-on, No Spiral.png
# 146_Smooth, Completely round.png
# 1470_Smooth, Completely round.png
# 1471_Smooth, Completely round.png
# 1472_Disk, Edge-on, Rounded Bulge.png
# 1473_Disk, Face-on, Tight Spiral.png
# 1474_Disk, Face-on, Tight Spiral.png
# 1475_Disk, Face-on, No Spiral.png
# 1476_Disk, Edge-on, No Bulge.png
# 1477_Disk, Face-on, No Spiral.png
# 1478_Smooth, in-between round.png
# 1479_Smooth, in-between round.png
# 147_Smooth, in-between round.png
# 1480_Smooth, Completely round.png
# 1481_Disk, Face-on, No Spiral.png
# 1482_Disk, Face-on, No Spiral.png
# 1483_Disk, Face-on, No Spiral.png
# 1484_Smooth, in-between round.png
# 1485_Smooth, in-between round.png
# 1486_Smooth, in-between round.png
# 1487_Smooth, Cigar shaped.png
# 1488_Smooth, Completely round.png
# 1489_Disk, Edge-on, Rounded Bulge.png
# 148_Smooth, in-between round.png
# 1490_Smooth, Completely round.png
# 1491_Smooth, in-between round.png
# 1492_Smooth, in-between round.png
# 1493_Smooth, in-between round.png
# 1494_Smooth, Completely round.png
# 1495_Smooth, in-between round.png
# 1496_Disk, Edge-on, Rounded Bulge.png
# 1497_Smooth, Completely round.png
# 1498_Smooth, in-between round.png
# 1499_Smooth, in-between round.png
# 149_Disk, Face-on, Loose Spiral.png
# 14_Smooth, Completely round.png
# 150_Disk, Face-on, Medium Spiral.png
# 151_Smooth, Completely round.png
# 152_Smooth, Completely round.png
# 153_Smooth, Completely round.png
# 154_Smooth, Completely round.png
# 155_Smooth, Completely round.png
# 156_Smooth, Completely round.png
# 157_Disk, Face-on, No Spiral.png
# 158_Disk, Edge-on, Rounded Bulge.png
# 159_Smooth, Completely round.png
# 15_Disk, Face-on, No Spiral.png
# 160_Disk, Face-on, Loose Spiral.png
# 161_Smooth, Completely round.png
# 162_Smooth, Completely round.png
# 163_Smooth, in-between round.png
# 164_Smooth, Completely round.png
# 165_Disk, Face-on, No Spiral.png
# 166_Disk, Face-on, No Spiral.png
# 167_Disk, Edge-on, Rounded Bulge.png
# 168_Smooth, in-between round.png
# 169_Disk, Face-on, No Spiral.png
# 16_Disk, Face-on, No Spiral.png
# 170_Smooth, Completely round.png
# 171_Smooth, Completely round.png
# 172_Disk, Face-on, No Spiral.png
# 173_Smooth, Completely round.png
# 174_Disk, Face-on, Loose Spiral.png
# 175_Smooth, in-between round.png
# 176_Disk, Face-on, No Spiral.png
# 177_Smooth, in-between round.png
# 178_Disk, Face-on, No Spiral.png
# 179_Disk, Face-on, Tight Spiral.png
# 17_Smooth, in-between round.png
# 180_Smooth, in-between round.png
# 181_Disk, Face-on, No Spiral.png
# 182_Smooth, in-between round.png
# 183_Smooth, Completely round.png
# 184_Smooth, Completely round.png
# 185_Smooth, Completely round.png
# 186_Disk, Face-on, No Spiral.png
# 187_Smooth, in-between round.png
# 188_Smooth, in-between round.png
# 189_Disk, Face-on, Medium Spiral.png
# 18_Smooth, Completely round.png
# 190_Smooth, in-between round.png
# 191_Smooth, in-between round.png
# 192_Smooth, Completely round.png
# 193_Disk, Edge-on, No Bulge.png
# 194_Smooth, Completely round.png
# 195_Smooth, Completely round.png
# 196_Smooth, Completely round.png
# 197_Smooth, in-between round.png
# 198_Disk, Edge-on, Rounded Bulge.png
# 199_Disk, Edge-on, Rounded Bulge.png
# 19_Disk, Face-on, Medium Spiral.png
# 1_Smooth, Completely round.png
# 200_Smooth, Completely round.png
# 201_Disk, Edge-on, Rounded Bulge.png
# 202_Disk, Face-on, Tight Spiral.png
# 203_Disk, Face-on, No Spiral.png
# 204_Smooth, Completely round.png
# 205_Smooth, Completely round.png
# 206_Smooth, Completely round.png
# 207_Disk, Edge-on, Rounded Bulge.png
# 208_Smooth, Completely round.png
# 209_Smooth, in-between round.png
# 20_Disk, Face-on, No Spiral.png
# 210_Smooth, in-between round.png
# 211_Disk, Face-on, No Spiral.png
# 212_Smooth, Completely round.png
# 213_Smooth, in-between round.png
# 214_Disk, Face-on, Medium Spiral.png
# 215_Disk, Face-on, Loose Spiral.png
# 216_Smooth, Completely round.png
# 217_Smooth, Completely round.png
# 218_Smooth, in-between round.png
# 219_Disk, Face-on, No Spiral.png
# 21_Smooth, Completely round.png
# 220_Disk, Face-on, No Spiral.png
# 221_Smooth, Completely round.png
# 222_Disk, Edge-on, No Bulge.png
# 223_Smooth, in-between round.png
# 224_Disk, Face-on, No Spiral.png
# 225_Disk, Face-on, No Spiral.png
# 226_Smooth, Completely round.png
# 227_Disk, Face-on, No Spiral.png
# 228_Smooth, in-between round.png
# 229_Smooth, Completely round.png
# 22_Disk, Face-on, Medium Spiral.png
# 230_Smooth, Completely round.png
# 231_Smooth, Completely round.png
# 232_Disk, Face-on, No Spiral.png
# 233_Smooth, in-between round.png
# 234_Smooth, Completely round.png
# 235_Disk, Face-on, Tight Spiral.png
# 236_Disk, Face-on, No Spiral.png
# 237_Disk, Face-on, No Spiral.png
# 238_Disk, Face-on, Tight Spiral.png
# 239_Smooth, Completely round.png
# 23_Disk, Face-on, Medium Spiral.png
# 240_Disk, Edge-on, Rounded Bulge.png
# 241_Disk, Face-on, No Spiral.png
# 242_Smooth, Completely round.png
# 243_Disk, Face-on, No Spiral.png
# 244_Smooth, Completely round.png
# 245_Smooth, in-between round.png
# 246_Smooth, Completely round.png
# 247_Smooth, Completely round.png
# 248_Smooth, Completely round.png
# 249_Smooth, Cigar shaped.png
# 24_Disk, Face-on, No Spiral.png
# 250_Smooth, Completely round.png
# 251_Disk, Face-on, No Spiral.png
# 252_Smooth, in-between round.png
# 253_Disk, Face-on, No Spiral.png
# 254_Smooth, Completely round.png
# 255_Disk, Face-on, Tight Spiral.png
# 256_Disk, Face-on, Medium Spiral.png
# 257_Smooth, in-between round.png
# 258_Smooth, in-between round.png
# 259_Smooth, Completely round.png
# 25_Smooth, in-between round.png
# 260_Smooth, Completely round.png
# 261_Smooth, Completely round.png
# 262_Smooth, in-between round.png
# 263_Smooth, in-between round.png
# 264_Disk, Face-on, No Spiral.png
# 265_Smooth, in-between round.png
# 266_Smooth, Completely round.png
# 267_Smooth, Completely round.png
# 268_Disk, Face-on, Tight Spiral.png
# 269_Smooth, in-between round.png
# 26_Disk, Edge-on, Rounded Bulge.png
# 270_Smooth, Completely round.png
# 271_Smooth, Completely round.png
# 272_Smooth, Completely round.png
# 273_Smooth, Completely round.png
# 274_Smooth, in-between round.png
# 275_Smooth, Completely round.png
# 276_Smooth, Completely round.png
# 277_Smooth, in-between round.png
# 278_Smooth, Completely round.png
# 279_Disk, Face-on, No Spiral.png
# 27_Smooth, Completely round.png
# 280_Disk, Edge-on, Rounded Bulge.png
# 281_Smooth, in-between round.png
# 282_Disk, Edge-on, Rounded Bulge.png
# 283_Smooth, in-between round.png
# 284_Disk, Edge-on, No Bulge.png
# 285_Smooth, Completely round.png
# 286_Smooth, in-between round.png
# 287_Smooth, in-between round.png
# 288_Smooth, Completely round.png
# 289_Disk, Face-on, No Spiral.png
# 28_Smooth, in-between round.png
# 290_Disk, Face-on, Medium Spiral.png
# 291_Disk, Face-on, Tight Spiral.png
# 292_Smooth, in-between round.png
# 293_Smooth, Completely round.png
# 294_Disk, Edge-on, Rounded Bulge.png
# 295_Smooth, Completely round.png
# 296_Smooth, in-between round.png
# 297_Smooth, in-between round.png
# 298_Smooth, in-between round.png
# 299_Smooth, in-between round.png
# 29_Disk, Face-on, No Spiral.png
# 2_Disk, Face-on, No Spiral.png
# 300_Disk, Face-on, No Spiral.png
# 301_Smooth, Completely round.png
# 302_Smooth, Completely round.png
# 303_Disk, Edge-on, No Bulge.png
# 304_Disk, Edge-on, Rounded Bulge.png
# 305_Disk, Face-on, No Spiral.png
# 306_Smooth, in-between round.png
# 307_Disk, Face-on, Loose Spiral.png
# 308_Smooth, in-between round.png
# 309_Smooth, in-between round.png
# 30_Smooth, in-between round.png
# 310_Smooth, Completely round.png
# 311_Smooth, in-between round.png
# 312_Smooth, Completely round.png
# 313_Smooth, Completely round.png
# 314_Disk, Face-on, No Spiral.png
# 315_Smooth, Completely round.png
# 316_Disk, Face-on, No Spiral.png
# 317_Smooth, in-between round.png
# 318_Disk, Edge-on, Rounded Bulge.png
# 319_Smooth, Completely round.png
# 31_Smooth, Completely round.png
# 320_Disk, Face-on, Tight Spiral.png
# 321_Smooth, Completely round.png
# 322_Smooth, in-between round.png
# 323_Disk, Edge-on, Rounded Bulge.png
# 324_Disk, Face-on, No Spiral.png
# 325_Disk, Face-on, No Spiral.png
# 326_Smooth, in-between round.png
# 327_Smooth, in-between round.png
# 328_Smooth, Completely round.png
# 329_Smooth, Completely round.png
# 32_Smooth, Completely round.png
# 330_Disk, Face-on, Tight Spiral.png
# 331_Disk, Face-on, No Spiral.png
# 332_Disk, Face-on, No Spiral.png
# 333_Smooth, in-between round.png
# 334_Smooth, Completely round.png
# 335_Smooth, in-between round.png
# 336_Smooth, Completely round.png
# 337_Smooth, Completely round.png
# 338_Smooth, Completely round.png
# 339_Disk, Face-on, No Spiral.png
# 33_Smooth, Completely round.png
# 340_Smooth, Completely round.png
# 341_Smooth, in-between round.png
# 342_Disk, Face-on, No Spiral.png
# 343_Disk, Face-on, No Spiral.png
# 344_Smooth, Completely round.png
# 345_Disk, Edge-on, Rounded Bulge.png
# 346_Disk, Face-on, No Spiral.png
# 347_Disk, Face-on, No Spiral.png
# 348_Smooth, in-between round.png
# 349_Smooth, in-between round.png
# 34_Smooth, in-between round.png
# 350_Smooth, in-between round.png
# 351_Disk, Edge-on, Rounded Bulge.png
# 352_Disk, Face-on, Tight Spiral.png
# 353_Disk, Face-on, No Spiral.png
# 354_Smooth, Completely round.png
# 355_Smooth, in-between round.png
# 356_Disk, Face-on, Medium Spiral.png
# 357_Smooth, Completely round.png
# 358_Smooth, Completely round.png
# 359_Smooth, Completely round.png
# 35_Smooth, Completely round.png
# 360_Disk, Face-on, No Spiral.png
# 361_Disk, Face-on, No Spiral.png
# 362_Smooth, in-between round.png
# 363_Smooth, in-between round.png
# 364_Smooth, in-between round.png
# 365_Smooth, Completely round.png
# 366_Smooth, in-between round.png
# 367_Smooth, in-between round.png
# 368_Disk, Face-on, No Spiral.png
# 369_Smooth, Completely round.png
# 36_Smooth, in-between round.png
# 370_Disk, Face-on, Medium Spiral.png
# 371_Disk, Edge-on, No Bulge.png
# 372_Smooth, Completely round.png
# 373_Smooth, in-between round.png
# 374_Disk, Face-on, No Spiral.png
# 375_Smooth, Completely round.png
# 376_Smooth, Completely round.png
# 377_Smooth, Completely round.png
# 378_Smooth, Completely round.png
# 379_Disk, Face-on, No Spiral.png
# 37_Smooth, Completely round.png
# 380_Smooth, in-between round.png
# 381_Smooth, in-between round.png
# 382_Smooth, in-between round.png
# 383_Smooth, in-between round.png
# 384_Disk, Edge-on, Rounded Bulge.png
# 385_Disk, Face-on, No Spiral.png
# 386_Smooth, in-between round.png
# 387_Smooth, in-between round.png
# 388_Disk, Face-on, Tight Spiral.png
# 389_Disk, Edge-on, Rounded Bulge.png
# 38_Smooth, in-between round.png
# 390_Smooth, in-between round.png
# 391_Disk, Face-on, Loose Spiral.png
# 392_Smooth, Completely round.png
# 393_Smooth, in-between round.png
# 394_Smooth, in-between round.png
# 395_Smooth, Completely round.png
# 396_Smooth, Completely round.png
# 397_Smooth, Completely round.png
# 398_Disk, Face-on, No Spiral.png
# 399_Disk, Face-on, Medium Spiral.png
# 39_Smooth, in-between round.png
# 3_Smooth, in-between round.png
# 400_Smooth, Completely round.png
# 401_Smooth, Completely round.png
# 402_Disk, Edge-on, No Bulge.png
# 403_Smooth, in-between round.png
# 404_Smooth, Completely round.png
# 405_Smooth, Completely round.png
# 406_Smooth, Completely round.png
# 407_Smooth, Completely round.png
# 408_Smooth, Completely round.png
# 409_Smooth, in-between round.png
# 40_Smooth, Completely round.png
# 410_Disk, Face-on, Tight Spiral.png
# 411_Smooth, in-between round.png
# 412_Smooth, Completely round.png
# 413_Smooth, Completely round.png
# 414_Disk, Face-on, No Spiral.png
# 415_Smooth, Completely round.png
# 416_Disk, Edge-on, Rounded Bulge.png
# 417_Smooth, in-between round.png
# 418_Smooth, in-between round.png
# 419_Smooth, Completely round.png
# 41_Smooth, in-between round.png
# 420_Smooth, in-between round.png
# 421_Disk, Face-on, Medium Spiral.png
# 422_Disk, Edge-on, Rounded Bulge.png
# 423_Smooth, Completely round.png
# 424_Smooth, Completely round.png
# 425_Disk, Edge-on, Rounded Bulge.png
# 426_Disk, Face-on, No Spiral.png
# 427_Disk, Face-on, No Spiral.png
# 428_Disk, Face-on, Loose Spiral.png
# 429_Smooth, in-between round.png
# 42_Disk, Face-on, No Spiral.png
# 430_Disk, Edge-on, No Bulge.png
# 431_Disk, Face-on, No Spiral.png
# 432_Disk, Face-on, Tight Spiral.png
# 433_Smooth, Completely round.png
# 434_Smooth, Completely round.png
# 435_Disk, Face-on, No Spiral.png
# 436_Smooth, Completely round.png
# 437_Disk, Face-on, Medium Spiral.png
# 438_Disk, Edge-on, No Bulge.png
# 439_Smooth, Completely round.png
# 43_Disk, Edge-on, Rounded Bulge.png
# 440_Smooth, Completely round.png
# 441_Smooth, Cigar shaped.png
# 442_Smooth, Cigar shaped.png
# 443_Disk, Face-on, No Spiral.png
# 444_Smooth, in-between round.png
# 445_Disk, Face-on, Tight Spiral.png
# 446_Smooth, Completely round.png
# 447_Smooth, in-between round.png
# 448_Disk, Face-on, Medium Spiral.png
# 449_Smooth, in-between round.png
# 44_Smooth, in-between round.png
# 450_Smooth, in-between round.png
# 451_Smooth, Completely round.png
# 452_Smooth, Completely round.png
# 453_Disk, Face-on, No Spiral.png
# 454_Disk, Edge-on, Rounded Bulge.png
# 455_Smooth, in-between round.png
# 456_Smooth, Completely round.png
# 457_Smooth, Completely round.png
# 458_Smooth, Completely round.png
# 459_Smooth, Completely round.png
# 45_Smooth, in-between round.png
# 460_Disk, Edge-on, Rounded Bulge.png
# 461_Smooth, Completely round.png
# 462_Disk, Face-on, Tight Spiral.png
# 463_Smooth, in-between round.png
# 464_Disk, Edge-on, Rounded Bulge.png
# 465_Disk, Face-on, No Spiral.png
# 466_Smooth, Completely round.png
# 467_Smooth, Completely round.png
# 468_Smooth, in-between round.png
# 469_Smooth, Completely round.png
# 46_Disk, Face-on, No Spiral.png
# 470_Disk, Face-on, No Spiral.png
# 471_Disk, Edge-on, Rounded Bulge.png
# 472_Smooth, Completely round.png
# 473_Smooth, Completely round.png
# 474_Disk, Face-on, No Spiral.png
# 475_Smooth, Completely round.png
# 476_Smooth, Completely round.png
# 477_Disk, Edge-on, Rounded Bulge.png
# 478_Disk, Face-on, No Spiral.png
# 479_Smooth, Completely round.png
# 47_Smooth, in-between round.png
# 480_Smooth, Completely round.png
# 481_Smooth, Completely round.png
# 482_Disk, Face-on, No Spiral.png
# 483_Smooth, in-between round.png
# 484_Smooth, Completely round.png
# 485_Smooth, Completely round.png
# 486_Smooth, in-between round.png
# 487_Disk, Face-on, Medium Spiral.png
# 488_Smooth, Cigar shaped.png
# 489_Disk, Edge-on, Rounded Bulge.png
# 48_Disk, Face-on, No Spiral.png
# 490_Disk, Face-on, Tight Spiral.png
# 491_Disk, Face-on, Medium Spiral.png
# 492_Smooth, Completely round.png
# 493_Disk, Face-on, No Spiral.png
# 494_Smooth, in-between round.png
# 495_Smooth, in-between round.png
# 496_Smooth, Completely round.png
# 497_Disk, Face-on, No Spiral.png
# 498_Smooth, Completely round.png
# 499_Smooth, in-between round.png
# 49_Disk, Edge-on, No Bulge.png
# 4_Disk, Face-on, No Spiral.png
# 500_Smooth, Completely round.png
# 501_Disk, Face-on, Tight Spiral.png
# 502_Smooth, Completely round.png
# 503_Smooth, Completely round.png
# 504_Smooth, Completely round.png
# 505_Disk, Face-on, No Spiral.png
# 506_Disk, Face-on, Medium Spiral.png
# 507_Smooth, in-between round.png
# 508_Smooth, in-between round.png
# 509_Smooth, Completely round.png
# 50_Disk, Face-on, Medium Spiral.png
# 510_Smooth, in-between round.png
# 511_Smooth, Completely round.png
# 512_Smooth, Completely round.png
# 513_Disk, Face-on, Tight Spiral.png
# 514_Smooth, in-between round.png
# 515_Smooth, in-between round.png
# 516_Disk, Face-on, Tight Spiral.png
# 517_Disk, Face-on, Loose Spiral.png
# 518_Disk, Edge-on, No Bulge.png
# 519_Smooth, in-between round.png
# 51_Disk, Edge-on, No Bulge.png
# 520_Smooth, in-between round.png
# 521_Disk, Face-on, No Spiral.png
# 522_Smooth, in-between round.png
# 523_Smooth, Completely round.png
# 524_Smooth, Completely round.png
# 525_Smooth, in-between round.png
# 526_Smooth, in-between round.png
# 527_Disk, Face-on, No Spiral.png
# 528_Smooth, Completely round.png
# 529_Disk, Face-on, No Spiral.png
# 52_Disk, Edge-on, No Bulge.png
# 530_Smooth, in-between round.png
# 531_Disk, Edge-on, Rounded Bulge.png
# 532_Smooth, in-between round.png
# 533_Smooth, Cigar shaped.png
# 534_Smooth, Completely round.png
# 535_Disk, Face-on, Tight Spiral.png
# 536_Disk, Edge-on, Rounded Bulge.png
# 537_Smooth, Cigar shaped.png
# 538_Smooth, Completely round.png
# 539_Smooth, in-between round.png
# 53_Smooth, Completely round.png
# 540_Smooth, in-between round.png
# 541_Disk, Face-on, No Spiral.png
# 542_Disk, Face-on, No Spiral.png
# 543_Disk, Face-on, Medium Spiral.png
# 544_Smooth, Completely round.png
# 545_Smooth, in-between round.png
# 546_Disk, Face-on, No Spiral.png
# 547_Smooth, Completely round.png
# 548_Smooth, Completely round.png
# 549_Disk, Edge-on, Rounded Bulge.png
# 54_Smooth, Cigar shaped.png
# 550_Smooth, in-between round.png
# 551_Disk, Edge-on, No Bulge.png
# 552_Smooth, in-between round.png
# 553_Disk, Face-on, No Spiral.png
# 554_Disk, Face-on, No Spiral.png
# 555_Disk, Edge-on, Rounded Bulge.png
# 556_Disk, Face-on, Medium Spiral.png
# 557_Smooth, Completely round.png
# 558_Smooth, Completely round.png
# 559_Disk, Face-on, Tight Spiral.png
# 55_Disk, Face-on, Loose Spiral.png
# 560_Disk, Edge-on, No Bulge.png
# 561_Smooth, in-between round.png
# 562_Smooth, in-between round.png
# 563_Smooth, Completely round.png
# 564_Disk, Face-on, Loose Spiral.png
# 565_Smooth, Completely round.png
# 566_Smooth, Completely round.png
# 567_Disk, Face-on, Medium Spiral.png
# 568_Disk, Edge-on, Rounded Bulge.png
# 569_Smooth, in-between round.png
# 56_Disk, Face-on, Loose Spiral.png
# 570_Smooth, in-between round.png
# 571_Smooth, in-between round.png
# 572_Smooth, in-between round.png
# 573_Smooth, Completely round.png
# 574_Smooth, in-between round.png
# 575_Disk, Face-on, No Spiral.png
# 576_Disk, Edge-on, Rounded Bulge.png
# 577_Smooth, in-between round.png
# 578_Disk, Face-on, No Spiral.png
# 579_Smooth, in-between round.png
# 57_Smooth, in-between round.png
# 580_Disk, Face-on, Medium Spiral.png
# 581_Smooth, Completely round.png
# 582_Smooth, in-between round.png
# 583_Disk, Face-on, No Spiral.png
# 584_Smooth, Completely round.png
# 585_Disk, Edge-on, Rounded Bulge.png
# 586_Smooth, Completely round.png
# 587_Smooth, Completely round.png
# 588_Smooth, in-between round.png
# 589_Smooth, Completely round.png
# 58_Disk, Face-on, No Spiral.png
# 590_Disk, Face-on, No Spiral.png
# 591_Smooth, in-between round.png
# 592_Disk, Face-on, No Spiral.png
# 593_Disk, Face-on, No Spiral.png
# 594_Disk, Face-on, Tight Spiral.png
# 595_Disk, Edge-on, No Bulge.png
# 596_Disk, Face-on, Tight Spiral.png
# 597_Smooth, in-between round.png
# 598_Disk, Edge-on, No Bulge.png
# 599_Smooth, in-between round.png
# 59_Smooth, in-between round.png
# 5_Smooth, Completely round.png
# 600_Smooth, in-between round.png
# 601_Smooth, Completely round.png
# 602_Smooth, in-between round.png
# 603_Smooth, Completely round.png
# 604_Smooth, in-between round.png
# 605_Smooth, in-between round.png
# 606_Disk, Face-on, Medium Spiral.png
# 607_Disk, Face-on, No Spiral.png
# 608_Smooth, Completely round.png
# 609_Smooth, Completely round.png
# 60_Disk, Edge-on, Rounded Bulge.png
# 610_Smooth, Completely round.png
# 611_Smooth, Completely round.png
# 612_Smooth, in-between round.png
# 613_Smooth, Completely round.png
# 614_Smooth, in-between round.png
# 615_Smooth, Completely round.png
# 616_Disk, Face-on, No Spiral.png
# 617_Smooth, Completely round.png
# 618_Disk, Edge-on, Rounded Bulge.png
# 619_Disk, Edge-on, No Bulge.png
# 61_Disk, Edge-on, No Bulge.png
# 620_Disk, Face-on, Tight Spiral.png
# 621_Disk, Face-on, Medium Spiral.png
# 622_Disk, Face-on, No Spiral.png
# 623_Smooth, in-between round.png
# 624_Disk, Face-on, Tight Spiral.png
# 625_Smooth, Completely round.png
# 626_Smooth, Completely round.png
# 627_Smooth, Completely round.png
# 628_Disk, Edge-on, No Bulge.png
# 629_Disk, Face-on, No Spiral.png
# 62_Smooth, in-between round.png
# 630_Smooth, Completely round.png
# 631_Smooth, Completely round.png
# 632_Disk, Edge-on, Rounded Bulge.png
# 633_Smooth, in-between round.png
# 634_Smooth, Completely round.png
# 635_Smooth, Completely round.png
# 636_Smooth, Completely round.png
# 637_Smooth, in-between round.png
# 638_Smooth, Completely round.png
# 639_Smooth, in-between round.png
# 63_Disk, Face-on, Medium Spiral.png
# 640_Disk, Face-on, Tight Spiral.png
# 641_Smooth, in-between round.png
# 642_Disk, Face-on, No Spiral.png
# 643_Smooth, Completely round.png
# 644_Smooth, in-between round.png
# 645_Smooth, Completely round.png
# 646_Smooth, Completely round.png
# 647_Smooth, Completely round.png
# 648_Smooth, in-between round.png
# 649_Smooth, Completely round.png
# 64_Smooth, Completely round.png
# 650_Disk, Edge-on, Rounded Bulge.png
# 651_Disk, Face-on, Medium Spiral.png
# 652_Disk, Face-on, No Spiral.png
# 653_Disk, Face-on, No Spiral.png
# 654_Smooth, Completely round.png
# 655_Disk, Face-on, No Spiral.png
# 656_Disk, Face-on, Tight Spiral.png
# 657_Disk, Face-on, Tight Spiral.png
# 658_Disk, Edge-on, Rounded Bulge.png
# 659_Smooth, in-between round.png
# 65_Smooth, in-between round.png
# 660_Disk, Face-on, Medium Spiral.png
# 661_Disk, Edge-on, No Bulge.png
# 662_Disk, Face-on, No Spiral.png
# 663_Disk, Face-on, No Spiral.png
# 664_Smooth, Completely round.png
# 665_Disk, Face-on, No Spiral.png
# 666_Disk, Face-on, No Spiral.png
# 667_Smooth, Completely round.png
# 668_Disk, Face-on, No Spiral.png
# 669_Disk, Face-on, No Spiral.png
# 66_Smooth, Completely round.png
# 670_Smooth, in-between round.png
# 671_Disk, Face-on, Medium Spiral.png
# 672_Smooth, in-between round.png
# 673_Disk, Edge-on, Rounded Bulge.png
# 674_Smooth, Completely round.png
# 675_Smooth, in-between round.png
# 676_Disk, Edge-on, Rounded Bulge.png
# 677_Smooth, in-between round.png
# 678_Disk, Face-on, Tight Spiral.png
# 679_Disk, Face-on, Tight Spiral.png
# 67_Disk, Face-on, Medium Spiral.png
# 680_Smooth, Completely round.png
# 681_Smooth, Completely round.png
# 682_Disk, Face-on, Medium Spiral.png
# 683_Disk, Face-on, No Spiral.png
# 684_Smooth, Completely round.png
# 685_Disk, Face-on, No Spiral.png
# 686_Smooth, Completely round.png
# 687_Smooth, Completely round.png
# 688_Smooth, in-between round.png
# 689_Disk, Face-on, No Spiral.png
# 68_Smooth, Completely round.png
# 690_Disk, Face-on, Tight Spiral.png
# 691_Smooth, in-between round.png
# 692_Smooth, in-between round.png
# 693_Disk, Edge-on, Rounded Bulge.png
# 694_Smooth, Completely round.png
# 695_Smooth, in-between round.png
# 696_Disk, Face-on, Tight Spiral.png
# 697_Disk, Face-on, Medium Spiral.png
# 698_Smooth, Completely round.png
# 699_Smooth, in-between round.png
# 69_Smooth, in-between round.png
# 6_Disk, Face-on, Medium Spiral.png
# 700_Disk, Face-on, Medium Spiral.png
# 701_Smooth, Completely round.png
# 702_Smooth, in-between round.png
# 703_Smooth, Completely round.png
# 704_Disk, Edge-on, Rounded Bulge.png
# 705_Disk, Face-on, No Spiral.png
# 706_Smooth, Completely round.png
# 707_Smooth, in-between round.png
# 708_Disk, Edge-on, Rounded Bulge.png
# 709_Disk, Edge-on, Rounded Bulge.png
# 70_Disk, Face-on, Tight Spiral.png
# 710_Disk, Face-on, Tight Spiral.png
# 711_Smooth, Completely round.png
# 712_Smooth, Completely round.png
# 713_Smooth, in-between round.png
# 714_Disk, Edge-on, No Bulge.png
# 715_Smooth, in-between round.png
# 716_Smooth, in-between round.png
# 717_Disk, Face-on, Tight Spiral.png
# 718_Smooth, Completely round.png
# 719_Smooth, Completely round.png
# 71_Smooth, Completely round.png
# 720_Smooth, Completely round.png
# 721_Smooth, Cigar shaped.png
# 722_Smooth, in-between round.png
# 723_Smooth, in-between round.png
# 724_Smooth, in-between round.png
# 725_Smooth, in-between round.png
# 726_Smooth, Completely round.png
# 727_Disk, Edge-on, Rounded Bulge.png
# 728_Disk, Face-on, No Spiral.png
# 729_Disk, Face-on, No Spiral.png
# 72_Smooth, Completely round.png
# 730_Disk, Face-on, Tight Spiral.png
# 731_Smooth, Completely round.png
# 732_Smooth, Completely round.png
# 733_Disk, Face-on, Tight Spiral.png
# 734_Disk, Face-on, No Spiral.png
# 735_Disk, Face-on, No Spiral.png
# 736_Disk, Edge-on, Rounded Bulge.png
# 737_Smooth, Completely round.png
# 738_Smooth, Completely round.png
# 739_Disk, Face-on, No Spiral.png
# 73_Smooth, in-between round.png
# 740_Smooth, Completely round.png
# 741_Disk, Face-on, No Spiral.png
# 742_Smooth, in-between round.png
# 743_Disk, Face-on, Tight Spiral.png
# 744_Smooth, Completely round.png
# 745_Smooth, Cigar shaped.png
# 746_Smooth, Completely round.png
# 747_Smooth, Completely round.png
# 748_Smooth, in-between round.png
# 749_Smooth, in-between round.png
# 74_Disk, Edge-on, No Bulge.png
# 750_Disk, Face-on, No Spiral.png
# 751_Disk, Face-on, Tight Spiral.png
# 752_Disk, Face-on, Medium Spiral.png
# 753_Smooth, Completely round.png
# 754_Smooth, Completely round.png
# 755_Disk, Edge-on, No Bulge.png
# 756_Smooth, in-between round.png
# 757_Smooth, in-between round.png
# 758_Smooth, in-between round.png
# 759_Smooth, Completely round.png
# 75_Smooth, Completely round.png
# 760_Smooth, Completely round.png
# 761_Disk, Face-on, Tight Spiral.png
# 762_Smooth, Completely round.png
# 763_Smooth, in-between round.png
# 764_Disk, Face-on, No Spiral.png
# 765_Smooth, Completely round.png
# 766_Smooth, in-between round.png
# 767_Smooth, in-between round.png
# 768_Disk, Face-on, No Spiral.png
# 769_Disk, Face-on, No Spiral.png
# 76_Disk, Face-on, No Spiral.png
# 770_Smooth, Completely round.png
# 771_Smooth, in-between round.png
# 772_Smooth, Completely round.png
# 773_Smooth, in-between round.png
# 774_Smooth, in-between round.png
# 775_Smooth, Completely round.png
# 776_Smooth, Completely round.png
# 777_Smooth, in-between round.png
# 778_Smooth, Completely round.png
# 779_Disk, Face-on, Medium Spiral.png
# 77_Smooth, Completely round.png
# 780_Smooth, in-between round.png
# 781_Smooth, in-between round.png
# 782_Smooth, Completely round.png
# 783_Disk, Face-on, No Spiral.png
# 784_Disk, Face-on, No Spiral.png
# 785_Disk, Face-on, Tight Spiral.png
# 786_Smooth, Completely round.png
# 787_Smooth, Cigar shaped.png
# 788_Disk, Face-on, No Spiral.png
# 789_Disk, Face-on, No Spiral.png
# 78_Disk, Face-on, Medium Spiral.png
# 790_Disk, Face-on, Loose Spiral.png
# 791_Disk, Face-on, No Spiral.png
# 792_Smooth, in-between round.png
# 793_Smooth, Completely round.png
# 794_Smooth, in-between round.png
# 795_Disk, Face-on, Loose Spiral.png
# 796_Smooth, Completely round.png
# 797_Disk, Face-on, Loose Spiral.png
# 798_Smooth, Completely round.png
# 799_Smooth, Cigar shaped.png
# 79_Disk, Face-on, Medium Spiral.png
# 7_Smooth, Completely round.png
# 800_Disk, Face-on, No Spiral.png
# 801_Disk, Face-on, No Spiral.png
# 802_Disk, Face-on, Tight Spiral.png
# 803_Disk, Face-on, No Spiral.png
# 804_Smooth, in-between round.png
# 805_Smooth, Completely round.png
# 806_Disk, Face-on, No Spiral.png
# 807_Smooth, Completely round.png
# 808_Smooth, in-between round.png
# 809_Disk, Face-on, No Spiral.png
# 80_Smooth, Completely round.png
# 810_Smooth, Completely round.png
# 811_Smooth, in-between round.png
# 812_Smooth, Completely round.png
# 813_Disk, Face-on, No Spiral.png
# 814_Smooth, in-between round.png
# 815_Disk, Face-on, No Spiral.png
# 816_Smooth, Completely round.png
# 817_Smooth, Cigar shaped.png
# 818_Disk, Face-on, Loose Spiral.png
# 819_Smooth, in-between round.png
# 81_Smooth, in-between round.png
# 820_Smooth, in-between round.png
# 821_Disk, Face-on, No Spiral.png
# 822_Smooth, in-between round.png
# 823_Smooth, Completely round.png
# 824_Smooth, Completely round.png
# 825_Smooth, in-between round.png
# 826_Smooth, in-between round.png
# 827_Smooth, in-between round.png
# 828_Disk, Face-on, No Spiral.png
# 829_Smooth, in-between round.png
# 82_Disk, Face-on, No Spiral.png
# 830_Smooth, in-between round.png
# 831_Disk, Face-on, No Spiral.png
# 832_Disk, Face-on, No Spiral.png
# 833_Smooth, Completely round.png
# 834_Disk, Edge-on, No Bulge.png
# 835_Smooth, in-between round.png
# 836_Disk, Face-on, No Spiral.png
# 837_Smooth, in-between round.png
# 838_Smooth, in-between round.png
# 839_Smooth, in-between round.png
# 83_Smooth, in-between round.png
# 840_Smooth, Completely round.png
# 841_Smooth, Completely round.png
# 842_Smooth, in-between round.png
# 843_Disk, Face-on, Loose Spiral.png
# 844_Disk, Face-on, No Spiral.png
# 845_Smooth, Completely round.png
# 846_Disk, Face-on, No Spiral.png
# 847_Smooth, Completely round.png
# 848_Smooth, Completely round.png
# 849_Disk, Face-on, Medium Spiral.png
# 84_Smooth, Completely round.png
# 850_Smooth, Completely round.png
# 851_Smooth, Completely round.png
# 852_Smooth, Completely round.png
# 853_Smooth, Completely round.png
# 854_Smooth, Completely round.png
# 855_Disk, Face-on, Tight Spiral.png
# 856_Smooth, Completely round.png
# 857_Smooth, in-between round.png
# 858_Smooth, Completely round.png
# 859_Disk, Face-on, Loose Spiral.png
# 85_Smooth, in-between round.png
# 860_Smooth, Completely round.png
# 861_Smooth, in-between round.png
# 862_Smooth, Completely round.png
# 863_Smooth, in-between round.png
# 864_Smooth, in-between round.png
# 865_Disk, Edge-on, Rounded Bulge.png
# 866_Smooth, Completely round.png
# 867_Disk, Face-on, No Spiral.png
# 868_Smooth, Completely round.png
# 869_Smooth, Completely round.png
# 86_Smooth, Completely round.png
# 870_Disk, Face-on, Medium Spiral.png
# 871_Smooth, Completely round.png
# 872_Smooth, Completely round.png
# 873_Smooth, in-between round.png
# 874_Disk, Face-on, Tight Spiral.png
# 875_Smooth, Cigar shaped.png
# 876_Smooth, in-between round.png
# 877_Smooth, in-between round.png
# 878_Disk, Face-on, No Spiral.png
# 879_Smooth, in-between round.png
# 87_Disk, Face-on, No Spiral.png
# 880_Disk, Face-on, No Spiral.png
# 881_Disk, Edge-on, Rounded Bulge.png
# 882_Smooth, in-between round.png
# 883_Smooth, Completely round.png
# 884_Smooth, Completely round.png
# 885_Disk, Edge-on, Rounded Bulge.png
# 886_Disk, Face-on, No Spiral.png
# 887_Smooth, Completely round.png
# 888_Smooth, Completely round.png
# 889_Disk, Face-on, Medium Spiral.png
# 88_Smooth, Completely round.png
# 890_Disk, Edge-on, Rounded Bulge.png
# 891_Disk, Face-on, Loose Spiral.png
# 892_Disk, Face-on, Tight Spiral.png
# 893_Disk, Face-on, No Spiral.png
# 894_Smooth, in-between round.png
# 895_Smooth, Completely round.png
# 896_Disk, Face-on, No Spiral.png
# 897_Smooth, Completely round.png
# 898_Smooth, in-between round.png
# 899_Disk, Edge-on, Rounded Bulge.png
# 89_Smooth, Cigar shaped.png
# 8_Disk, Edge-on, Rounded Bulge.png
# 900_Smooth, in-between round.png
# 901_Disk, Edge-on, No Bulge.png
# 902_Disk, Edge-on, No Bulge.png
# 903_Smooth, Completely round.png
# 904_Disk, Face-on, Medium Spiral.png
# 905_Disk, Face-on, Tight Spiral.png
# 906_Smooth, in-between round.png
# 907_Disk, Edge-on, No Bulge.png
# 908_Disk, Face-on, Tight Spiral.png
# 909_Smooth, in-between round.png
# 90_Disk, Face-on, Medium Spiral.png
# 910_Disk, Face-on, No Spiral.png
# 911_Smooth, Completely round.png
# 912_Smooth, in-between round.png
# 913_Smooth, Completely round.png
# 914_Disk, Edge-on, Rounded Bulge.png
# 915_Disk, Face-on, Medium Spiral.png
# 916_Smooth, Completely round.png
# 917_Smooth, in-between round.png
# 918_Disk, Face-on, Medium Spiral.png
# 919_Disk, Face-on, No Spiral.png
# 91_Disk, Face-on, Tight Spiral.png
# 920_Disk, Face-on, No Spiral.png
# 921_Disk, Face-on, Loose Spiral.png
# ...
# 2_F_Disk, Face-on, No Spiral.png
# 30_A_Smooth, in-between round.png
# 30_B_Smooth, in-between round.png
# 30_C_Smooth, in-between round.png
# 30_D_Smooth, in-between round.png
# 30_E_Smooth, in-between round.png
# 30_F_Smooth, in-between round.png
# 31_A_Smooth, Completely round.png
# 31_B_Smooth, Completely round.png
# 31_C_Smooth, Completely round.png
# 31_D_Smooth, Completely round.png
# 31_E_Smooth, Completely round.png
# 31_F_Smooth, Completely round.png
# 32_A_Smooth, Completely round.png
# 32_B_Smooth, Completely round.png
# 32_C_Smooth, Completely round.png
# 32_D_Smooth, Completely round.png
# 32_E_Smooth, Completely round.png
# 32_F_Smooth, Completely round.png
# 33_A_Smooth, Completely round.png
# 33_B_Smooth, Completely round.png
# 33_C_Smooth, Completely round.png
# 33_D_Smooth, Completely round.png
# 33_E_Smooth, Completely round.png
# 33_F_Smooth, Completely round.png
# 34_A_Smooth, in-between round.png
# 34_B_Smooth, in-between round.png
# 34_C_Smooth, in-between round.png
# 34_D_Smooth, in-between round.png
# 34_E_Smooth, in-between round.png
# 34_F_Smooth, in-between round.png
# 35_A_Smooth, Completely round.png
# 35_B_Smooth, Completely round.png
# 35_C_Smooth, Completely round.png
# 35_D_Smooth, Completely round.png
# 35_E_Smooth, Completely round.png
# 35_F_Smooth, Completely round.png
# 36_A_Smooth, in-between round.png
# 36_B_Smooth, in-between round.png
# 36_C_Smooth, in-between round.png
# 36_D_Smooth, in-between round.png
# 36_E_Smooth, in-between round.png
# 36_F_Smooth, in-between round.png
# 37_A_Smooth, Completely round.png
# 37_B_Smooth, Completely round.png
# 37_C_Smooth, Completely round.png
# 37_D_Smooth, Completely round.png
# 37_E_Smooth, Completely round.png
# 37_F_Smooth, Completely round.png
# 38_A_Smooth, in-between round.png
# 38_B_Smooth, in-between round.png
# 38_C_Smooth, in-between round.png
# 38_D_Smooth, in-between round.png
# 38_E_Smooth, in-between round.png
# 38_F_Smooth, in-between round.png
# 39_A_Smooth, in-between round.png
# 39_B_Smooth, in-between round.png
# 39_C_Smooth, in-between round.png
# 39_D_Smooth, in-between round.png
# 39_E_Smooth, in-between round.png
# 39_F_Smooth, in-between round.png
# 3_A_Smooth, in-between round.png
# 3_B_Smooth, in-between round.png
# 3_C_Smooth, in-between round.png
# 3_D_Smooth, in-between round.png
# 3_E_Smooth, in-between round.png
# 3_F_Smooth, in-between round.png
# 40_A_Smooth, Completely round.png
# 40_B_Smooth, Completely round.png
# 40_C_Smooth, Completely round.png
# 40_D_Smooth, Completely round.png
# 40_E_Smooth, Completely round.png
# 40_F_Smooth, Completely round.png
# 41_A_Smooth, in-between round.png
# 41_B_Smooth, in-between round.png
# 41_C_Smooth, in-between round.png
# 41_D_Smooth, in-between round.png
# 41_E_Smooth, in-between round.png
# 41_F_Smooth, in-between round.png
# 42_A_Disk, Face-on, No Spiral.png
# 42_B_Disk, Face-on, No Spiral.png
# 42_C_Disk, Face-on, No Spiral.png
# 42_D_Disk, Face-on, No Spiral.png
# 42_E_Disk, Face-on, No Spiral.png
# 42_F_Disk, Face-on, No Spiral.png
# 43_A_Disk, Edge-on, Rounded Bulge.png
# 43_B_Disk, Edge-on, Rounded Bulge.png
# 43_C_Disk, Edge-on, Rounded Bulge.png
# 43_D_Disk, Edge-on, Rounded Bulge.png
# 43_E_Disk, Edge-on, Rounded Bulge.png
# 43_F_Disk, Edge-on, Rounded Bulge.png
# 44_A_Smooth, in-between round.png
# 44_B_Smooth, in-between round.png
# 44_C_Smooth, in-between round.png
# 44_D_Smooth, in-between round.png
# 44_E_Smooth, in-between round.png
# 44_F_Smooth, in-between round.png
# 45_A_Smooth, in-between round.png
# 45_B_Smooth, in-between round.png
# 45_C_Smooth, in-between round.png
# 45_D_Smooth, in-between round.png
# 45_E_Smooth, in-between round.png
# 45_F_Smooth, in-between round.png
# 46_A_Disk, Face-on, No Spiral.png
# 46_B_Disk, Face-on, No Spiral.png
# 46_C_Disk, Face-on, No Spiral.png
# 46_D_Disk, Face-on, No Spiral.png
# 46_E_Disk, Face-on, No Spiral.png
# 46_F_Disk, Face-on, No Spiral.png
# 47_A_Smooth, in-between round.png
# 47_B_Smooth, in-between round.png
# 47_C_Smooth, in-between round.png
# 47_D_Smooth, in-between round.png
# 47_E_Smooth, in-between round.png
# 47_F_Smooth, in-between round.png
# 48_A_Disk, Face-on, No Spiral.png
# 48_B_Disk, Face-on, No Spiral.png
# 48_C_Disk, Face-on, No Spiral.png
# 48_D_Disk, Face-on, No Spiral.png
# 48_E_Disk, Face-on, No Spiral.png
# 48_F_Disk, Face-on, No Spiral.png
# 49_A_Disk, Edge-on, No Bulge.png
# 49_B_Disk, Edge-on, No Bulge.png
# 49_C_Disk, Edge-on, No Bulge.png
# 49_D_Disk, Edge-on, No Bulge.png
# 49_E_Disk, Edge-on, No Bulge.png
# 49_F_Disk, Edge-on, No Bulge.png
# 4_A_Disk, Face-on, No Spiral.png
# 4_B_Disk, Face-on, No Spiral.png
# 4_C_Disk, Face-on, No Spiral.png
# 4_D_Disk, Face-on, No Spiral.png
# 4_E_Disk, Face-on, No Spiral.png
# 4_F_Disk, Face-on, No Spiral.png
# 50_A_Disk, Face-on, Medium Spiral.png
# 50_B_Disk, Face-on, Medium Spiral.png
# 50_C_Disk, Face-on, Medium Spiral.png
# 50_D_Disk, Face-on, Medium Spiral.png
# 50_E_Disk, Face-on, Medium Spiral.png
# 50_F_Disk, Face-on, Medium Spiral.png
# 51_A_Disk, Edge-on, No Bulge.png
# 51_B_Disk, Edge-on, No Bulge.png
# 51_C_Disk, Edge-on, No Bulge.png
# 51_D_Disk, Edge-on, No Bulge.png
# 51_E_Disk, Edge-on, No Bulge.png
# 51_F_Disk, Edge-on, No Bulge.png
# 52_A_Disk, Edge-on, No Bulge.png
# 52_B_Disk, Edge-on, No Bulge.png
# 52_C_Disk, Edge-on, No Bulge.png
# 52_D_Disk, Edge-on, No Bulge.png
# 52_E_Disk, Edge-on, No Bulge.png
# 52_F_Disk, Edge-on, No Bulge.png
# 53_A_Smooth, Completely round.png
# 53_B_Smooth, Completely round.png
# 53_C_Smooth, Completely round.png
# 53_D_Smooth, Completely round.png
# 53_E_Smooth, Completely round.png
# 53_F_Smooth, Completely round.png
# 54_A_Smooth, Cigar shaped.png
# 54_B_Smooth, Cigar shaped.png
# 54_C_Smooth, Cigar shaped.png
# 54_D_Smooth, Cigar shaped.png
# 54_E_Smooth, Cigar shaped.png
# 54_F_Smooth, Cigar shaped.png
# 55_A_Disk, Face-on, Loose Spiral.png
# 55_B_Disk, Face-on, Loose Spiral.png
# 55_C_Disk, Face-on, Loose Spiral.png
# 55_D_Disk, Face-on, Loose Spiral.png
# 55_E_Disk, Face-on, Loose Spiral.png
# 55_F_Disk, Face-on, Loose Spiral.png
# 56_A_Disk, Face-on, Loose Spiral.png
# 56_B_Disk, Face-on, Loose Spiral.png
# 56_C_Disk, Face-on, Loose Spiral.png
# 56_D_Disk, Face-on, Loose Spiral.png
# 56_E_Disk, Face-on, Loose Spiral.png
# 56_F_Disk, Face-on, Loose Spiral.png
# 57_A_Smooth, in-between round.png
# 57_B_Smooth, in-between round.png
# 57_C_Smooth, in-between round.png
# 57_D_Smooth, in-between round.png
# 57_E_Smooth, in-between round.png
# 57_F_Smooth, in-between round.png
# 58_A_Disk, Face-on, No Spiral.png
# 58_B_Disk, Face-on, No Spiral.png
# 58_C_Disk, Face-on, No Spiral.png
# 58_D_Disk, Face-on, No Spiral.png
# 58_E_Disk, Face-on, No Spiral.png
# 58_F_Disk, Face-on, No Spiral.png
# 59_A_Smooth, in-between round.png
# 59_B_Smooth, in-between round.png
# 59_C_Smooth, in-between round.png
# 59_D_Smooth, in-between round.png
# 59_E_Smooth, in-between round.png
# 59_F_Smooth, in-between round.png
# 5_A_Smooth, Completely round.png
# 5_B_Smooth, Completely round.png
# 5_C_Smooth, Completely round.png
# 5_D_Smooth, Completely round.png
# 5_E_Smooth, Completely round.png
# 5_F_Smooth, Completely round.png
# 60_A_Disk, Edge-on, Rounded Bulge.png
# 60_B_Disk, Edge-on, Rounded Bulge.png
# 60_C_Disk, Edge-on, Rounded Bulge.png
# 60_D_Disk, Edge-on, Rounded Bulge.png
# 60_E_Disk, Edge-on, Rounded Bulge.png
# 60_F_Disk, Edge-on, Rounded Bulge.png
# 61_A_Disk, Edge-on, No Bulge.png
# 61_B_Disk, Edge-on, No Bulge.png
# 61_C_Disk, Edge-on, No Bulge.png
# 61_D_Disk, Edge-on, No Bulge.png
# 61_E_Disk, Edge-on, No Bulge.png
# 61_F_Disk, Edge-on, No Bulge.png
# 62_A_Smooth, in-between round.png
# 62_B_Smooth, in-between round.png
# 62_C_Smooth, in-between round.png
# 62_D_Smooth, in-between round.png
# 62_E_Smooth, in-between round.png
# 62_F_Smooth, in-between round.png
# 63_A_Disk, Face-on, Medium Spiral.png
# 63_B_Disk, Face-on, Medium Spiral.png
# 63_C_Disk, Face-on, Medium Spiral.png
# 63_D_Disk, Face-on, Medium Spiral.png
# 63_E_Disk, Face-on, Medium Spiral.png
# 63_F_Disk, Face-on, Medium Spiral.png
# 64_A_Smooth, Completely round.png
# 64_B_Smooth, Completely round.png
# 64_C_Smooth, Completely round.png
# 64_D_Smooth, Completely round.png
# 64_E_Smooth, Completely round.png
# 64_F_Smooth, Completely round.png
# 65_A_Smooth, in-between round.png
# 65_B_Smooth, in-between round.png
# 65_C_Smooth, in-between round.png
# 65_D_Smooth, in-between round.png
# 65_E_Smooth, in-between round.png
# 65_F_Smooth, in-between round.png
# 66_A_Smooth, Completely round.png
# 66_B_Smooth, Completely round.png
# 66_C_Smooth, Completely round.png
# 66_D_Smooth, Completely round.png
# 66_E_Smooth, Completely round.png
# 66_F_Smooth, Completely round.png
# 67_A_Disk, Face-on, Medium Spiral.png
# 67_B_Disk, Face-on, Medium Spiral.png
# 67_C_Disk, Face-on, Medium Spiral.png
# 67_D_Disk, Face-on, Medium Spiral.png
# 67_E_Disk, Face-on, Medium Spiral.png
# 67_F_Disk, Face-on, Medium Spiral.png
# 68_A_Smooth, Completely round.png
# 68_B_Smooth, Completely round.png
# 68_C_Smooth, Completely round.png
# 68_D_Smooth, Completely round.png
# 68_E_Smooth, Completely round.png
# 68_F_Smooth, Completely round.png
# 69_A_Smooth, in-between round.png
# 69_B_Smooth, in-between round.png
# 69_C_Smooth, in-between round.png
# 69_D_Smooth, in-between round.png
# 69_E_Smooth, in-between round.png
# 69_F_Smooth, in-between round.png
# 6_A_Disk, Face-on, Medium Spiral.png
# 6_B_Disk, Face-on, Medium Spiral.png
# 6_C_Disk, Face-on, Medium Spiral.png
# 6_D_Disk, Face-on, Medium Spiral.png
# 6_E_Disk, Face-on, Medium Spiral.png
# 6_F_Disk, Face-on, Medium Spiral.png
# 70_A_Disk, Face-on, Tight Spiral.png
# 70_B_Disk, Face-on, Tight Spiral.png
# 70_C_Disk, Face-on, Tight Spiral.png
# 70_D_Disk, Face-on, Tight Spiral.png
# 70_E_Disk, Face-on, Tight Spiral.png
# 70_F_Disk, Face-on, Tight Spiral.png
# 71_A_Smooth, Completely round.png
# 71_B_Smooth, Completely round.png
# 71_C_Smooth, Completely round.png
# 71_D_Smooth, Completely round.png
# 71_E_Smooth, Completely round.png
# 71_F_Smooth, Completely round.png
# 72_A_Smooth, Completely round.png
# 72_B_Smooth, Completely round.png
# 72_C_Smooth, Completely round.png
# 72_D_Smooth, Completely round.png
# 72_E_Smooth, Completely round.png
# 72_F_Smooth, Completely round.png
# 73_A_Smooth, in-between round.png
# 73_B_Smooth, in-between round.png
# 73_C_Smooth, in-between round.png
# 73_D_Smooth, in-between round.png
# 73_E_Smooth, in-between round.png
# 73_F_Smooth, in-between round.png
# 74_A_Disk, Edge-on, No Bulge.png
# 74_B_Disk, Edge-on, No Bulge.png
# 74_C_Disk, Edge-on, No Bulge.png
# 74_D_Disk, Edge-on, No Bulge.png
# 74_E_Disk, Edge-on, No Bulge.png
# 74_F_Disk, Edge-on, No Bulge.png
# 75_A_Smooth, Completely round.png
# 75_B_Smooth, Completely round.png
# 75_C_Smooth, Completely round.png
# 75_D_Smooth, Completely round.png
# 75_E_Smooth, Completely round.png
# 75_F_Smooth, Completely round.png
# 76_A_Disk, Face-on, No Spiral.png
# 76_B_Disk, Face-on, No Spiral.png
# 76_C_Disk, Face-on, No Spiral.png
# 76_D_Disk, Face-on, No Spiral.png
# 76_E_Disk, Face-on, No Spiral.png
# 76_F_Disk, Face-on, No Spiral.png
# 77_A_Smooth, Completely round.png
# 77_B_Smooth, Completely round.png
# 77_C_Smooth, Completely round.png
# 77_D_Smooth, Completely round.png
# 77_E_Smooth, Completely round.png
# 77_F_Smooth, Completely round.png
# 78_A_Disk, Face-on, Medium Spiral.png
# 78_B_Disk, Face-on, Medium Spiral.png
# 78_C_Disk, Face-on, Medium Spiral.png
# 78_D_Disk, Face-on, Medium Spiral.png
# 78_E_Disk, Face-on, Medium Spiral.png
# 78_F_Disk, Face-on, Medium Spiral.png
# 79_A_Disk, Face-on, Medium Spiral.png
# 79_B_Disk, Face-on, Medium Spiral.png
# 79_C_Disk, Face-on, Medium Spiral.png
# 79_D_Disk, Face-on, Medium Spiral.png
# 79_E_Disk, Face-on, Medium Spiral.png
# 79_F_Disk, Face-on, Medium Spiral.png
# 7_A_Smooth, Completely round.png
# 7_B_Smooth, Completely round.png
# 7_C_Smooth, Completely round.png
# 7_D_Smooth, Completely round.png
# 7_E_Smooth, Completely round.png
# 7_F_Smooth, Completely round.png
# 80_A_Smooth, Completely round.png
# 80_B_Smooth, Completely round.png
# 80_C_Smooth, Completely round.png
# 80_D_Smooth, Completely round.png
# 80_E_Smooth, Completely round.png
# 80_F_Smooth, Completely round.png
# 81_A_Smooth, in-between round.png
# 81_B_Smooth, in-between round.png
# 81_C_Smooth, in-between round.png
# 81_D_Smooth, in-between round.png
# 81_E_Smooth, in-between round.png
# 81_F_Smooth, in-between round.png
# 82_A_Disk, Face-on, No Spiral.png
# 82_B_Disk, Face-on, No Spiral.png
# 82_C_Disk, Face-on, No Spiral.png
# 82_D_Disk, Face-on, No Spiral.png
# 82_E_Disk, Face-on, No Spiral.png
# 82_F_Disk, Face-on, No Spiral.png
# 83_A_Smooth, in-between round.png
# 83_B_Smooth, in-between round.png
# 83_C_Smooth, in-between round.png
# 83_D_Smooth, in-between round.png
# 83_E_Smooth, in-between round.png
# 83_F_Smooth, in-between round.png
# 84_A_Smooth, Completely round.png
# 84_B_Smooth, Completely round.png
# 84_C_Smooth, Completely round.png
# 84_D_Smooth, Completely round.png
# 84_E_Smooth, Completely round.png
# 84_F_Smooth, Completely round.png
# 85_A_Smooth, in-between round.png
# 85_B_Smooth, in-between round.png
# 85_C_Smooth, in-between round.png
# 85_D_Smooth, in-between round.png
# 85_E_Smooth, in-between round.png
# 85_F_Smooth, in-between round.png
# 86_A_Smooth, Completely round.png
# 86_B_Smooth, Completely round.png
# 86_C_Smooth, Completely round.png
# 86_D_Smooth, Completely round.png
# 86_E_Smooth, Completely round.png
# 86_F_Smooth, Completely round.png
# 87_A_Disk, Face-on, No Spiral.png
# 87_B_Disk, Face-on, No Spiral.png
# 87_C_Disk, Face-on, No Spiral.png
# 87_D_Disk, Face-on, No Spiral.png
# 87_E_Disk, Face-on, No Spiral.png
# 87_F_Disk, Face-on, No Spiral.png
# 88_A_Smooth, Completely round.png
# 88_B_Smooth, Completely round.png
# 88_C_Smooth, Completely round.png
# 88_D_Smooth, Completely round.png
# 88_E_Smooth, Completely round.png
# 88_F_Smooth, Completely round.png
# 89_A_Smooth, Cigar shaped.png
# 89_B_Smooth, Cigar shaped.png
# 89_C_Smooth, Cigar shaped.png
# 89_D_Smooth, Cigar shaped.png
# 89_E_Smooth, Cigar shaped.png
# 89_F_Smooth, Cigar shaped.png
# 8_A_Disk, Edge-on, Rounded Bulge.png
# 8_B_Disk, Edge-on, Rounded Bulge.png
# 8_C_Disk, Edge-on, Rounded Bulge.png
# 8_D_Disk, Edge-on, Rounded Bulge.png
# 8_E_Disk, Edge-on, Rounded Bulge.png
# 8_F_Disk, Edge-on, Rounded Bulge.png
# 90_A_Disk, Face-on, Medium Spiral.png
# 90_B_Disk, Face-on, Medium Spiral.png
# 90_C_Disk, Face-on, Medium Spiral.png
# 90_D_Disk, Face-on, Medium Spiral.png
# 90_E_Disk, Face-on, Medium Spiral.png
# 90_F_Disk, Face-on, Medium Spiral.png
# 91_A_Disk, Face-on, Tight Spiral.png
# 91_B_Disk, Face-on, Tight Spiral.png
# 91_C_Disk, Face-on, Tight Spiral.png
# 91_D_Disk, Face-on, Tight Spiral.png
# 91_E_Disk, Face-on, Tight Spiral.png
# 91_F_Disk, Face-on, Tight Spiral.png
# 92_A_Smooth, in-between round.png
# 92_B_Smooth, in-between round.png
# 92_C_Smooth, in-between round.png
# 92_D_Smooth, in-between round.png
# 92_E_Smooth, in-between round.png
# 92_F_Smooth, in-between round.png
# 93_A_Smooth, in-between round.png
# 93_B_Smooth, in-between round.png
# 93_C_Smooth, in-between round.png
# 93_D_Smooth, in-between round.png
# 93_E_Smooth, in-between round.png
# 93_F_Smooth, in-between round.png
# 94_A_Smooth, Completely round.png
# 94_B_Smooth, Completely round.png
# 94_C_Smooth, Completely round.png
# 94_D_Smooth, Completely round.png
# 94_E_Smooth, Completely round.png
# 94_F_Smooth, Completely round.png
# 95_A_Smooth, in-between round.png
# 95_B_Smooth, in-between round.png
# 95_C_Smooth, in-between round.png
# 95_D_Smooth, in-between round.png
# 95_E_Smooth, in-between round.png
# 95_F_Smooth, in-between round.png
# 96_A_Disk, Face-on, Tight Spiral.png
# 96_B_Disk, Face-on, Tight Spiral.png
# 96_C_Disk, Face-on, Tight Spiral.png
# 96_D_Disk, Face-on, Tight Spiral.png
# 96_E_Disk, Face-on, Tight Spiral.png
# 96_F_Disk, Face-on, Tight Spiral.png
# 97_A_Disk, Face-on, Tight Spiral.png
# 97_B_Disk, Face-on, Tight Spiral.png
# 97_C_Disk, Face-on, Tight Spiral.png
# 97_D_Disk, Face-on, Tight Spiral.png
# 97_E_Disk, Face-on, Tight Spiral.png
# 97_F_Disk, Face-on, Tight Spiral.png
# 98_A_Smooth, Completely round.png
# 98_B_Smooth, Completely round.png
# 98_C_Smooth, Completely round.png
# 98_D_Smooth, Completely round.png
# 98_E_Smooth, Completely round.png
# 98_F_Smooth, Completely round.png
# 99_A_Smooth, Completely round.png
# 99_B_Smooth, Completely round.png
# 99_C_Smooth, Completely round.png
# 99_D_Smooth, Completely round.png
# 99_E_Smooth, Completely round.png
# 99_F_Smooth, Completely round.png
# 9_A_Smooth, in-between round.png
# 9_B_Smooth, in-between round.png
# 9_C_Smooth, in-between round.png
# 9_D_Smooth, in-between round.png
# 9_E_Smooth, in-between round.png
# 9_F_Smooth, in-between round.png

# %%
plt.imshow(train_set_x_orig_2.reshape(r2, n_pixeles, n_pixeles, 3)[10])

# %%
plt.imshow(test_set_x_orig_2.reshape(r, n_pixeles, n_pixeles, 3)[10])

# %%
train = train_set_x_orig_2.reshape(r2, n_pixeles, n_pixeles, 3)
train.shape
# Out:
# (5588, 64, 64, 3)

# %%
# para train
d1=2199 + 200 + 487+1 # sin lentes
d2=2400 + 300 #con lentes

hola = np.zeros((1, d1 + 1)) 
bye = np.zeros((1, d2)) + 1
c = np.append(hola, bye)
c_train = c.reshape(1, d1+d2 +1)
c_train.shape
# Out:
# (1, 5588)

# %%
test = test_set_x_orig_2.reshape(r, n_pixeles, n_pixeles, 3)
test.shape
# Out:
# (3201, 64, 64, 3)

# %%
# para test
d1=1500+200+1 #sin lentes
d2=1500 #con lentes

hola = np.zeros((1, d1))
bye = np.zeros((1, d2)) + 1
c = np.append(hola, bye)
c_test = c.reshape(1, d1+d2)
c_test.shape
# Out:
# (1, 3201)

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_happy_dataset()

# %%
classes
# Out:
# array([0, 1])

# %%
classes[1]
# Out:
# 1

# %%
# Loading the data "LENS / NO_LENS"
#classes2 = classes
#classes2[0] = b'NO_LENS'
#classes2[1] = b'LENS'

X_train_orig = train
Y_train_orig = c_train
X_test_orig = test
Y_test_orig = c_test
#classes = classes2

# %%
# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 5588
# number of test examples = 3201
# X_train shape: (5588, 64, 64, 3)
# Y_train shape: (5588, 1)
# X_test shape: (3201, 64, 64, 3)
# Y_test shape: (3201, 1)

# %% [markdown]
# You can display the images contained in the dataset. Images are **64x64** pixels in RGB format (3 channels).

# %%
index = 191
plt.imshow(X_train_orig[index]) #display sample training image
plt.show()

# %% [markdown]
# <a name='2'></a>
# ## 2 - Layers in TF Keras
#
# In the previous assignment, you created layers manually in numpy. In TF Keras, you don't have to write code directly to create layers. Rather, TF Keras has pre-defined layers you can use.
#
# When you create a layer in TF Keras, you are creating a function that takes some input and transforms it into an output you can reuse later. Nice and easy!

# %% [markdown]
# <a name='3'></a>
# ## 3 - The Sequential API
#
# In the previous assignment, you built helper functions using `numpy` to understand the mechanics behind convolutional neural networks. Most practical applications of deep learning today are built using programming frameworks, which have many built-in functions you can simply call. Keras is a high-level abstraction built on top of TensorFlow, which allows for even more simplified and optimized model creation and training.
#
# For the first part of this assignment, you'll create a model using TF Keras' Sequential API, which allows you to build layer by layer, and is ideal for building models where each layer has **exactly one** input tensor and **one** output tensor.
#
# As you'll see, using the Sequential API is simple and straightforward, but is only appropriate for simpler, more straightforward tasks. Later in this notebook you'll spend some time building with a more flexible, powerful alternative: the Functional API.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Create the Sequential Model
#
# As mentioned earlier, the TensorFlow Keras Sequential API can be used to build simple models with layer operations that proceed in a sequential order.
#
# You can also add layers incrementally to a Sequential model with the `.add()` method, or remove them using the `.pop()` method, much like you would in a regular Python list.
#
# Actually, you can think of a Sequential model as behaving like a list of layers. Like Python lists, Sequential layers are ordered, and the order in which they are specified matters.  If your model is non-linear or contains layers with multiple inputs or outputs, a Sequential model wouldn't be the right choice!
#
# For any layer construction in Keras, you'll need to specify the input shape in advance. This is because in Keras, the shape of the weights is based on the shape of the inputs. The weights are only created when the model first sees some input data. Sequential models can be created by passing a list of layers to the Sequential constructor, like you will do in the next assignment.
#
# <a name='ex-1'></a>
# ### Exercise 1 - happyModel
#
# Implement the `happyModel` function below to build the following model: `ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE`. Take help from [tf.keras.layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers)
#
# Also, plug in the following parameters for all the steps:
#
#  - [ZeroPadding2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ZeroPadding2D): padding 3, input shape 64 x 64 x 3
#  - [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): Use 32 7x7 filters, stride 1
#  - [BatchNormalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization): for axis 3
#  - [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU)
#  - [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): Using default parameters
#  - [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the previous output.
#  - Fully-connected ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) layer: Apply a fully connected layer with 1 neuron and a sigmoid activation.
#
#
#  **Hint:**
#
#  Use **tfl** as shorthand for **tensorflow.keras.layers**

# %%
# GRADED FUNCTION: happyModel

def happyModel():
    """
    Implements the forward propagation for the binary classification model:
    ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code all the values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    None

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    model = tf.keras.Sequential([
            ## ZeroPadding2D with padding 3, input shape of 64 x 64 x 3
            
            ## Conv2D with 32 7x7 filters and stride of 1
            
            ## BatchNormalization for axis 3
            
            ## ReLU
            
            ## Max Pooling 2D with default parameters
            
            ## Flatten layer
            
            ## Dense layer with 1 unit for output & 'sigmoid' activation
            
            # YOUR CODE STARTS HERE
            tfl.ZeroPadding2D(padding=(3, 3), input_shape=(64, 64, 3)),
            tfl.Conv2D(32, (7,7), strides=(1, 1)),
            tfl.BatchNormalization(axis=-1),
            tfl.ReLU(),
            tfl.MaxPool2D(),
            tfl.Flatten(),
            tfl.Dense(1, activation='sigmoid')
            # YOUR CODE ENDS HERE
        ])
    
    return model

# %%
happy_model = happyModel()
# Print a summary for each layer
for layer in summary(happy_model):
    print(layer)
    
output = [['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))],
            ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform'],
            ['BatchNormalization', (None, 64, 64, 32), 128],
            ['ReLU', (None, 64, 64, 32), 0],
            ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid'],
            ['Flatten', (None, 32768), 0],
            ['Dense', (None, 1), 32769, 'sigmoid']]
    
comparator(summary(happy_model), output)
# Out:
# ['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))]
# ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform']
# ['BatchNormalization', (None, 64, 64, 32), 128]
# ['ReLU', (None, 64, 64, 32), 0]
# ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid']
# ['Flatten', (None, 32768), 0]
# ['Dense', (None, 1), 32769, 'sigmoid']
# All tests passed!
# 2022-12-06 00:12:00.999609: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luiscantero/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-12-06 00:12:01.000596: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-06 00:12:01.000732: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (LAPTOP-P5EMMDVO): /proc/driver/nvidia/version does not exist
# 2022-12-06 00:12:01.005922: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Now that your model is created, you can compile it for training with an optimizer and loss of your choice. When the string `accuracy` is specified as a metric, the type of accuracy used will be automatically converted based on the loss function used. This is one of the many optimizations built into TensorFlow that make your life easier! If you'd like to read more on how the compiler operates, check the docs [here](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile).

# %%
happy_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %% [markdown]
# It's time to check your model's parameters with the `.summary()` method. This will display the types of layers you have, the shape of the outputs, and how many parameters are in each layer.

# %%
happy_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d (ZeroPadding  (None, 70, 70, 3)        0
#  2D)
#
#  conv2d (Conv2D)             (None, 64, 64, 32)        4736
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  re_lu (ReLU)                (None, 64, 64, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1)                 32769
#
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Train and Evaluate the Model
#
# After creating the model, compiling it with your choice of optimizer and loss function, and doing a sanity check on its contents, you are now ready to build!
#
# Simply call `.fit()` to train. That's it! No need for mini-batching, saving, or complex backpropagation computations. That's all been done for you, as you're using a TensorFlow dataset with the batches specified already. You do have the option to specify epoch number or minibatch size if you like (for example, in the case of an un-batched dataset).

# %%
happy_model.fit(X_train, Y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 350/350 [==============================] - 16s 43ms/step - loss: 0.0745 - accuracy: 0.9851
# Epoch 2/10
# 350/350 [==============================] - 15s 42ms/step - loss: 0.0337 - accuracy: 0.9966
# Epoch 3/10
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0374 - accuracy: 0.9966
# Epoch 4/10
# 350/350 [==============================] - 24s 69ms/step - loss: 0.0433 - accuracy: 0.9964
# Epoch 5/10
# 350/350 [==============================] - 27s 77ms/step - loss: 0.0170 - accuracy: 0.9973
# Epoch 6/10
# 350/350 [==============================] - 25s 72ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 7/10
# 350/350 [==============================] - 20s 56ms/step - loss: 0.0100 - accuracy: 0.9989
# Epoch 8/10
# 350/350 [==============================] - 23s 65ms/step - loss: 0.0235 - accuracy: 0.9975
# Epoch 9/10
# 350/350 [==============================] - 25s 72ms/step - loss: 0.0046 - accuracy: 0.9993
# Epoch 10/10
# 350/350 [==============================] - 29s 84ms/step - loss: 7.3763e-04 - accuracy: 0.9996

# %% [markdown]
# After that completes, just use `.evaluate()` to evaluate against your test set. This function will print the value of the loss function and the performance metrics specified during the compilation of the model. In this case, the `binary_crossentropy` and the `accuracy` respectively.

# %%
happy_model.evaluate(X_test, Y_test)
# Out:
# 101/101 [==============================] - 3s 26ms/step - loss: 1.8981 - accuracy: 0.9022
# [1.8980917930603027, 0.9022180438041687]

# %% [markdown]
# Easy, right? But what if you need to build a model with shared layers, branches, or multiple inputs and outputs? This is where Sequential, with its beautifully simple yet limited functionality, won't be able to help you.
#
# Next up: Enter the Functional API, your slightly more complex, highly flexible friend.

# %% [markdown]
# <a name='4'></a>
# ## 4 - The Functional API

# %% [markdown]
# Welcome to the second half of the assignment, where you'll use Keras' flexible [Functional API](https://www.tensorflow.org/guide/keras/functional) to build a ConvNet that can differentiate between 6 sign language digits.
#
# The Functional API can handle models with non-linear topology, shared layers, as well as layers with multiple inputs or outputs. Imagine that, where the Sequential API requires the model to move in a linear fashion through its layers, the Functional API allows much more flexibility. Where Sequential is a straight line, a Functional model is a graph, where the nodes of the layers can connect in many more ways than one.
#
# In the visual example below, the one possible direction of the movement Sequential model is shown in contrast to a skip connection, which is just one of the many ways a Functional model can be constructed. A skip connection, as you might have guessed, skips some layer in the network and feeds the output to a later layer in the network. Don't worry, you'll be spending more time with skip connections very soon!

# %% [markdown]
# <img src="images/seq_vs_func.png" style="width:350px;height:200px;">

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Load the SIGNS Dataset
#
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %% [markdown]
# <img src="images/SIGNS.png" style="width:800px;height:300px;">
#
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of an image from the dataset
index = 9
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 4

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Split the Data into Train/Test Sets
#
# In Course 2, you built a fully-connected network for this dataset. But since this is an image dataset, it is more natural to apply a ConvNet to it.
#
# To get started, let's examine the shapes of your data.

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Forward Propagation
#
# In TensorFlow, there are built-in functions that implement the convolution steps for you. By now, you should be familiar with how TensorFlow builds computational graphs. In the [Functional API](https://www.tensorflow.org/guide/keras/functional), you create a graph of layers. This is what allows such great flexibility.
#
# However, the following model could also be defined using the Sequential API since the information flow is on a single line. But don't deviate. What we want you to learn is to use the functional API.
#
# Begin building your graph of layers by creating an input node that functions as a callable object:
#
# - **input_img = tf.keras.Input(shape=input_shape):**
#
# Then, create a new node in the graph of layers by calling a layer on the `input_img` object:
#
# - **tf.keras.layers.Conv2D(filters= ... , kernel_size= ... , padding='same')(input_img):** Read the full documentation on [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D).
#
# - **tf.keras.layers.MaxPool2D(pool_size=(f, f), strides=(s, s), padding='same'):** `MaxPool2D()` downsamples your input using a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window.  For max pooling, you usually operate on a single example at a time and a single channel at a time. Read the full documentation on [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D).
#
# - **tf.keras.layers.ReLU():** computes the elementwise ReLU of Z (which can be any shape). You can read the full documentation on [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU).
#
# - **tf.keras.layers.Flatten()**: given a tensor "P", this function takes each training (or test) example in the batch and flattens it into a 1D vector.
#
#     * If a tensor P has the shape (batch_size,h,w,c), it returns a flattened tensor with shape (batch_size, k), where $k=h \times w \times c$.  "k" equals the product of all the dimension sizes other than the first dimension.
#
#     * For example, given a tensor with dimensions [100, 2, 3, 4], it flattens the tensor to be of shape [100, 24], where 24 = 2 * 3 * 4.  You can read the full documentation on [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten).
#
# - **tf.keras.layers.Dense(units= ... , activation='softmax')(F):** given the flattened input F, it returns the output computed using a fully connected layer. You can read the full documentation on [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense).
#
# In the last function above (`tf.keras.layers.Dense()`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
# Lastly, before creating the model, you'll need to define the output using the last of the function's compositions (in this example, a Dense layer):
#
# - **outputs = tf.keras.layers.Dense(units=6, activation='softmax')(F)**
#
#
# #### Window, kernel, filter, pool
#
# The words "kernel" and "filter" are used to refer to the same thing. The word "filter" accounts for the amount of "kernels" that will be used in a single convolution layer. "Pool" is the name of the operation that takes the max or average value of the kernels.
#
# This is why the parameter `pool_size` refers to `kernel_size`, and you use `(f,f)` to refer to the filter size.
#
# Pool size and kernel size refer to the same thing in different objects - They refer to the shape of the window where the operation takes place.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - convolutional_model
#
# Implement the `convolutional_model` function below to build the following model: `CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE`. Use the functions above!
#
# Also, plug in the following parameters for all the steps:
#
#  - [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): Use 8 4 by 4 filters, stride 1, padding is "SAME"
#  - [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU)
#  - [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): Use an 8 by 8 filter size and an 8 by 8 stride, padding is "SAME"
#  - **Conv2D**: Use 16 2 by 2 filters, stride 1, padding is "SAME"
#  - **ReLU**
#  - **MaxPool2D**: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "SAME"
#  - [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the previous output.
#  - Fully-connected ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) layer: Apply a fully connected layer with 6 neurons and a softmax activation.

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    # Z1 = None
    ## RELU
    # A1 = None
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    # P1 = None
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    # Z2 = None
    ## RELU
    # A2 = None
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    # P2 = None
    ## FLATTEN
    # F = None
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    # outputs = None
    # YOUR CODE STARTS HERE
    Z1 = tfl.Conv2D(8, 4, activation='linear', padding="same", strides=1)(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)
    Z2 = tfl.Conv2D(16, 2, activation='linear', padding="same", strides=1)(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    F = tfl.Flatten()(P2)
    outputs = tfl.Dense(6, activation='softmax')(F)
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
    
output = [['InputLayer', [(None, 64, 64, 3)], 0],
        ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 64, 64, 8), 0],
        ['MaxPooling2D', (None, 8, 8, 8), 0, (8, 8), (8, 8), 'same'],
        ['Conv2D', (None, 8, 8, 16), 528, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 8, 8, 16), 0],
        ['MaxPooling2D', (None, 2, 2, 16), 0, (4, 4), (4, 4), 'same'],
        ['Flatten', (None, 64), 0],
        ['Dense', (None, 6), 390, 'softmax']]
    
comparator(summary(conv_model), output)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 8)         392
#
#  re_lu_3 (ReLU)              (None, 64, 64, 8)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 16)          528
#
#  re_lu_4 (ReLU)              (None, 8, 8, 16)          0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________
# All tests passed!

# %% [markdown]
# Both the Sequential and Functional APIs return a TF Keras model object. The only difference is how inputs are handled inside the object model!

# %% [markdown]
# <a name='4-4'></a>
# ### 4.4 - Train the Model

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 49ms/step - loss: 1.7970 - accuracy: 0.1657 - val_loss: 1.7851 - val_accuracy: 0.1833
# Epoch 2/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.7846 - accuracy: 0.2120 - val_loss: 1.7809 - val_accuracy: 0.2750
# Epoch 3/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.7792 - accuracy: 0.2750 - val_loss: 1.7746 - val_accuracy: 0.2917
# Epoch 4/100
# 17/17 [==============================] - 1s 47ms/step - loss: 1.7739 - accuracy: 0.2917 - val_loss: 1.7693 - val_accuracy: 0.3500
# Epoch 5/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.7669 - accuracy: 0.3389 - val_loss: 1.7638 - val_accuracy: 0.3583
# Epoch 6/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.7587 - accuracy: 0.3722 - val_loss: 1.7563 - val_accuracy: 0.3417
# Epoch 7/100
# 17/17 [==============================] - 1s 48ms/step - loss: 1.7494 - accuracy: 0.3787 - val_loss: 1.7472 - val_accuracy: 0.4000
# Epoch 8/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.7364 - accuracy: 0.3981 - val_loss: 1.7353 - val_accuracy: 0.4083
# Epoch 9/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.7214 - accuracy: 0.4259 - val_loss: 1.7220 - val_accuracy: 0.3500
# Epoch 10/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.7033 - accuracy: 0.4269 - val_loss: 1.7043 - val_accuracy: 0.4000
# Epoch 11/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.6799 - accuracy: 0.4343 - val_loss: 1.6814 - val_accuracy: 0.4000
# Epoch 12/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6517 - accuracy: 0.4352 - val_loss: 1.6564 - val_accuracy: 0.4167
# Epoch 13/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6194 - accuracy: 0.4380 - val_loss: 1.6264 - val_accuracy: 0.4083
# Epoch 14/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.5823 - accuracy: 0.4435 - val_loss: 1.5925 - val_accuracy: 0.4250
# Epoch 15/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.5434 - accuracy: 0.4509 - val_loss: 1.5562 - val_accuracy: 0.4333
# Epoch 16/100
# 17/17 [==============================] - 1s 50ms/step - loss: 1.5025 - accuracy: 0.4620 - val_loss: 1.5200 - val_accuracy: 0.4583
# Epoch 17/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.4616 - accuracy: 0.4815 - val_loss: 1.4824 - val_accuracy: 0.4750
# Epoch 18/100
# 17/17 [==============================] - 1s 49ms/step - loss: 1.4213 - accuracy: 0.4963 - val_loss: 1.4463 - val_accuracy: 0.4833
# Epoch 19/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.3831 - accuracy: 0.5139 - val_loss: 1.4114 - val_accuracy: 0.5000
# Epoch 20/100
# 17/17 [==============================] - 1s 47ms/step - loss: 1.3452 - accuracy: 0.5417 - val_loss: 1.3761 - val_accuracy: 0.5083
# Epoch 21/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.3091 - accuracy: 0.5593 - val_loss: 1.3425 - val_accuracy: 0.5167
# Epoch 22/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.2744 - accuracy: 0.5778 - val_loss: 1.3086 - val_accuracy: 0.5250
# Epoch 23/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.2406 - accuracy: 0.5898 - val_loss: 1.2757 - val_accuracy: 0.5750
# Epoch 24/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.2064 - accuracy: 0.6019 - val_loss: 1.2423 - val_accuracy: 0.5833
# Epoch 25/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.1745 - accuracy: 0.6148 - val_loss: 1.2119 - val_accuracy: 0.6000
# Epoch 26/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.1438 - accuracy: 0.6204 - val_loss: 1.1818 - val_accuracy: 0.5750
# Epoch 27/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.1145 - accuracy: 0.6343 - val_loss: 1.1537 - val_accuracy: 0.5667
# Epoch 28/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.0866 - accuracy: 0.6454 - val_loss: 1.1265 - val_accuracy: 0.5583
# Epoch 29/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.0593 - accuracy: 0.6546 - val_loss: 1.1015 - val_accuracy: 0.5833
# Epoch 30/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.0339 - accuracy: 0.6685 - val_loss: 1.0751 - val_accuracy: 0.5833
# Epoch 31/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.0106 - accuracy: 0.6778 - val_loss: 1.0515 - val_accuracy: 0.5917
# Epoch 32/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9874 - accuracy: 0.6824 - val_loss: 1.0266 - val_accuracy: 0.5750
# Epoch 33/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9653 - accuracy: 0.6926 - val_loss: 1.0059 - val_accuracy: 0.6000
# Epoch 34/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9431 - accuracy: 0.6944 - val_loss: 0.9844 - val_accuracy: 0.5917
# Epoch 35/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9235 - accuracy: 0.7019 - val_loss: 0.9639 - val_accuracy: 0.6167
# Epoch 36/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9037 - accuracy: 0.7065 - val_loss: 0.9445 - val_accuracy: 0.6167
# Epoch 37/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.8844 - accuracy: 0.7139 - val_loss: 0.9263 - val_accuracy: 0.6250
# Epoch 38/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.8669 - accuracy: 0.7194 - val_loss: 0.9072 - val_accuracy: 0.6250
# Epoch 39/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.8498 - accuracy: 0.7250 - val_loss: 0.8894 - val_accuracy: 0.6333
# Epoch 40/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.8330 - accuracy: 0.7315 - val_loss: 0.8711 - val_accuracy: 0.6500
# Epoch 41/100
# 17/17 [==============================] - 1s 53ms/step - loss: 0.8164 - accuracy: 0.7361 - val_loss: 0.8541 - val_accuracy: 0.6583
# Epoch 42/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.8009 - accuracy: 0.7417 - val_loss: 0.8382 - val_accuracy: 0.6750
# Epoch 43/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.7860 - accuracy: 0.7472 - val_loss: 0.8221 - val_accuracy: 0.6750
# Epoch 44/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.7714 - accuracy: 0.7556 - val_loss: 0.8066 - val_accuracy: 0.6750
# Epoch 45/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.7575 - accuracy: 0.7546 - val_loss: 0.7922 - val_accuracy: 0.6917
# Epoch 46/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.7442 - accuracy: 0.7611 - val_loss: 0.7790 - val_accuracy: 0.7083
# Epoch 47/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.7312 - accuracy: 0.7620 - val_loss: 0.7660 - val_accuracy: 0.7000
# Epoch 48/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.7187 - accuracy: 0.7676 - val_loss: 0.7542 - val_accuracy: 0.7083
# Epoch 49/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.7072 - accuracy: 0.7713 - val_loss: 0.7419 - val_accuracy: 0.7167
# Epoch 50/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.6957 - accuracy: 0.7769 - val_loss: 0.7293 - val_accuracy: 0.7250
# Epoch 51/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.6843 - accuracy: 0.7769 - val_loss: 0.7173 - val_accuracy: 0.7250
# Epoch 52/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.6734 - accuracy: 0.7787 - val_loss: 0.7067 - val_accuracy: 0.7250
# Epoch 53/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.6635 - accuracy: 0.7824 - val_loss: 0.6975 - val_accuracy: 0.7250
# Epoch 54/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6538 - accuracy: 0.7861 - val_loss: 0.6874 - val_accuracy: 0.7333
# Epoch 55/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.6443 - accuracy: 0.7870 - val_loss: 0.6774 - val_accuracy: 0.7500
# Epoch 56/100
# 17/17 [==============================] - 1s 53ms/step - loss: 0.6353 - accuracy: 0.7870 - val_loss: 0.6680 - val_accuracy: 0.7500
# Epoch 57/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.6263 - accuracy: 0.7880 - val_loss: 0.6589 - val_accuracy: 0.7583
# Epoch 58/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.6178 - accuracy: 0.7898 - val_loss: 0.6499 - val_accuracy: 0.7667
# Epoch 59/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.6091 - accuracy: 0.7926 - val_loss: 0.6415 - val_accuracy: 0.7750
# Epoch 60/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.6009 - accuracy: 0.7935 - val_loss: 0.6325 - val_accuracy: 0.7750
# Epoch 61/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.5930 - accuracy: 0.7981 - val_loss: 0.6235 - val_accuracy: 0.7917
# Epoch 62/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5849 - accuracy: 0.8028 - val_loss: 0.6149 - val_accuracy: 0.7917
# Epoch 63/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5768 - accuracy: 0.8074 - val_loss: 0.6071 - val_accuracy: 0.7917
# Epoch 64/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5691 - accuracy: 0.8083 - val_loss: 0.5992 - val_accuracy: 0.8000
# Epoch 65/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5614 - accuracy: 0.8139 - val_loss: 0.5915 - val_accuracy: 0.8000
# Epoch 66/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5535 - accuracy: 0.8185 - val_loss: 0.5830 - val_accuracy: 0.8000
# Epoch 67/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.5461 - accuracy: 0.8222 - val_loss: 0.5747 - val_accuracy: 0.8083
# Epoch 68/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5389 - accuracy: 0.8241 - val_loss: 0.5673 - val_accuracy: 0.8167
# Epoch 69/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.5316 - accuracy: 0.8287 - val_loss: 0.5597 - val_accuracy: 0.8167
# Epoch 70/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5248 - accuracy: 0.8296 - val_loss: 0.5532 - val_accuracy: 0.8167
# Epoch 71/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5182 - accuracy: 0.8306 - val_loss: 0.5464 - val_accuracy: 0.8167
# Epoch 72/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5115 - accuracy: 0.8315 - val_loss: 0.5390 - val_accuracy: 0.8167
# Epoch 73/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.5053 - accuracy: 0.8343 - val_loss: 0.5328 - val_accuracy: 0.8250
# Epoch 74/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4990 - accuracy: 0.8352 - val_loss: 0.5264 - val_accuracy: 0.8250
# Epoch 75/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4928 - accuracy: 0.8361 - val_loss: 0.5201 - val_accuracy: 0.8333
# Epoch 76/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4868 - accuracy: 0.8407 - val_loss: 0.5139 - val_accuracy: 0.8333
# Epoch 77/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4808 - accuracy: 0.8454 - val_loss: 0.5078 - val_accuracy: 0.8417
# Epoch 78/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4749 - accuracy: 0.8491 - val_loss: 0.5015 - val_accuracy: 0.8417
# Epoch 79/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4691 - accuracy: 0.8509 - val_loss: 0.4954 - val_accuracy: 0.8500
# Epoch 80/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4633 - accuracy: 0.8519 - val_loss: 0.4887 - val_accuracy: 0.8500
# Epoch 81/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4574 - accuracy: 0.8519 - val_loss: 0.4827 - val_accuracy: 0.8500
# Epoch 82/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4517 - accuracy: 0.8537 - val_loss: 0.4768 - val_accuracy: 0.8500
# Epoch 83/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4464 - accuracy: 0.8546 - val_loss: 0.4717 - val_accuracy: 0.8500
# Epoch 84/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4411 - accuracy: 0.8556 - val_loss: 0.4656 - val_accuracy: 0.8583
# Epoch 85/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4360 - accuracy: 0.8565 - val_loss: 0.4605 - val_accuracy: 0.8667
# Epoch 86/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4311 - accuracy: 0.8583 - val_loss: 0.4549 - val_accuracy: 0.8750
# Epoch 87/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.4264 - accuracy: 0.8611 - val_loss: 0.4506 - val_accuracy: 0.8750
# Epoch 88/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4213 - accuracy: 0.8630 - val_loss: 0.4460 - val_accuracy: 0.8750
# Epoch 89/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4168 - accuracy: 0.8639 - val_loss: 0.4412 - val_accuracy: 0.8750
# Epoch 90/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.4121 - accuracy: 0.8639 - val_loss: 0.4366 - val_accuracy: 0.8750
# Epoch 91/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4075 - accuracy: 0.8657 - val_loss: 0.4323 - val_accuracy: 0.8750
# Epoch 92/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.4037 - accuracy: 0.8694 - val_loss: 0.4282 - val_accuracy: 0.8750
# Epoch 93/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.3993 - accuracy: 0.8750 - val_loss: 0.4239 - val_accuracy: 0.8750
# Epoch 94/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.3951 - accuracy: 0.8750 - val_loss: 0.4203 - val_accuracy: 0.8750
# Epoch 95/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.3911 - accuracy: 0.8759 - val_loss: 0.4167 - val_accuracy: 0.8750
# Epoch 96/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.3871 - accuracy: 0.8759 - val_loss: 0.4133 - val_accuracy: 0.8750
# Epoch 97/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.3831 - accuracy: 0.8769 - val_loss: 0.4099 - val_accuracy: 0.8750
# Epoch 98/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.3793 - accuracy: 0.8778 - val_loss: 0.4068 - val_accuracy: 0.8750
# Epoch 99/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.3759 - accuracy: 0.8759 - val_loss: 0.4037 - val_accuracy: 0.8750
# Epoch 100/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.3721 - accuracy: 0.8787 - val_loss: 0.4008 - val_accuracy: 0.8750

# %% [markdown]
# <a name='5'></a>
# ## 5 - History Object
#
# The history object is an output of the `.fit()` operation, and provides a record of all the loss and metric values in memory. It's stored as a dictionary that you can retrieve at `history.history`:

# %%
history.history
# Out:
# {'loss': [1.7970001697540283,
#   1.784600019454956,
#   1.7791810035705566,
#   1.7739436626434326,
#   1.7668647766113281,
#   1.7586524486541748,
#   1.7493844032287598,
#   1.73641836643219,
#   1.7213776111602783,
#   1.703260064125061,
#   1.6798549890518188,
#   1.6517353057861328,
#   1.619429111480713,
#   1.5823018550872803,
#   1.5433598756790161,
#   1.5024875402450562,
#   1.4615808725357056,
#   1.4213159084320068,
#   1.3831208944320679,
#   1.345178484916687,
#   1.3091049194335938,
#   1.274365782737732,
#   1.240636944770813,
#   1.206384539604187,
#   1.1744599342346191,
#   1.1437902450561523,
#   1.1144933700561523,
#   1.0866413116455078,
#   1.0593301057815552,
#   1.0339248180389404,
#   1.0106135606765747,
#   0.9873827695846558,
#   0.9653337001800537,
#   0.9430850148200989,
#   0.9234941005706787,
#   0.9037467241287231,
#   0.8844118118286133,
#   0.8668932914733887,
#   0.8498059511184692,
#   0.8329607248306274,
#   0.8163552284240723,
#   0.8009004592895508,
#   0.7859840989112854,
#   0.7713519334793091,
#   0.7574673295021057,
#   0.7442060112953186,
#   0.7312048077583313,
#   0.7187241911888123,
#   0.7072427272796631,
#   0.695708155632019,
#   0.6842795610427856,
#   0.6734232306480408,
#   0.6634508967399597,
#   0.6537796854972839,
#   0.6442853212356567,
#   0.6353396773338318,
#   0.6263456344604492,
#   0.6177883148193359,
#   0.609145998954773,
#   0.6008992791175842,
#   0.5929768085479736,
#   0.5849058628082275,
#   0.5768399834632874,
#   0.569077730178833,
#   0.5613522529602051,
#   0.5535370111465454,
#   0.5460859537124634,
#   0.5389100313186646,
#   0.5316178798675537,
#   0.5248435139656067,
#   0.5181824564933777,
#   0.5115487575531006,
#   0.5052518248558044,
#   0.4990348517894745,
#   0.49275049567222595,
#   0.4867786467075348,
#   0.4808329939842224,
#   0.4749295711517334,
#   0.4690747559070587,
#   0.46325984597206116,
#   0.45742693543434143,
#   0.4517452120780945,
#   0.44641414284706116,
#   0.4410530924797058,
#   0.4360339045524597,
#   0.4311279058456421,
#   0.4263536036014557,
#   0.42131364345550537,
#   0.4168049097061157,
#   0.41211703419685364,
#   0.40754055976867676,
#   0.40367481112480164,
#   0.39933887124061584,
#   0.3951323926448822,
#   0.3910502791404724,
#   0.3871418535709381,
#   0.38308992981910706,
#   0.3793368339538574,
#   0.3758535087108612,
#   0.37205052375793457],
#  'accuracy': [0.1657407432794571,
#   0.21203704178333282,
#   0.2750000059604645,
#   0.2916666567325592,
#   0.33888888359069824,
#   0.3722222149372101,
#   0.3787037134170532,
#   0.39814814925193787,
#   0.42592594027519226,
#   0.4268518388271332,
#   0.4342592656612396,
#   0.43518519401550293,
#   0.43796294927597046,
#   0.4435185194015503,
#   0.45092591643333435,
#   0.46203702688217163,
#   0.48148149251937866,
#   0.4962962865829468,
#   0.5138888955116272,
#   0.5416666865348816,
#   0.5592592358589172,
#   0.5777778029441833,
#   0.5898148417472839,
#   0.6018518805503845,
#   0.614814817905426,
#   0.6203703880310059,
#   0.6342592835426331,
#   0.645370364189148,
#   0.654629647731781,
#   0.6685185432434082,
#   0.6777777671813965,
#   0.6824073791503906,
#   0.6925926208496094,
#   0.6944444179534912,
#   0.7018518447875977,
#   0.7064814567565918,
#   0.7138888835906982,
#   0.7194444537162781,
#   0.7250000238418579,
#   0.7314814925193787,
#   0.7361111044883728,
#   0.7416666746139526,
#   0.7472222447395325,
#   0.7555555701255798,
#   0.7546296119689941,
#   0.7611111402511597,
#   0.7620370388031006,
#   0.7675926089286804,
#   0.7712963223457336,
#   0.7768518328666687,
#   0.7768518328666687,
#   0.7787036895751953,
#   0.7824074029922485,
#   0.7861111164093018,
#   0.7870370149612427,
#   0.7870370149612427,
#   0.7879629731178284,
#   0.789814829826355,
#   0.7925925850868225,
#   0.7935185432434082,
#   0.7981481552124023,
#   0.8027777671813965,
#   0.8074073791503906,
#   0.8083333373069763,
#   0.8138889074325562,
#   0.8185185194015503,
#   0.8222222328186035,
#   0.8240740895271301,
#   0.8287037014961243,
#   0.8296296000480652,
#   0.8305555582046509,
#   0.8314814567565918,
#   0.8342592716217041,
#   0.835185170173645,
#   0.8361111283302307,
#   0.8407407402992249,
#   0.845370352268219,
#   0.8490740656852722,
#   0.8509259223937988,
#   0.8518518805503845,
#   0.8518518805503845,
#   0.8537036776542664,
#   0.854629635810852,
#   0.855555534362793,
#   0.8564814925193787,
#   0.8583333492279053,
#   0.8611111044883728,
#   0.8629629611968994,
#   0.8638888597488403,
#   0.8638888597488403,
#   0.8657407164573669,
#   0.8694444298744202,
#   0.875,
#   0.875,
#   0.8759258985519409,
#   0.8759258985519409,
#   0.8768518567085266,
#   0.8777777552604675,
#   0.8759258985519409,
#   0.8787037134170532],
#  'val_loss': [1.7851041555404663,
#   1.7809138298034668,
#   1.7746357917785645,
#   1.7692980766296387,
#   1.7637616395950317,
#   1.7563214302062988,
#   1.7472440004348755,
#   1.735326886177063,
#   1.722044587135315,
#   1.7043074369430542,
#   1.6814407110214233,
#   1.6564252376556396,
#   1.6263521909713745,
#   1.5925121307373047,
#   1.5561718940734863,
#   1.5200417041778564,
#   1.48239266872406,
#   1.4462529420852661,
#   1.4114469289779663,
#   1.3760813474655151,
#   1.3425140380859375,
#   1.3086177110671997,
#   1.2757006883621216,
#   1.2423245906829834,
#   1.2119320631027222,
#   1.181829571723938,
#   1.1536768674850464,
#   1.1265063285827637,
#   1.1015105247497559,
#   1.0751194953918457,
#   1.0515029430389404,
#   1.02658212184906,
#   1.005913257598877,
#   0.9844398498535156,
#   0.9638952612876892,
#   0.9444721937179565,
#   0.9262891411781311,
#   0.9072170257568359,
#   0.8893635272979736,
#   0.8710930943489075,
#   0.8541424870491028,
#   0.8381884098052979,
#   0.8220626711845398,
#   0.8066380023956299,
#   0.792236328125,
#   0.7789535522460938,
#   0.7659603357315063,
#   0.7541627883911133,
#   0.7419307827949524,
#   0.7292619943618774,
#   0.7173472046852112,
#   0.7067171931266785,
#   0.697540283203125,
#   0.6873711943626404,
#   0.6774423122406006,
#   0.6680304408073425,
#   0.6589308381080627,
#   0.6499373316764832,
#   0.6415027379989624,
#   0.6325369477272034,
#   0.623522162437439,
#   0.6148576736450195,
#   0.6070839166641235,
#   0.5991965532302856,
#   0.5915442109107971,
#   0.5829658508300781,
#   0.5747089385986328,
#   0.5673333406448364,
#   0.5596504807472229,
#   0.5531553626060486,
#   0.5463557839393616,
#   0.5389562249183655,
#   0.5327667593955994,
#   0.5263605713844299,
#   0.5201488137245178,
#   0.5139451622962952,
#   0.5078088641166687,
#   0.5015161633491516,
#   0.49538880586624146,
#   0.4886755645275116,
#   0.4826776087284088,
#   0.4767637252807617,
#   0.47172626852989197,
#   0.46562740206718445,
#   0.4604823887348175,
#   0.454916387796402,
#   0.45057204365730286,
#   0.4459582567214966,
#   0.44122615456581116,
#   0.4365502595901489,
#   0.432348370552063,
#   0.4282110631465912,
#   0.4239395260810852,
#   0.42026200890541077,
#   0.41667333245277405,
#   0.4133089482784271,
#   0.40990808606147766,
#   0.4067854881286621,
#   0.4036673307418823,
#   0.4007939398288727],
#  'val_accuracy': [0.18333333730697632,
#   0.2750000059604645,
#   0.2916666567325592,
#   0.3499999940395355,
#   0.3583333194255829,
#   0.34166666865348816,
#   0.4000000059604645,
#   0.40833333134651184,
#   0.3499999940395355,
#   0.4000000059604645,
#   0.4000000059604645,
#   0.4166666567325592,
#   0.40833333134651184,
#   0.42500001192092896,
#   0.4333333373069763,
#   0.4583333432674408,
#   0.4749999940395355,
#   0.4833333194255829,
#   0.5,
#   0.5083333253860474,
#   0.5166666507720947,
#   0.5249999761581421,
#   0.574999988079071,
#   0.5833333134651184,
#   0.6000000238418579,
#   0.574999988079071,
#   0.5666666626930237,
#   0.5583333373069763,
#   0.5833333134651184,
#   0.5833333134651184,
#   0.5916666388511658,
#   0.574999988079071,
#   0.6000000238418579,
#   0.5916666388511658,
#   0.6166666746139526,
#   0.6166666746139526,
#   0.625,
#   0.625,
#   0.6333333253860474,
#   0.6499999761581421,
#   0.6583333611488342,
#   0.675000011920929,
#   0.675000011920929,
#   0.675000011920929,
#   0.6916666626930237,
#   0.7083333134651184,
#   0.699999988079071,
#   0.7083333134651184,
#   0.7166666388511658,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7333333492279053,
#   0.75,
#   0.75,
#   0.7583333253860474,
#   0.7666666507720947,
#   0.7749999761581421,
#   0.7749999761581421,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.8083333373069763,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.824999988079071,
#   0.824999988079071,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8583333492279053,
#   0.8666666746139526,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875,
#   0.875]}

# %% [markdown]
# Now visualize the loss over time using `history.history`:

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /home/luiscantero/.local/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %% [markdown]
# **Congratulations**! You've finished the assignment and built two models: One that recognizes  smiles, and another that recognizes SIGN language with almost 80% accuracy on the test set. In addition to that, you now also understand the applications of two Keras APIs: Sequential and Functional. Nicely done!
#
# By now, you know a bit about how the Functional API works and may have glimpsed the possibilities. In your next assignment, you'll really get a feel for its power when you get the opportunity to build a very deep ConvNet, using ResNets!

# %% [markdown]
# <a name='6'></a>
# ## 6 - Bibliography
#
# You're always encouraged to read the official documentation. To that end, you can find the docs for the Sequential and Functional APIs here:
#
# https://www.tensorflow.org/guide/keras/sequential_model
#
# https://www.tensorflow.org/guide/keras/functional
